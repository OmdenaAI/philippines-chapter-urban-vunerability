# %%
######################################
#### UNCOMMENT THE COMMANDS BELOW ####
######################################

# !pip install -r /content/drive/MyDrive/Projects/philippines-chapter-urban-vunerability/noah/requirements.txt
# !npm install -g mapshaper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geopandas
#   Downloading geopandas-0.12.2-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 11.7 MB/s eta 0:00:00
# Collecting fiona
#   Downloading Fiona-1.8.22-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 42.2 MB/s eta 0:00:00
# Requirement already satisfied: shapely>=1.7 in /usr/local/lib/python3.8/dist-packages (from geopandas->-r /content/drive/MyDrive/Projects/philippines-chapter-urban-vunerability/noah/requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from geopandas->-r /content/drive/MyDrive/Projects/philippines-chapter-urban-vunerability/noah/requirements.txt (line 1)) (1.3.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from geopandas->-r /content/drive/MyDrive/Projects/philippines-chapter-urban-vunerability/noah/requirements.txt (line 1)) (21.3)
# Collecting pyproj>=2.6.1.post1
#   Downloading pyproj-3.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 88.0 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.8/dist-packages (from fiona->-r /content/drive/MyDrive/Projects/philippines-chapter-urban-vunerability/noah/requirements.txt (line 2)) (1.15.0)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.8/dist-packages (from fiona->-r /content/drive/MyDrive/Projects/philippines-chapter-urban-vunerability/noah/requirements.txt (line 2)) (7.1.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from fiona->-r /content/drive/MyDrive/Projects/philippines-chapter-urban-vunerability/noah/requirements.txt (line 2)) (2022.12.7)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.8/dist-packages (from fiona->-r /content/drive/MyDrive/Projects/philippines-chapter-urban-vunerability/noah/requirements.txt (line 2)) (22.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from fiona->-r /content/drive/MyDrive/Projects/philippines-chapter-urban-vunerability/noah/requirements.txt (line 2)) (57.4.0)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.0->geopandas->-r /content/drive/MyDrive/Projects/philippines-chapter-urban-vunerability/noah/requirements.txt (line 1)) (2022.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.0->geopandas->-r /content/drive/MyDrive/Projects/philippines-chapter-urban-vunerability/noah/requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.0->geopandas->-r /content/drive/MyDrive/Projects/philippines-chapter-urban-vunerability/noah/requirements.txt (line 1)) (1.21.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->geopandas->-r /content/drive/MyDrive/Projects/philippines-chapter-urban-vunerability/noah/requirements.txt (line 1)) (3.0.9)
# Installing collected packages: pyproj, munch, cligj, click-plugins, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.8.22 geopandas-0.12.2 munch-2.5.0 pyproj-3.4.1
# /tools/node/bin/mapshaper -> /tools/node/lib/node_modules/mapshaper/bin/mapshaper
# /tools/node/bin/mapshaper-gui -> /tools/node/lib/node_modules/mapshaper/bin/mapshaper-gui
# /tools/node/bin/mapshaper-xl -> /tools/node/lib/node_modules/mapshaper/bin/mapshaper-xl
#
# > msgpackr-extract@2.2.0 install /tools/node/lib/node_modules/mapshaper/node_modules/msgpackr-extract
# > node-gyp-build-optional-packages
#
# npm WARN optional SKIPPING OPTIONAL DEPENDENCY: @msgpackr-extract/msgpackr-extract-linux-arm64@2.2.0 (node_modules/mapshaper/node_modules/msgpackr-extract/node_modules/@msgpackr-extract/msgpackr-extract-linux-arm64):
# npm WARN notsup SKIPPING OPTIONAL DEPENDENCY: Unsupported platform for @msgpackr-extract/msgpackr-extract-linux-arm64@2.2.0: wanted {"os":"linux","arch":"arm64"} (current: {"os":"linux","arch":"x64"})
# npm WARN optional SKIPPING OPTIONAL DEPENDENCY: @msgpackr-extract/msgpackr-extract-win32-x64@2.2.0 (node_modules/mapshaper/node_modules/msgpackr-extract/node_modules/@msgpackr-extract/msgpackr-extract-win32-x64):
# npm WARN notsup SKIPPING OPTIONAL DEPENDENCY: Unsupported platform for @msgpackr-extract/msgpackr-extract-win32-x64@2.2.0: wanted {"os":"win32","arch":"x64"} (current: {"os":"linux","arch":"x64"})
# npm WARN optional SKIPPING OPTIONAL DEPENDENCY: @msgpackr-extract/msgpackr-extract-darwin-x64@2.2.0 (node_modules/mapshaper/node_modules/msgpackr-extract/node_modules/@msgpackr-extract/msgpackr-extract-darwin-x64):
# npm WARN notsup SKIPPING OPTIONAL DEPENDENCY: Unsupported platform for @msgpackr-extract/msgpackr-extract-darwin-x64@2.2.0: wanted {"os":"darwin","arch":"x64"} (current: {"os":"linux","arch":"x64"})
# npm WARN optional SKIPPING OPTIONAL DEPENDENCY: @msgpackr-extract/msgpackr-extract-linux-arm@2.2.0 (node_modules/mapshaper/node_modules/msgpackr-extract/node_modules/@msgpackr-extract/msgpackr-extract-linux-arm):
# npm WARN notsup SKIPPING OPTIONAL DEPENDENCY: Unsupported platform for @msgpackr-extract/msgpackr-extract-linux-arm@2.2.0: wanted {"os":"linux","arch":"arm"} (current: {"os":"linux","arch":"x64"})
# npm WARN optional SKIPPING OPTIONAL DEPENDENCY: @msgpackr-extract/msgpackr-extract-darwin-arm64@2.2.0 (node_modules/mapshaper/node_modules/msgpackr-extract/node_modules/@msgpackr-extract/msgpackr-extract-darwin-arm64):
# npm WARN notsup SKIPPING OPTIONAL DEPENDENCY: Unsupported platform for @msgpackr-extract/msgpackr-extract-darwin-arm64@2.2.0: wanted {"os":"darwin","arch":"arm64"} (current: {"os":"linux","arch":"x64"})
# npm WARN @tmcw/togeojson@5.6.0 requires a peer of @types/geojson@* but none is installed. You must install peer dependencies yourself.
#
# + mapshaper@0.6.21
# added 80 packages from 89 contributors in 11.661s

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 1. Before running the script make sure you have added a shortcut to the NOAH Datasets and other necessary files into your Google Drive...
# 2. Making a copy of NOAH dataset on Google Drive. First, cd into the NOAH dataset shortcut by running the command below. The path to it might differ for you but in my case I added it into my GDrive’s root folder. The format for the command is: `%cd /path/to/NOAH/shortcut`
# 3. Upon running, it should show the exact path to the symbolic link. Copy it! Mine looks like `this:/content/drive/.shortcut-targets-by-id/1ALE4-E9c-4AGjm1fqiPprWHrLUskeY9o/noah`
# 4. Run the command below to copy from the shortcut into your desired destination folder. This has to be done because files inside shortcuts are read-only: `cp -r '/sym/link/path/.' 'path/to/desired/directory'`
# 5. Once copied, make sure to work off of the notebook in the new directory you just copied.
# 6. Make sure to change the value for the PATH_TO_NB  variable under the Set config variables section. This variable contains the path to the notebook within the newly copied directory.
# 7. Run the cells until the Import ph-cities-shpfile part.
# 8. Choose between Flood or Landslide-Landslide Hazards.
#     * Under Landslide-Landslide Hazards, we only have one sub-directory. One person could work on this. --> c/o @Nathalie
#     * Under Flood, we have 3 sub-directories. It would be nice if we could get at least one person to run each sub-directory.
#         * flood-100yr
#         *  flood-25yr
#         * flood-5yr
# 9. In case your notebook errors out, don’t worry! I have set it up to track the progress of each run. Just re-run the necessary cells and the mapping will start at the point where the notebook errored out.
#
# Note: I have ran the following already so no need to run:
# * Storm Surge Advisory 1
# * Storm Surge Advisory 2
# * Storm Surge Advisory 3
# * Storm Surge Advisory 4
# * Alluvial Fan
# * Debris Flow

# %%
cd /content/drive/MyDrive/Projects/philippines-chapter-urban-vunerability/noah
# Out:
# /content/drive/.shortcut-targets-by-id/1D3_MvpM0yinyvBR0VR9XVI2Es3GejevR/noah

# %%
cp -r '/content/drive/.shortcut-targets-by-id/1D3_MvpM0yinyvBR0VR9XVI2Es3GejevR/noah' '/content/drive/MyDrive/Projects/philippines-chapter-urban-vunerability/noah_working'
# Out:
# ^C

# %%
# Mount data from drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from pathlib import Path
import numpy as np
import shutil
import geopandas as gp
import os
from zipfile import ZipFile
from fiona.io import ZipMemoryFile
import subprocess

# %% [markdown]
# ### Set config variables

# %%
#####################################################
#      Set the value of PATH_TO_NB to the path      #
# to the notebook within the newly-copied directory #
#####################################################

PATH_TO_NB = "/content/drive/MyDrive/Projects/philippines-chapter-urban-vunerability/noah_working/noah/3-merging-noah-datasets.ipynb" 

WORKINGDIR = Path(PATH_TO_NB)
PROJECTROOT = WORKINGDIR.parents[0]

CITY_SHPFILE = Path(PROJECTROOT, "shp-assets", "ph-cities-shp-files", "ph_cities_v2.shp")
CALAMITY_SHPFILE_DIR = Path(PROJECTROOT, "shp-assets", "noah-shp-files")

TMP_FOLDER = Path(PROJECTROOT, "tmp-folder")
VAR_HOLDER = Path(PROJECTROOT, "var-holder")
DATASETS_DIR = Path(PROJECTROOT, "output-datasets")

# %% [markdown]
# ### Helper functions

# %%
def unzip_path(zip):
  ZipFile(zip).extractall(TMP_FOLDER)

# %%
def delete_zip_folder():
  for filename in os.listdir(TMP_FOLDER):
    file_path = os.path.join(TMP_FOLDER, filename)
    try:
        if os.path.isfile(file_path) or os.path.islink(file_path):
            os.unlink(file_path)
        elif os.path.isdir(file_path):
            shutil.rmtree(file_path)
    except Exception as e:
        print('Failed to delete %s. Reason: %s' % (file_path, e))

# %%
def retrieve_shp_file(path):
  files = os.listdir(path)
  shp = [file for file in files if ".shp" in file][0]
  return shp

# %%
def shrink_shp_file():
  shp_file = retrieve_shp_file(TMP_FOLDER)

  source_file = Path(TMP_FOLDER, shp_file)
  destination_file = Path(TMP_FOLDER, f"{shp_file.replace('.shp', '')}-shrunk.shp")
  
  shrink = subprocess.run(["mapshaper", 
                           str(source_file), 
                           "-simplify", 
                           "5%", "-o", 
                           str(destination_file)])
  return destination_file

# %%
def dissolve_and_reset(gdf):
  gdf = gdf.copy()

  dissolve_col = [col for col in projected_gdf.columns if col not in ['index', 'name', 'geometry']][0]

  gdf = gdf.dissolve(["name", dissolve_col])
  gdf = gdf.reset_index()

  return gdf

# %%
def read_progress(path):
  try: 
    with open(path) as f:
      content = f.readline()
      return int(content)
  except FileNotFoundError:
    write_progress(path, '0')
    return 0

# %%
def write_progress(path, progress):
  with open(path, 'w') as f:
    f.write(progress)

# %%
def map_to_city(path_to_dir, dir):
  delete_zip_folder()

  print(f"Merging {dir}...")
  path = Path(path_to_dir, dir)

  zip_files = [file for file in os.listdir(path) if ".zip" in file]
  
  progress_var_path = Path(VAR_HOLDER, f"{dir}-progress.txt")

  progress = read_progress(progress_var_path)

  if len(zip_files)!=1:
    if progress == len(zip_files)-1:
      print("This directory has been merged!")
      return None

  for i in np.arange(progress, len(zip_files)): 

    zip_path = Path(path, zip_files[i])

    print(f"Progress: {i+1}/{len(zip_files)}")

    print(f"Unzipping {zip_files[i]}...")

    unzip_path(zip_path)

    print(f"Compressing {zip_files[i]}...")

    destination_path = shrink_shp_file()

    print(f"Reading compressed version of {zip_files[i]}...")

    gdf = gp.read_file(destination_path)

    if i == 0:
      print(f"Mapping to cities: {zip_files[i]}...")
      projected_df = gp.overlay(df, gdf, how="intersection").reset_index()
    else:
      print(f"Mapping to cities: {zip_files[i]}...")
      tmp_projected_df = gp.overlay(df, gdf, how="intersection").reset_index()
      
      print(f"Reading existing projected geodataframe...")
      projected_df = gp.read_parquet(Path(DATASETS_DIR, f"{dir}-projected.parquet"))
      projected_df = pd.concat([projected_df, tmp_projected_df])

    print(f"Dropping duplicates from output dataframe...")
    projected_df.drop_duplicates(inplace=True)

    print(f"Persisting output dataframe...")
    projected_df.to_parquet(Path(DATASETS_DIR, f"{dir}-projected.parquet"))

    print(f"Deleting {zip_files[i]} artifacts...")
    delete_zip_folder()
    print("========")

    write_progress(Path(VAR_HOLDER, f"{dir}-progress.txt"), str(i))

# %% [markdown]
# ### Import ph-cities-shpfile

# %%
df = gp.read_file(CITY_SHPFILE)
df.head()
# Out:
#          psgc          name    city_munic            province  \
# 0  1705301000       Aborlan       Aborlan             Palawan
# 1  1705101000  Abra De Ilog  Abra De Ilog  Occidental Mindoro
# 2   300801000        Abucay        Abucay              Bataan
# 3   201501000        Abulug        Abulug             Cagayan
# 4   803701000        Abuyog        Abuyog               Leyte
#
#                        clean_idx   longitude   latitude  \
# 0               aborlan, palawan  118.548417   9.437101
# 1  abradeilog, occidentalmindoro  120.726826  13.443721
# 2                 abucay, bataan  120.534870  14.721315
# 3                abulug, cagayan  121.457273  18.443485
# 4                  abuyog, leyte  125.011485  10.747102
#
#                     coords                                           geometry
# 0   9.4371009, 118.5484168  MULTIPOLYGON (((118.57998 9.37215, 118.57982 9...
# 1  13.4437209, 120.7268262  POLYGON ((120.60896 13.35233, 120.60797 13.373...
# 2  14.7213146, 120.5348704  POLYGON ((120.45676 14.69671, 120.45620 14.696...
# 3  18.4434854, 121.4572732  MULTIPOLYGON (((121.40276 18.40896, 121.40276 ...
# 4   10.747102, 125.0114853  POLYGON ((125.04650 10.56751, 125.04588 10.576...

# %%
keep_cols = ["name", "geometry"]
df = df[keep_cols]

# %% [markdown]
# ### Storm Surge

# %%
# PATH_TO_STORMSURGE_DIR = Path(CALAMITY_SHPFILE_DIR, "Storm Surge")

# %% [markdown]
# ------

# %%
# dir = "StormSurgeAdvisory1"

# %%
# map_to_city(PATH_TO_STORMSURGE_DIR, dir)

# %%
# projected_gdf = gp.read_parquet(Path(DATASETS_DIR, f"{dir}-projected.parquet"))

# %%
# projected_gdf = dissolve_and_reset(projected_gdf)

# %%
# projected_gdf.to_parquet(Path(DATASETS_DIR, f"{dir}-projected.parquet"))

# %% [markdown]
# ------

# %%
# dir = "StormSurgeAdvisory2"

# %%
# map_to_city(PATH_TO_STORMSURGE_DIR, dir)

# %%
# projected_gdf = gp.read_parquet(Path(DATASETS_DIR, f"{dir}-projected.parquet"))

# %%
# projected_gdf = dissolve_and_reset(projected_gdf)

# %%
# projected_gdf.to_parquet(Path(DATASETS_DIR, f"{dir}-projected.parquet"))

# %% [markdown]
# ------

# %%
# dir = "StormSurgeAdvisory3"

# %%
# map_to_city(PATH_TO_STORMSURGE_DIR, dir)

# %%
# projected_gdf = gp.read_parquet(Path(DATASETS_DIR, f"{dir}-projected.parquet"))

# %%
# projected_gdf = dissolve_and_reset(projected_gdf)

# %%
# projected_gdf.to_parquet(Path(DATASETS_DIR, f"{dir}-projected.parquet"))

# %% [markdown]
# ------

# %%
# dir = "StormSurgeAdvisory4"

# %%
# map_to_city(PATH_TO_STORMSURGE_DIR, dir)

# %%
# projected_gdf = gp.read_parquet(Path(DATASETS_DIR, f"{dir}-projected.parquet"))

# %%
# projected_gdf = dissolve_and_reset(projected_gdf)

# %%
# projected_gdf.to_parquet(Path(DATASETS_DIR, f"{dir}-projected.parquet"))

# %% [markdown]
# ### Flood

# %%
PATH_TO_FLOOD_DIR = Path(CALAMITY_SHPFILE_DIR, "Flood")

# %%
dir = "flood-100yr"

# %%
map_to_city(PATH_TO_FLOOD_DIR, dir)
# Out:
# Merging flood-100yr...
# Progress: 1/79
# Unzipping IlocosSur.zip...
# Compressing IlocosSur.zip...
# Reading compressed version of IlocosSur.zip...
# Mapping to cities: IlocosSur.zip...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting IlocosSur.zip artifacts...
# ========
# Progress: 2/79
# Unzipping IlocosNorte.zip...
# Compressing IlocosNorte.zip...
# Reading compressed version of IlocosNorte.zip...
# Mapping to cities: IlocosNorte.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting IlocosNorte.zip artifacts...
# ========
# Progress: 3/79
# Unzipping Isabela.zip...
# Compressing Isabela.zip...
# Reading compressed version of Isabela.zip...
# Mapping to cities: Isabela.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Isabela.zip artifacts...
# ========
# Progress: 4/79
# Unzipping NuevaVizcaya.zip...
# Compressing NuevaVizcaya.zip...
# Reading compressed version of NuevaVizcaya.zip...
# Mapping to cities: NuevaVizcaya.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting NuevaVizcaya.zip artifacts...
# ========
# Progress: 5/79
# Unzipping Pangasinan.zip...
# Compressing Pangasinan.zip...
# Reading compressed version of Pangasinan.zip...
# Mapping to cities: Pangasinan.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Pangasinan.zip artifacts...
# ========
# Progress: 6/79
# Unzipping LaUnion.zip...
# Compressing LaUnion.zip...
# Reading compressed version of LaUnion.zip...
# Mapping to cities: LaUnion.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting LaUnion.zip artifacts...
# ========
# Progress: 7/79
# Unzipping NuevaEcija.zip...
# Compressing NuevaEcija.zip...
# Reading compressed version of NuevaEcija.zip...
# Mapping to cities: NuevaEcija.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting NuevaEcija.zip artifacts...
# ========
# Progress: 8/79
# Unzipping Bulacan.zip...
# Compressing Bulacan.zip...
# Reading compressed version of Bulacan.zip...
# Mapping to cities: Bulacan.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Bulacan.zip artifacts...
# ========
# Progress: 9/79
# Unzipping Bataan.zip...
# Compressing Bataan.zip...
# Reading compressed version of Bataan.zip...
# Mapping to cities: Bataan.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Bataan.zip artifacts...
# ========
# Progress: 10/79
# Unzipping Quirino.zip...
# Compressing Quirino.zip...
# Reading compressed version of Quirino.zip...
# Mapping to cities: Quirino.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Quirino.zip artifacts...
# ========
# Progress: 11/79
# Unzipping Cagayan.zip...
# Compressing Cagayan.zip...
# Reading compressed version of Cagayan.zip...
# Mapping to cities: Cagayan.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Cagayan.zip artifacts...
# ========
# Progress: 12/79
# Unzipping Batanes.zip...
# Compressing Batanes.zip...
# Reading compressed version of Batanes.zip...
# Mapping to cities: Batanes.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Batanes.zip artifacts...
# ========
# Progress: 13/79
# Unzipping Aurora.zip...
# Compressing Aurora.zip...
# Reading compressed version of Aurora.zip...
# Mapping to cities: Aurora.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Aurora.zip artifacts...
# ========
# Progress: 14/79
# Unzipping Zambales.zip...
# Compressing Zambales.zip...
# Reading compressed version of Zambales.zip...
# Mapping to cities: Zambales.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Zambales.zip artifacts...
# ========
# Progress: 15/79
# Unzipping Pampanga.zip...
# Compressing Pampanga.zip...
# Reading compressed version of Pampanga.zip...
# Mapping to cities: Pampanga.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Pampanga.zip artifacts...
# ========
# Progress: 16/79
# Unzipping Cavite.zip...
# Compressing Cavite.zip...
# Reading compressed version of Cavite.zip...
# Mapping to cities: Cavite.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Cavite.zip artifacts...
# ========
# Progress: 17/79
# Unzipping Batangas.zip...
# Compressing Batangas.zip...
# Reading compressed version of Batangas.zip...
# Mapping to cities: Batangas.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Batangas.zip artifacts...
# ========
# Progress: 18/79
# Unzipping Tarlac.zip...
# Compressing Tarlac.zip...
# Reading compressed version of Tarlac.zip...
# Mapping to cities: Tarlac.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Tarlac.zip artifacts...
# ========
# Progress: 19/79
# Unzipping Laguna.zip...
# Compressing Laguna.zip...
# Reading compressed version of Laguna.zip...
# Mapping to cities: Laguna.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Laguna.zip artifacts...
# ========
# Progress: 20/79
# Unzipping Quezon.zip...
# Compressing Quezon.zip...
# Reading compressed version of Quezon.zip...
# Mapping to cities: Quezon.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Quezon.zip artifacts...
# ========
# Progress: 21/79
# Unzipping Rizal.zip...
# Compressing Rizal.zip...
# Reading compressed version of Rizal.zip...
# Mapping to cities: Rizal.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Rizal.zip artifacts...
# ========
# Progress: 22/79
# Unzipping Albay.zip...
# Compressing Albay.zip...
# Reading compressed version of Albay.zip...
# Mapping to cities: Albay.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Albay.zip artifacts...
# ========
# Progress: 23/79
# Unzipping CamarinesNorte.zip...
# Compressing CamarinesNorte.zip...
# Reading compressed version of CamarinesNorte.zip...
# Mapping to cities: CamarinesNorte.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting CamarinesNorte.zip artifacts...
# ========
# Progress: 24/79
# Unzipping CamarinesSur.zip...
# Compressing CamarinesSur.zip...
# Reading compressed version of CamarinesSur.zip...
# Mapping to cities: CamarinesSur.zip...
# <ipython-input-29-80515b1f0f22>:41: UserWarning: `keep_geom_type=True` in overlay resulted in 14483 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries
#   tmp_projected_df = gp.overlay(df, gdf, how="intersection").reset_index()
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting CamarinesSur.zip artifacts...
# ========
# Progress: 25/79
# Unzipping Catanduanes.zip...
# Compressing Catanduanes.zip...
# Reading compressed version of Catanduanes.zip...
# Mapping to cities: Catanduanes.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Catanduanes.zip artifacts...
# ========
# Progress: 26/79
# Unzipping Sorsogon.zip...
# Compressing Sorsogon.zip...
# Reading compressed version of Sorsogon.zip...
# Mapping to cities: Sorsogon.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Sorsogon.zip artifacts...
# ========
# Progress: 27/79
# Unzipping Aklan.zip...
# Compressing Aklan.zip...
# Reading compressed version of Aklan.zip...
# Mapping to cities: Aklan.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Aklan.zip artifacts...
# ========
# Progress: 28/79
# Unzipping Masbate.zip...
# Compressing Masbate.zip...
# Reading compressed version of Masbate.zip...
# Mapping to cities: Masbate.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Masbate.zip artifacts...
# ========
# Progress: 29/79
# Unzipping Capiz.zip...
# Compressing Capiz.zip...
# Reading compressed version of Capiz.zip...
# Mapping to cities: Capiz.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Capiz.zip artifacts...
# ========
# Progress: 30/79
# Unzipping Antique.zip...
# Compressing Antique.zip...
# Reading compressed version of Antique.zip...
# Mapping to cities: Antique.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Antique.zip artifacts...
# ========
# Progress: 31/79
# Unzipping Iloilo.zip...
# Compressing Iloilo.zip...
# Reading compressed version of Iloilo.zip...
# Mapping to cities: Iloilo.zip...
# <ipython-input-29-80515b1f0f22>:41: UserWarning: `keep_geom_type=True` in overlay resulted in 7126 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries
#   tmp_projected_df = gp.overlay(df, gdf, how="intersection").reset_index()
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Iloilo.zip artifacts...
# ========
# Progress: 32/79
# Unzipping Bohol.zip...
# Compressing Bohol.zip...
# Reading compressed version of Bohol.zip...
# Mapping to cities: Bohol.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Bohol.zip artifacts...
# ========
# Progress: 33/79
# Unzipping Cebu.zip...
# Compressing Cebu.zip...
# Reading compressed version of Cebu.zip...
# Mapping to cities: Cebu.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Cebu.zip artifacts...
# ========
# Progress: 34/79
# Unzipping EasternSamar.zip...
# Compressing EasternSamar.zip...
# Reading compressed version of EasternSamar.zip...
# Mapping to cities: EasternSamar.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting EasternSamar.zip artifacts...
# ========
# Progress: 35/79
# Unzipping Leyte.zip...
# Compressing Leyte.zip...
# Reading compressed version of Leyte.zip...
# Mapping to cities: Leyte.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Leyte.zip artifacts...
# ========
# Progress: 36/79
# Unzipping NorthernSamar.zip...
# Compressing NorthernSamar.zip...
# Reading compressed version of NorthernSamar.zip...
# Mapping to cities: NorthernSamar.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting NorthernSamar.zip artifacts...
# ========
# Progress: 37/79
# Unzipping Samar.zip...
# Compressing Samar.zip...
# Reading compressed version of Samar.zip...
# Mapping to cities: Samar.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Samar.zip artifacts...
# ========
# Progress: 38/79
# Unzipping SouthernLeyte.zip...
# Compressing SouthernLeyte.zip...
# Reading compressed version of SouthernLeyte.zip...
# Mapping to cities: SouthernLeyte.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting SouthernLeyte.zip artifacts...
# ========
# Progress: 39/79
# Unzipping Biliran.zip...
# Compressing Biliran.zip...
# Reading compressed version of Biliran.zip...
# Mapping to cities: Biliran.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Biliran.zip artifacts...
# ========
# Progress: 40/79
# Unzipping ZamboangaDelNorte.zip...
# Compressing ZamboangaDelNorte.zip...
# Reading compressed version of ZamboangaDelNorte.zip...
# Mapping to cities: ZamboangaDelNorte.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting ZamboangaDelNorte.zip artifacts...
# ========
# Progress: 41/79
# Unzipping ZamboangaDelSur.zip...
# Compressing ZamboangaDelSur.zip...
# Reading compressed version of ZamboangaDelSur.zip...
# Mapping to cities: ZamboangaDelSur.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting ZamboangaDelSur.zip artifacts...
# ========
# Progress: 42/79
# Unzipping ZamboangaSibugay.zip...
# Compressing ZamboangaSibugay.zip...
# Reading compressed version of ZamboangaSibugay.zip...
# Mapping to cities: ZamboangaSibugay.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting ZamboangaSibugay.zip artifacts...
# ========
# Progress: 43/79
# Unzipping Bukidnon.zip...
# Compressing Bukidnon.zip...
# Reading compressed version of Bukidnon.zip...
# Mapping to cities: Bukidnon.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Bukidnon.zip artifacts...
# ========
# Progress: 44/79
# Unzipping MisamisOccidental.zip...
# Compressing MisamisOccidental.zip...
# Reading compressed version of MisamisOccidental.zip...
# Mapping to cities: MisamisOccidental.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting MisamisOccidental.zip artifacts...
# ========
# Progress: 45/79
# Unzipping LanaoDelNorte.zip...
# Compressing LanaoDelNorte.zip...
# Reading compressed version of LanaoDelNorte.zip...
# Mapping to cities: LanaoDelNorte.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting LanaoDelNorte.zip artifacts...
# ========
# Progress: 46/79
# Unzipping Camiguin.zip...
# Compressing Camiguin.zip...
# Reading compressed version of Camiguin.zip...
# Mapping to cities: Camiguin.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Camiguin.zip artifacts...
# ========
# Progress: 47/79
# Unzipping DavaoDelNorte.zip...
# Compressing DavaoDelNorte.zip...
# Reading compressed version of DavaoDelNorte.zip...
# Mapping to cities: DavaoDelNorte.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting DavaoDelNorte.zip artifacts...
# ========
# Progress: 48/79
# Unzipping DavaoDelSur.zip...
# Compressing DavaoDelSur.zip...
# Reading compressed version of DavaoDelSur.zip...
# Mapping to cities: DavaoDelSur.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting DavaoDelSur.zip artifacts...
# ========
# Progress: 49/79
# Unzipping MisamisOriental.zip...
# Compressing MisamisOriental.zip...
# Reading compressed version of MisamisOriental.zip...
# Mapping to cities: MisamisOriental.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting MisamisOriental.zip artifacts...
# ========
# Progress: 50/79
# Unzipping DavaoOriental.zip...
# Compressing DavaoOriental.zip...
# Reading compressed version of DavaoOriental.zip...
# Mapping to cities: DavaoOriental.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting DavaoOriental.zip artifacts...
# ========
# Progress: 51/79
# Unzipping Cotabato.zip...
# Compressing Cotabato.zip...
# Reading compressed version of Cotabato.zip...
# Mapping to cities: Cotabato.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Cotabato.zip artifacts...
# ========
# Progress: 52/79
# Unzipping DavaoOccidental.zip...
# Compressing DavaoOccidental.zip...
# Reading compressed version of DavaoOccidental.zip...
# Mapping to cities: DavaoOccidental.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting DavaoOccidental.zip artifacts...
# ========
# Progress: 53/79
# Unzipping SouthCotabato.zip...
# Compressing SouthCotabato.zip...
# Reading compressed version of SouthCotabato.zip...
# Mapping to cities: SouthCotabato.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting SouthCotabato.zip artifacts...
# ========
# Progress: 54/79
# Unzipping CompostelaValley.zip...
# Compressing CompostelaValley.zip...
# Reading compressed version of CompostelaValley.zip...
# Mapping to cities: CompostelaValley.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting CompostelaValley.zip artifacts...
# ========
# Progress: 55/79
# Unzipping Sarangani.zip...
# Compressing Sarangani.zip...
# Reading compressed version of Sarangani.zip...
# Mapping to cities: Sarangani.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Sarangani.zip artifacts...
# ========
# Progress: 56/79
# Unzipping MetroManila.zip...
# Compressing MetroManila.zip...
# Reading compressed version of MetroManila.zip...
# Mapping to cities: MetroManila.zip...
# Reading existing projected geodataframe...
# <ipython-input-29-80515b1f0f22>:41: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:4326
# Right CRS: EPSG:32651
#
#   tmp_projected_df = gp.overlay(df, gdf, how="intersection").reset_index()
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting MetroManila.zip artifacts...
# ========
# Progress: 57/79
# Unzipping SultanKudarat.zip...
# Compressing SultanKudarat.zip...
# Reading compressed version of SultanKudarat.zip...
# Mapping to cities: SultanKudarat.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting SultanKudarat.zip artifacts...
# ========
# Progress: 58/79
# Unzipping MountainProvince.zip...
# Compressing MountainProvince.zip...
# Reading compressed version of MountainProvince.zip...
# Mapping to cities: MountainProvince.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting MountainProvince.zip artifacts...
# ========
# Progress: 59/79
# Unzipping Ifugao.zip...
# Compressing Ifugao.zip...
# Reading compressed version of Ifugao.zip...
# Mapping to cities: Ifugao.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Ifugao.zip artifacts...
# ========
# Progress: 60/79
# Unzipping Kalinga.zip...
# Compressing Kalinga.zip...
# Reading compressed version of Kalinga.zip...
# Mapping to cities: Kalinga.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Kalinga.zip artifacts...
# ========
# Progress: 61/79
# Unzipping Abra.zip...
# Compressing Abra.zip...
# Reading compressed version of Abra.zip...
# Mapping to cities: Abra.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Abra.zip artifacts...
# ========
# Progress: 62/79
# Unzipping Basilan.zip...
# Compressing Basilan.zip...
# Reading compressed version of Basilan.zip...
# Mapping to cities: Basilan.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Basilan.zip artifacts...
# ========
# Progress: 63/79
# Unzipping Apayao.zip...
# Compressing Apayao.zip...
# Reading compressed version of Apayao.zip...
# Mapping to cities: Apayao.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Apayao.zip artifacts...
# ========
# Progress: 64/79
# Unzipping Benguet.zip...
# Compressing Benguet.zip...
# Reading compressed version of Benguet.zip...
# Mapping to cities: Benguet.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Benguet.zip artifacts...
# ========
# Progress: 65/79
# Unzipping LanaoDelSur.zip...
# Compressing LanaoDelSur.zip...
# Reading compressed version of LanaoDelSur.zip...
# Mapping to cities: LanaoDelSur.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting LanaoDelSur.zip artifacts...
# ========
# Progress: 66/79
# Unzipping Maguindanao.zip...
# Compressing Maguindanao.zip...
# Reading compressed version of Maguindanao.zip...
# Mapping to cities: Maguindanao.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Maguindanao.zip artifacts...
# ========
# Progress: 67/79
# Unzipping TawiTawi.zip...
# Compressing TawiTawi.zip...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-33-903457967e92> in <module>
# ----> 1 map_to_city(PATH_TO_FLOOD_DIR, dir)
#
# <ipython-input-29-80515b1f0f22> in map_to_city(path_to_dir, dir)
#      28     print(f"Compressing {zip_files[i]}...")
#      29
# ---> 30     destination_path = shrink_shp_file()
#      31
#      32     print(f"Reading compressed version of {zip_files[i]}...")
#
# <ipython-input-25-3a1f3aaabb8c> in shrink_shp_file()
#       1 def shrink_shp_file():
# ----> 2   shp_file = retrieve_shp_file(TMP_FOLDER)
#       3
#       4   source_file = Path(TMP_FOLDER, shp_file)
#       5   destination_file = Path(TMP_FOLDER, f"{shp_file.replace('.shp', '')}-shrunk.shp")
#
# <ipython-input-24-df9b131568fe> in retrieve_shp_file(path)
#       1 def retrieve_shp_file(path):
#       2   files = os.listdir(path)
# ----> 3   shp = [file for file in files if ".shp" in file][0]
#       4   return shp
#
# IndexError: list index out of range

# %%
projected_gdf = gp.read_parquet(Path(DATASETS_DIR, f"{dir}-projected.parquet"))

# %%
projected_gdf = dissolve_and_reset(projected_gdf)

# %%
projected_gdf.to_parquet(Path(DATASETS_DIR, f"{dir}-projected.parquet"))

# %% [markdown]
# --------

# %%
dir = "flood-25yr"

# %%
map_to_city(PATH_TO_FLOOD_DIR, dir)
# Out:
# Merging flood-25yr...
# Progress: 1/71
# Unzipping LaUnion.zip...
# Compressing LaUnion.zip...
# Reading compressed version of LaUnion.zip...
# Mapping to cities: LaUnion.zip...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting LaUnion.zip artifacts...
# ========
# Progress: 2/71
# Unzipping IlocosNorte.zip...
# Compressing IlocosNorte.zip...
# Reading compressed version of IlocosNorte.zip...
# Mapping to cities: IlocosNorte.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting IlocosNorte.zip artifacts...
# ========
# Progress: 3/71
# Unzipping IlocosSur.zip...
# Compressing IlocosSur.zip...
# Reading compressed version of IlocosSur.zip...
# Mapping to cities: IlocosSur.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting IlocosSur.zip artifacts...
# ========
# Progress: 4/71
# Unzipping Pangasinan.zip...
# Compressing Pangasinan.zip...
# Reading compressed version of Pangasinan.zip...
# Mapping to cities: Pangasinan.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Pangasinan.zip artifacts...
# ========
# Progress: 5/71
# Unzipping Cagayan.zip...
# Compressing Cagayan.zip...
# Reading compressed version of Cagayan.zip...
# Mapping to cities: Cagayan.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Cagayan.zip artifacts...
# ========
# Progress: 6/71
# Unzipping Quirino.zip...
# Compressing Quirino.zip...
# Reading compressed version of Quirino.zip...
# Mapping to cities: Quirino.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Quirino.zip artifacts...
# ========
# Progress: 7/71
# Unzipping NuevaVizcaya.zip...
# Compressing NuevaVizcaya.zip...
# Reading compressed version of NuevaVizcaya.zip...
# Mapping to cities: NuevaVizcaya.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting NuevaVizcaya.zip artifacts...
# ========
# Progress: 8/71
# Unzipping Isabela.zip...
# Compressing Isabela.zip...
# Reading compressed version of Isabela.zip...
# Mapping to cities: Isabela.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Isabela.zip artifacts...
# ========
# Progress: 9/71
# Unzipping Bataan.zip...
# Compressing Bataan.zip...
# Reading compressed version of Bataan.zip...
# Mapping to cities: Bataan.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Bataan.zip artifacts...
# ========
# Progress: 10/71
# Unzipping Bulacan.zip...
# Compressing Bulacan.zip...
# Reading compressed version of Bulacan.zip...
# Mapping to cities: Bulacan.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Bulacan.zip artifacts...
# ========
# Progress: 11/71
# Unzipping NuevaEcija.zip...
# Compressing NuevaEcija.zip...
# Reading compressed version of NuevaEcija.zip...
# Mapping to cities: NuevaEcija.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting NuevaEcija.zip artifacts...
# ========
# Progress: 12/71
# Unzipping Aurora.zip...
# Compressing Aurora.zip...
# Reading compressed version of Aurora.zip...
# Mapping to cities: Aurora.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Aurora.zip artifacts...
# ========
# Progress: 13/71
# Unzipping Tarlac.zip...
# Compressing Tarlac.zip...
# Reading compressed version of Tarlac.zip...
# Mapping to cities: Tarlac.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Tarlac.zip artifacts...
# ========
# Progress: 14/71
# Unzipping Pampanga.zip...
# Compressing Pampanga.zip...
# Reading compressed version of Pampanga.zip...
# Mapping to cities: Pampanga.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Pampanga.zip artifacts...
# ========
# Progress: 15/71
# Unzipping Zambales.zip...
# Compressing Zambales.zip...
# Reading compressed version of Zambales.zip...
# Mapping to cities: Zambales.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Zambales.zip artifacts...
# ========
# Progress: 16/71
# Unzipping Laguna.zip...
# Compressing Laguna.zip...
# Reading compressed version of Laguna.zip...
# Mapping to cities: Laguna.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Laguna.zip artifacts...
# ========
# Progress: 17/71
# Unzipping Batangas.zip...
# Compressing Batangas.zip...
# Reading compressed version of Batangas.zip...
# Mapping to cities: Batangas.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Batangas.zip artifacts...
# ========
# Progress: 18/71
# Unzipping Cavite.zip...
# Compressing Cavite.zip...
# Reading compressed version of Cavite.zip...
# Mapping to cities: Cavite.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Cavite.zip artifacts...
# ========
# Progress: 19/71
# Unzipping Albay.zip...
# Compressing Albay.zip...
# Reading compressed version of Albay.zip...
# Mapping to cities: Albay.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Albay.zip artifacts...
# ========
# Progress: 20/71
# Unzipping Rizal.zip...
# Compressing Rizal.zip...
# Reading compressed version of Rizal.zip...
# Mapping to cities: Rizal.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Rizal.zip artifacts...
# ========
# Progress: 21/71
# Unzipping Quezon.zip...
# Compressing Quezon.zip...
# Reading compressed version of Quezon.zip...
# Mapping to cities: Quezon.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Quezon.zip artifacts...
# ========
# Progress: 22/71
# Unzipping CamarinesNorte.zip...
# Compressing CamarinesNorte.zip...
# Reading compressed version of CamarinesNorte.zip...
# Mapping to cities: CamarinesNorte.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting CamarinesNorte.zip artifacts...
# ========
# Progress: 23/71
# Unzipping CamarinesSur.zip...
# Compressing CamarinesSur.zip...
# Reading compressed version of CamarinesSur.zip...
# Mapping to cities: CamarinesSur.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting CamarinesSur.zip artifacts...
# ========
# Progress: 24/71
# Unzipping Masbate.zip...
# Compressing Masbate.zip...
# Reading compressed version of Masbate.zip...
# Mapping to cities: Masbate.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Masbate.zip artifacts...
# ========
# Progress: 25/71
# Unzipping Catanduanes.zip...
# Compressing Catanduanes.zip...
# Reading compressed version of Catanduanes.zip...
# Mapping to cities: Catanduanes.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Catanduanes.zip artifacts...
# ========
# Progress: 26/71
# Unzipping Capiz.zip...
# Compressing Capiz.zip...
# Reading compressed version of Capiz.zip...
# Mapping to cities: Capiz.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Capiz.zip artifacts...
# ========
# Progress: 27/71
# Unzipping Aklan.zip...
# Compressing Aklan.zip...
# Reading compressed version of Aklan.zip...
# Mapping to cities: Aklan.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Aklan.zip artifacts...
# ========
# Progress: 28/71
# Unzipping Sorsogon.zip...
# Compressing Sorsogon.zip...
# Reading compressed version of Sorsogon.zip...
# Mapping to cities: Sorsogon.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Sorsogon.zip artifacts...
# ========
# Progress: 29/71
# Unzipping Antique.zip...
# Compressing Antique.zip...
# Reading compressed version of Antique.zip...
# Mapping to cities: Antique.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Antique.zip artifacts...
# ========
# Progress: 30/71
# Unzipping Bohol.zip...
# Compressing Bohol.zip...
# Reading compressed version of Bohol.zip...
# Mapping to cities: Bohol.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Bohol.zip artifacts...
# ========
# Progress: 31/71
# Unzipping Cebu.zip...
# Compressing Cebu.zip...
# Reading compressed version of Cebu.zip...
# Mapping to cities: Cebu.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Cebu.zip artifacts...
# ========
# Progress: 32/71
# Unzipping Iloilo.zip...
# Compressing Iloilo.zip...
# Reading compressed version of Iloilo.zip...
# Mapping to cities: Iloilo.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Iloilo.zip artifacts...
# ========
# Progress: 33/71
# Unzipping EasternSamar.zip...
# Compressing EasternSamar.zip...
# Reading compressed version of EasternSamar.zip...
# Mapping to cities: EasternSamar.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting EasternSamar.zip artifacts...
# ========
# Progress: 34/71
# Unzipping Samar.zip...
# Compressing Samar.zip...
# Reading compressed version of Samar.zip...
# Mapping to cities: Samar.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Samar.zip artifacts...
# ========
# Progress: 35/71
# Unzipping SouthernLeyte.zip...
# Compressing SouthernLeyte.zip...
# Reading compressed version of SouthernLeyte.zip...
# Mapping to cities: SouthernLeyte.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting SouthernLeyte.zip artifacts...
# ========
# Progress: 36/71
# Unzipping Leyte.zip...
# Compressing Leyte.zip...
# Reading compressed version of Leyte.zip...
# Mapping to cities: Leyte.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Leyte.zip artifacts...
# ========
# Progress: 37/71
# Unzipping ZamboangaSibugay.zip...
# Compressing ZamboangaSibugay.zip...
# Reading compressed version of ZamboangaSibugay.zip...
# Mapping to cities: ZamboangaSibugay.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting ZamboangaSibugay.zip artifacts...
# ========
# Progress: 38/71
# Unzipping ZamboangaDelNorte.zip...
# Compressing ZamboangaDelNorte.zip...
# Reading compressed version of ZamboangaDelNorte.zip...
# Mapping to cities: ZamboangaDelNorte.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting ZamboangaDelNorte.zip artifacts...
# ========
# Progress: 39/71
# Unzipping Bukidnon.zip...
# Compressing Bukidnon.zip...
# Reading compressed version of Bukidnon.zip...
# Mapping to cities: Bukidnon.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Bukidnon.zip artifacts...
# ========
# Progress: 40/71
# Unzipping LanaoDelNorte.zip...
# Compressing LanaoDelNorte.zip...
# Reading compressed version of LanaoDelNorte.zip...
# Mapping to cities: LanaoDelNorte.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting LanaoDelNorte.zip artifacts...
# ========
# Progress: 41/71
# Unzipping ZamboangaDelSur.zip...
# Compressing ZamboangaDelSur.zip...
# Reading compressed version of ZamboangaDelSur.zip...
# Mapping to cities: ZamboangaDelSur.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting ZamboangaDelSur.zip artifacts...
# ========
# Progress: 42/71
# Unzipping MisamisOccidental.zip...
# Compressing MisamisOccidental.zip...
# Reading compressed version of MisamisOccidental.zip...
# Mapping to cities: MisamisOccidental.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting MisamisOccidental.zip artifacts...
# ========
# Progress: 43/71
# Unzipping MisamisOriental.zip...
# Compressing MisamisOriental.zip...
# Reading compressed version of MisamisOriental.zip...
# Mapping to cities: MisamisOriental.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting MisamisOriental.zip artifacts...
# ========
# Progress: 44/71
# Unzipping DavaoDelNorte.zip...
# Compressing DavaoDelNorte.zip...
# Reading compressed version of DavaoDelNorte.zip...
# Mapping to cities: DavaoDelNorte.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting DavaoDelNorte.zip artifacts...
# ========
# Progress: 45/71
# Unzipping DavaoDelSur.zip...
# Compressing DavaoDelSur.zip...
# Reading compressed version of DavaoDelSur.zip...
# Mapping to cities: DavaoDelSur.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting DavaoDelSur.zip artifacts...
# ========
# Progress: 46/71
# Unzipping Cotabato.zip...
# Compressing Cotabato.zip...
# Reading compressed version of Cotabato.zip...
# Mapping to cities: Cotabato.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Cotabato.zip artifacts...
# ========
# Progress: 47/71
# Unzipping DavaoOriental.zip...
# Compressing DavaoOriental.zip...
# Reading compressed version of DavaoOriental.zip...
# Mapping to cities: DavaoOriental.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting DavaoOriental.zip artifacts...
# ========
# Progress: 48/71
# Unzipping CompostelaValley.zip...
# Compressing CompostelaValley.zip...
# Reading compressed version of CompostelaValley.zip...
# Mapping to cities: CompostelaValley.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting CompostelaValley.zip artifacts...
# ========
# Progress: 49/71
# Unzipping SouthCotabato.zip...
# Compressing SouthCotabato.zip...
# Reading compressed version of SouthCotabato.zip...
# Mapping to cities: SouthCotabato.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting SouthCotabato.zip artifacts...
# ========
# Progress: 50/71
# Unzipping Sarangani.zip...
# Compressing Sarangani.zip...
# Reading compressed version of Sarangani.zip...
# Mapping to cities: Sarangani.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Sarangani.zip artifacts...
# ========
# Progress: 51/71
# Unzipping SultanKudarat.zip...
# Compressing SultanKudarat.zip...
# Reading compressed version of SultanKudarat.zip...
# Mapping to cities: SultanKudarat.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting SultanKudarat.zip artifacts...
# ========
# Progress: 52/71
# Unzipping MetroManila.zip...
# Compressing MetroManila.zip...
# Reading compressed version of MetroManila.zip...
# Mapping to cities: MetroManila.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting MetroManila.zip artifacts...
# ========
# Progress: 53/71
# Unzipping Abra.zip...
# Compressing Abra.zip...
# Reading compressed version of Abra.zip...
# Mapping to cities: Abra.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Abra.zip artifacts...
# ========
# Progress: 54/71
# Unzipping Apayao.zip...
# Compressing Apayao.zip...
# Reading compressed version of Apayao.zip...
# Mapping to cities: Apayao.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Apayao.zip artifacts...
# ========
# Progress: 55/71
# Unzipping Benguet.zip...
# Compressing Benguet.zip...
# Reading compressed version of Benguet.zip...
# Mapping to cities: Benguet.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Benguet.zip artifacts...
# ========
# Progress: 56/71
# Unzipping Ifugao.zip...
# Compressing Ifugao.zip...
# Reading compressed version of Ifugao.zip...
# Mapping to cities: Ifugao.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Ifugao.zip artifacts...
# ========
# Progress: 57/71
# Unzipping MountainProvince.zip...
# Compressing MountainProvince.zip...
# Reading compressed version of MountainProvince.zip...
# Mapping to cities: MountainProvince.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting MountainProvince.zip artifacts...
# ========
# Progress: 58/71
# Unzipping LanaoDelSur.zip...
# Compressing LanaoDelSur.zip...
# Reading compressed version of LanaoDelSur.zip...
# Mapping to cities: LanaoDelSur.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting LanaoDelSur.zip artifacts...
# ========
# Progress: 59/71
# Unzipping Kalinga.zip...
# Compressing Kalinga.zip...
# Reading compressed version of Kalinga.zip...
# Mapping to cities: Kalinga.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Kalinga.zip artifacts...
# ========
# Progress: 60/71
# Unzipping Maguindanao.zip...
# Compressing Maguindanao.zip...
# Reading compressed version of Maguindanao.zip...
# Mapping to cities: Maguindanao.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Maguindanao.zip artifacts...
# ========
# Progress: 61/71
# Unzipping SurigaoDelSur.zip...
# Compressing SurigaoDelSur.zip...
# Reading compressed version of SurigaoDelSur.zip...
# Mapping to cities: SurigaoDelSur.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting SurigaoDelSur.zip artifacts...
# ========
# Progress: 62/71
# Unzipping AgusanDelSur.zip...
# Compressing AgusanDelSur.zip...
# Reading compressed version of AgusanDelSur.zip...
# Mapping to cities: AgusanDelSur.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting AgusanDelSur.zip artifacts...
# ========
# Progress: 63/71
# Unzipping AgusanDelNorte.zip...
# Compressing AgusanDelNorte.zip...
# Reading compressed version of AgusanDelNorte.zip...
# Mapping to cities: AgusanDelNorte.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting AgusanDelNorte.zip artifacts...
# ========
# Progress: 64/71
# Unzipping DinagatIslands.zip...
# Compressing DinagatIslands.zip...
# Reading compressed version of DinagatIslands.zip...
# Mapping to cities: DinagatIslands.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting DinagatIslands.zip artifacts...
# ========
# Progress: 65/71
# Unzipping SurigaoDelNorte.zip...
# Compressing SurigaoDelNorte.zip...
# Reading compressed version of SurigaoDelNorte.zip...
# Mapping to cities: SurigaoDelNorte.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting SurigaoDelNorte.zip artifacts...
# ========
# Progress: 66/71
# Unzipping OccidentalMindoro.zip...
# Compressing OccidentalMindoro.zip...
# Reading compressed version of OccidentalMindoro.zip...
# Mapping to cities: OccidentalMindoro.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting OccidentalMindoro.zip artifacts...
# ========
# Progress: 67/71
# Unzipping Marinduque.zip...
# Compressing Marinduque.zip...
# Reading compressed version of Marinduque.zip...
# Mapping to cities: Marinduque.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Marinduque.zip artifacts...
# ========
# Progress: 68/71
# Unzipping Palawan.zip...
# Compressing Palawan.zip...
# Reading compressed version of Palawan.zip...
# Mapping to cities: Palawan.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Palawan.zip artifacts...
# ========
# Progress: 69/71
# Unzipping OrientalMindoro.zip...
# Compressing OrientalMindoro.zip...
# Reading compressed version of OrientalMindoro.zip...
# Mapping to cities: OrientalMindoro.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting OrientalMindoro.zip artifacts...
# ========
# Progress: 70/71
# Unzipping NegrosOriental.zip...
# Compressing NegrosOriental.zip...
# Reading compressed version of NegrosOriental.zip...
# Mapping to cities: NegrosOriental.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting NegrosOriental.zip artifacts...
# ========
# Progress: 71/71
# Unzipping NegrosOccidental.zip...
# Compressing NegrosOccidental.zip...
# Reading compressed version of NegrosOccidental.zip...
# Mapping to cities: NegrosOccidental.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting NegrosOccidental.zip artifacts...
# ========

# %%
projected_gdf = gp.read_parquet(Path(DATASETS_DIR, f"{dir}-projected.parquet"))

# %%
projected_gdf = dissolve_and_reset(projected_gdf)

# %%
projected_gdf.to_parquet(Path(DATASETS_DIR, f"{dir}-projected.parquet"))

# %% [markdown]
# ------------

# %%
dir = "flood-5yr"

# %%
map_to_city(PATH_TO_FLOOD_DIR, dir)
# Out:
# Merging flood-5yr...
# Progress: 21/65
# Unzipping Rizal.zip...
# Compressing Rizal.zip...
# Reading compressed version of Rizal.zip...
# Mapping to cities: Rizal.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Rizal.zip artifacts...
# ========
# Progress: 22/65
# Unzipping Masbate.zip...
# Compressing Masbate.zip...
# Reading compressed version of Masbate.zip...
# Mapping to cities: Masbate.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Masbate.zip artifacts...
# ========
# Progress: 23/65
# Unzipping Sorsogon.zip...
# Compressing Sorsogon.zip...
# Reading compressed version of Sorsogon.zip...
# Mapping to cities: Sorsogon.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Sorsogon.zip artifacts...
# ========
# Progress: 24/65
# Unzipping CamarinesNorte.zip...
# Compressing CamarinesNorte.zip...
# Reading compressed version of CamarinesNorte.zip...
# Mapping to cities: CamarinesNorte.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting CamarinesNorte.zip artifacts...
# ========
# Progress: 25/65
# Unzipping Quezon.zip...
# Compressing Quezon.zip...
# Reading compressed version of Quezon.zip...
# Mapping to cities: Quezon.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Quezon.zip artifacts...
# ========
# Progress: 26/65
# Unzipping Iloilo.zip...
# Compressing Iloilo.zip...
# Reading compressed version of Iloilo.zip...
# Mapping to cities: Iloilo.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Iloilo.zip artifacts...
# ========
# Progress: 27/65
# Unzipping Capiz.zip...
# Compressing Capiz.zip...
# Reading compressed version of Capiz.zip...
# Mapping to cities: Capiz.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Capiz.zip artifacts...
# ========
# Progress: 28/65
# Unzipping Bohol.zip...
# Compressing Bohol.zip...
# Reading compressed version of Bohol.zip...
# Mapping to cities: Bohol.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Bohol.zip artifacts...
# ========
# Progress: 29/65
# Unzipping Cebu.zip...
# Compressing Cebu.zip...
# Reading compressed version of Cebu.zip...
# Mapping to cities: Cebu.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Cebu.zip artifacts...
# ========
# Progress: 30/65
# Unzipping EasternSamar.zip...
# Compressing EasternSamar.zip...
# Reading compressed version of EasternSamar.zip...
# Mapping to cities: EasternSamar.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting EasternSamar.zip artifacts...
# ========
# Progress: 31/65
# Unzipping Leyte.zip...
# Compressing Leyte.zip...
# Reading compressed version of Leyte.zip...
# Mapping to cities: Leyte.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Leyte.zip artifacts...
# ========
# Progress: 32/65
# Unzipping MisamisOccidental.zip...
# Compressing MisamisOccidental.zip...
# Reading compressed version of MisamisOccidental.zip...
# Mapping to cities: MisamisOccidental.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting MisamisOccidental.zip artifacts...
# ========
# Progress: 33/65
# Unzipping DavaoDelNorte.zip...
# Compressing DavaoDelNorte.zip...
# Reading compressed version of DavaoDelNorte.zip...
# Mapping to cities: DavaoDelNorte.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting DavaoDelNorte.zip artifacts...
# ========
# Progress: 34/65
# Unzipping ZamboangaDelSur.zip...
# Compressing ZamboangaDelSur.zip...
# Reading compressed version of ZamboangaDelSur.zip...
# Mapping to cities: ZamboangaDelSur.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting ZamboangaDelSur.zip artifacts...
# ========
# Progress: 35/65
# Unzipping ZamboangaSibugay.zip...
# Compressing ZamboangaSibugay.zip...
# Reading compressed version of ZamboangaSibugay.zip...
# Mapping to cities: ZamboangaSibugay.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting ZamboangaSibugay.zip artifacts...
# ========
# Progress: 36/65
# Unzipping Bukidnon.zip...
# Compressing Bukidnon.zip...
# Reading compressed version of Bukidnon.zip...
# Mapping to cities: Bukidnon.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Bukidnon.zip artifacts...
# ========
# Progress: 37/65
# Unzipping MisamisOriental.zip...
# Compressing MisamisOriental.zip...
# Reading compressed version of MisamisOriental.zip...
# Mapping to cities: MisamisOriental.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting MisamisOriental.zip artifacts...
# ========
# Progress: 38/65
# Unzipping ZamboangaDelNorte.zip...
# Compressing ZamboangaDelNorte.zip...
# Reading compressed version of ZamboangaDelNorte.zip...
# Mapping to cities: ZamboangaDelNorte.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting ZamboangaDelNorte.zip artifacts...
# ========
# Progress: 39/65
# Unzipping Samar.zip...
# Compressing Samar.zip...
# Reading compressed version of Samar.zip...
# Mapping to cities: Samar.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Samar.zip artifacts...
# ========
# Progress: 40/65
# Unzipping LanaoDelNorte.zip...
# Compressing LanaoDelNorte.zip...
# Reading compressed version of LanaoDelNorte.zip...
# Mapping to cities: LanaoDelNorte.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting LanaoDelNorte.zip artifacts...
# ========
# Progress: 41/65
# Unzipping SouthernLeyte.zip...
# Compressing SouthernLeyte.zip...
# Reading compressed version of SouthernLeyte.zip...
# Mapping to cities: SouthernLeyte.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting SouthernLeyte.zip artifacts...
# ========
# Progress: 42/65
# Unzipping SouthCotabato.zip...
# Compressing SouthCotabato.zip...
# Reading compressed version of SouthCotabato.zip...
# Mapping to cities: SouthCotabato.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting SouthCotabato.zip artifacts...
# ========
# Progress: 43/65
# Unzipping Cotabato.zip...
# Compressing Cotabato.zip...
# Reading compressed version of Cotabato.zip...
# Mapping to cities: Cotabato.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Cotabato.zip artifacts...
# ========
# Progress: 44/65
# Unzipping DavaoDelSur.zip...
# Compressing DavaoDelSur.zip...
# Reading compressed version of DavaoDelSur.zip...
# Mapping to cities: DavaoDelSur.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting DavaoDelSur.zip artifacts...
# ========
# Progress: 45/65
# Unzipping Sarangani.zip...
# Compressing Sarangani.zip...
# Reading compressed version of Sarangani.zip...
# Mapping to cities: Sarangani.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Sarangani.zip artifacts...
# ========
# Progress: 46/65
# Unzipping DavaoOriental.zip...
# Compressing DavaoOriental.zip...
# Reading compressed version of DavaoOriental.zip...
# Mapping to cities: DavaoOriental.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting DavaoOriental.zip artifacts...
# ========
# Progress: 47/65
# Unzipping CompostelaValley.zip...
# Compressing CompostelaValley.zip...
# Reading compressed version of CompostelaValley.zip...
# Mapping to cities: CompostelaValley.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting CompostelaValley.zip artifacts...
# ========
# Progress: 48/65
# Unzipping SultanKudarat.zip...
# Compressing SultanKudarat.zip...
# Reading compressed version of SultanKudarat.zip...
# Mapping to cities: SultanKudarat.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting SultanKudarat.zip artifacts...
# ========
# Progress: 49/65
# Unzipping MetroManila.zip...
# Compressing MetroManila.zip...
# Reading compressed version of MetroManila.zip...
# Mapping to cities: MetroManila.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting MetroManila.zip artifacts...
# ========
# Progress: 50/65
# Unzipping Apayao.zip...
# Compressing Apayao.zip...
# Reading compressed version of Apayao.zip...
# Mapping to cities: Apayao.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Apayao.zip artifacts...
# ========
# Progress: 51/65
# Unzipping Ifugao.zip...
# Compressing Ifugao.zip...
# Reading compressed version of Ifugao.zip...
# Mapping to cities: Ifugao.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Ifugao.zip artifacts...
# ========
# Progress: 52/65
# Unzipping Maguindanao.zip...
# Compressing Maguindanao.zip...
# Reading compressed version of Maguindanao.zip...
# Mapping to cities: Maguindanao.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Maguindanao.zip artifacts...
# ========
# Progress: 53/65
# Unzipping LanaoDelSur.zip...
# Compressing LanaoDelSur.zip...
# Reading compressed version of LanaoDelSur.zip...
# Mapping to cities: LanaoDelSur.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting LanaoDelSur.zip artifacts...
# ========
# Progress: 54/65
# Unzipping Kalinga.zip...
# Compressing Kalinga.zip...
# Reading compressed version of Kalinga.zip...
# Mapping to cities: Kalinga.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Kalinga.zip artifacts...
# ========
# Progress: 55/65
# Unzipping MountainProvince.zip...
# Compressing MountainProvince.zip...
# Reading compressed version of MountainProvince.zip...
# Mapping to cities: MountainProvince.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting MountainProvince.zip artifacts...
# ========
# Progress: 56/65
# Unzipping Benguet.zip...
# Compressing Benguet.zip...
# Reading compressed version of Benguet.zip...
# Mapping to cities: Benguet.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Benguet.zip artifacts...
# ========
# Progress: 57/65
# Unzipping SurigaoDelSur.zip...
# Compressing SurigaoDelSur.zip...
# Reading compressed version of SurigaoDelSur.zip...
# Mapping to cities: SurigaoDelSur.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting SurigaoDelSur.zip artifacts...
# ========
# Progress: 58/65
# Unzipping SurigaoDelNorte.zip...
# Compressing SurigaoDelNorte.zip...
# Reading compressed version of SurigaoDelNorte.zip...
# Mapping to cities: SurigaoDelNorte.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting SurigaoDelNorte.zip artifacts...
# ========
# Progress: 59/65
# Unzipping OrientalMindoro.zip...
# Compressing OrientalMindoro.zip...
# Reading compressed version of OrientalMindoro.zip...
# Mapping to cities: OrientalMindoro.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting OrientalMindoro.zip artifacts...
# ========
# Progress: 60/65
# Unzipping OccidentalMindoro.zip...
# Compressing OccidentalMindoro.zip...
# Reading compressed version of OccidentalMindoro.zip...
# Mapping to cities: OccidentalMindoro.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting OccidentalMindoro.zip artifacts...
# ========
# Progress: 61/65
# Unzipping Palawan.zip...
# Compressing Palawan.zip...
# Reading compressed version of Palawan.zip...
# Mapping to cities: Palawan.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Palawan.zip artifacts...
# ========
# Progress: 62/65
# Unzipping Marinduque.zip...
# Compressing Marinduque.zip...
# Reading compressed version of Marinduque.zip...
# Mapping to cities: Marinduque.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Marinduque.zip artifacts...
# ========
# Progress: 63/65
# Unzipping DinagatIslands.zip...
# Compressing DinagatIslands.zip...
# Reading compressed version of DinagatIslands.zip...
# Mapping to cities: DinagatIslands.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting DinagatIslands.zip artifacts...
# ========
# Progress: 64/65
# Unzipping NegrosOccidental.zip...
# Compressing NegrosOccidental.zip...
# Reading compressed version of NegrosOccidental.zip...
# Mapping to cities: NegrosOccidental.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting NegrosOccidental.zip artifacts...
# ========
# Progress: 65/65
# Unzipping NegrosOriental.zip...
# Compressing NegrosOriental.zip...
# Reading compressed version of NegrosOriental.zip...
# Mapping to cities: NegrosOriental.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting NegrosOriental.zip artifacts...
# ========

# %%
projected_gdf = gp.read_parquet(Path(DATASETS_DIR, f"{dir}-projected.parquet"))

# %%
projected_gdf = dissolve_and_reset(projected_gdf)

# %%
projected_gdf.to_parquet(Path(DATASETS_DIR, f"{dir}-projected.parquet"))

# %% [markdown]
# ------------

# %% [markdown]
# ### Landslide - Landslide Hazards

# %%
PATH_TO_DEBRIS_FLOW = Path(CALAMITY_SHPFILE_DIR, "Landslide")

# %%
dir = "LandslideHazards"

# %%
map_to_city(PATH_TO_DEBRIS_FLOW, dir)
# Out:
# Merging LandslideHazards...
# Progress: 5/82
# Unzipping Batanes.zip...
# Compressing Batanes.zip...
# Reading compressed version of Batanes.zip...
# Mapping to cities: Batanes.zip...
# Reading existing projected geodataframe...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Batanes.zip artifacts...
# ========
# Progress: 6/82
# Unzipping Isabela.zip...
# Compressing Isabela.zip...
# ERROR:fiona._env:/content/drive/MyDrive/Projects/philippines-chapter-urban-vunerability/noah_working/noah/tmp-folder/Isabela_LandslideHazards_IMWTG_Undissolved-shrunk.shp: No such file or directory
# Reading compressed version of Isabela.zip...
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: /content/drive/MyDrive/Projects/philippines-chapter-urban-vunerability/noah_working/noah/tmp-folder/Isabela_LandslideHazards_IMWTG_Undissolved-shrunk.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-18-7a7a20830151> in <module>
# ----> 1 map_to_city(PATH_TO_DEBRIS_FLOW, dir)
#
# <ipython-input-13-80515b1f0f22> in map_to_city(path_to_dir, dir)
#      32     print(f"Reading compressed version of {zip_files[i]}...")
#      33
# ---> 34     gdf = gp.read_file(destination_path)
#      35
#      36     if i == 0:
#
# /usr/local/lib/python3.8/dist-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     257
#     258     if engine == "fiona":
# --> 259         return _read_file_fiona(
#     260             path_or_bytes, from_bytes, bbox=bbox, mask=mask, rows=rows, **kwargs
#     261         )
#
# /usr/local/lib/python3.8/dist-packages/geopandas/io/file.py in _read_file_fiona(path_or_bytes, from_bytes, bbox, mask, rows, where, **kwargs)
#     301
#     302     with fiona_env():
# --> 303         with reader(path_or_bytes, **kwargs) as features:
#     304             crs = features.crs_wkt
#     305             # attempt to get EPSG code
#
# /usr/local/lib/python3.8/dist-packages/fiona/env.py in wrapper(*args, **kwargs)
#     406     def wrapper(*args, **kwargs):
#     407         if local._env:
# --> 408             return f(*args, **kwargs)
#     409         else:
#     410             if isinstance(args[0], str):
#
# /usr/local/lib/python3.8/dist-packages/fiona/__init__.py in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, **kwargs)
#     262
#     263         if mode in ('a', 'r'):
# --> 264             c = Collection(path, mode, driver=driver, encoding=encoding,
#     265                            layer=layer, enabled_drivers=enabled_drivers, **kwargs)
#     266         elif mode == 'w':
#
# /usr/local/lib/python3.8/dist-packages/fiona/collection.py in __init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, **kwargs)
#     160             if self.mode == 'r':
#     161                 self.session = Session()
# --> 162                 self.session.start(self, **kwargs)
#     163             elif self.mode in ('a', 'w'):
#     164                 self.session = WritingSession()
#
# fiona/ogrext.pyx in fiona.ogrext.Session.start()
#
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# DriverError: /content/drive/MyDrive/Projects/philippines-chapter-urban-vunerability/noah_working/noah/tmp-folder/Isabela_LandslideHazards_IMWTG_Undissolved-shrunk.shp: No such file or directory

# %%
projected_gdf = gp.read_parquet(Path(DATASETS_DIR, f"{dir}-projected.parquet"))

# %%
projected_gdf = dissolve_and_reset(projected_gdf)

# %%
projected_gdf.to_parquet(Path(DATASETS_DIR, f"{dir}-projected.parquet"))

# %% [markdown]
# ------

# %% [markdown]
# ### Alluvial Fan, Debris Flow

# %%
# PATH_TO_AFDF = Path(CALAMITY_SHPFILE_DIR, "AlluvialFanDebrisFlow")

# %%
# dir = "AlluvialFan"

# %%
# map_to_city(PATH_TO_AFDF, dir)
# Out:
# Merging AlluvialFan...
# Progress: 1/1
# Unzipping Philippines_AlluvialFan.zip...
# Reading Philippines_AlluvialFan.zip...
# Mapping to cities: Philippines_AlluvialFan.zip...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Philippines_AlluvialFan.zip artifacts...
# ========

# %%
# projected_gdf = gp.read_parquet(Path(DATASETS_DIR, f"{dir}-projected.parquet"))

# %%
# projected_gdf = dissolve_and_reset(projected_gdf)

# %%
# projected_gdf.to_parquet(Path(DATASETS_DIR, f"{dir}-projected.parquet"))

# %% [markdown]
# -------

# %%
# PATH_TO_DEBRIS_FLOW = Path(CALAMITY_SHPFILE_DIR, "AlluvialFanDebrisFlow")

# %%
# dir = "DebrisFlow"

# %%
# map_to_city(PATH_TO_AFDF, dir)
# Out:
# Merging DebrisFlow...
# Progress: 1/1
# Unzipping Philippines_DebrisFlow.zip...
# Reading Philippines_DebrisFlow.zip...
# Mapping to cities: Philippines_DebrisFlow.zip...
# Dropping duplicates from output dataframe...
# Persisting output dataframe...
# Deleting Philippines_DebrisFlow.zip artifacts...
# ========

# %%
# projected_gdf = gp.read_parquet(Path(DATASETS_DIR, f"{dir}-projected.parquet"))

# %%
# projected_gdf = dissolve_and_reset(projected_gdf)

# %%
# projected_gdf.to_parquet(Path(DATASETS_DIR, f"{dir}-projected.parquet"))

# %% [markdown]
# ------
