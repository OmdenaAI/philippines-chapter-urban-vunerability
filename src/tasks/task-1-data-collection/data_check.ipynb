# %%
import pandas as pd

# To show all columns
pd.set_option('display.max_columns', None)

# Supress Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('merged_trained_v1.csv')
df1 = pd.read_csv('population_data_v2.csv')

# %%
df
# Out:
#              city_munic   longitude   latitude                   coords  \
# 0               Aborlan  118.548417   9.437101   9.4371009, 118.5484168
# 1          Abra De Ilog  120.726826  13.443721  13.4437209, 120.7268262
# 2                Abucay  120.534870  14.721315  14.7213146, 120.5348704
# 3                Abulug  121.457273  18.443485  18.4434854, 121.4572732
# 4                Abuyog  125.011485  10.747102   10.747102, 125.0114853
# ...                 ...         ...        ...                      ...
# 1627  City of Zamboanga  122.079000   6.921400          6.9214, 122.079
# 1628       Zamboanguita  123.199424   9.100465   9.1004649, 123.1994244
# 1629           Zaragoza  120.793554  15.447583  15.4475833, 120.7935538
# 1630            Zarraga  122.609582  10.822379  10.8223786, 122.6095819
# 1631          Zumarraga  124.841531  11.639055  11.6390554, 124.8415308
#
#                                                geometry  Disaster_ind  \
# ...

# %%
df1
# Out:
#         city_munic population
# 0          Aborlan     35,091
# 1     Abra De Ilog     31,306
# 2           Abucay     42,984
# 3           Abulug     32,497
# 4           Abuyog     59,571
# ...            ...        ...
# 1629     Zamboanga    977,234
# 1630  Zamboanguita     27,552
# 1631      Zaragoza     53,090
# 1632       Zarraga     27,305
# 1633     Zumarraga     16,936
#
# [1634 rows x 2 columns]

# %%
dup = df['city_munic'].duplicated(keep='last')
print(dup)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1627    False
# 1628    False
# 1629    False
# 1630    False
# 1631    False
# Name: city_munic, Length: 1632, dtype: bool

# %%
df['cluster_id'].unique()
# Out:
# array([1, 2, 0], dtype=int64)
