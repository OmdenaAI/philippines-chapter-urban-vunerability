# %% [markdown]
# # Merge Scraped .csv Files

# %% [markdown]
# First we need to import some dependencies to help us.
#
# We can use `csv` and `glob` for the merge and `Pandas` for creating a **DataFrame**.

# %%
import csv
import glob
import shutil

import pandas as pd
# To show all columns
# pd.set_option('display.max_columns', None)

# %% [markdown]
# We can now add the file path of the **.csv** files to a **variable** using `glob`.
#
# We use **'*'** to access all .csv files in the folder.

# %%
filenames = glob.glob("../../data/dti-data/*.csv")

# %% [markdown]
# We can now create a new **.csv** file, add the **header** row from one of the **.csv**
# files and then **iterate** through all of the **.csv** files using `next` to ignore
# the first row that contains the header row.

# %%
with open("merged_city_data.csv", "w", newline="") as f:
    writer = csv.writer(f)
    # write the header row once (This is a manual process of copy and paste)
    writer.writerow(['Pillar / Indicator',2014,2015,2016,2017,2018,2019,2020,2021,2022,'City_Municipality'])
    for filename in filenames:
        with open(filename, "r") as infile:
            reader = csv.reader(infile)
            # skip the header row in each file using `next`
            next(reader)
            for row in reader:
                writer.writerow(row)

# %%
filenames.sort()  # glob lacks reliable ordering, so impose your own if output order matters
with open('merged_city_data2.csv', 'wb') as f:
    for i, fname in enumerate(filenames):
        with open(fname, 'rb') as g:
            if i != 0:
                g.readline()  # Throw away header on all but first file
            # Block copy rest of file from input to output without parsing
            shutil.copyfileobj(g, f)

# %% [markdown]
# ## Create a DataFrame

# %% [markdown]
# We can now check our data.

# %%
df = pd.read_csv('merged_city_data2.csv')
df.head(60)
# Out:
#     Unnamed: 0                                 Pillar / Indicator    2014  \
# 0            0                                 Local Economy Size  0.2443
# 1            1                               Local Economy Growth  0.1861
# 2            2              Active Establishments in the Locality       -
# 3            3                          Safety Compliant Business       -
# 4            4                              Employment Generation  0.0000
# 5            5                                     Cost of Living  0.0000
# 6            6                             Cost of Doing Business  1.1160
# 7            7                                Financial Deepening  0.4888
# 8            8                                       Productivity  0.0000
# 9            9  Presence of Business and Professional Organiza...  0.0000
# 10          10                  Compliance to National Directives  2.5000
# 11          11              Presence of Investment Promotion Unit  0.0000
# 12          12                Compliance to ARTA Citizens Charter       -
# 13          13                Capacity to Generate Local Resource  0.0000
# 14          14                        Capacity of Health Services  0.0402
# 15          15                        Capacity of School Services  0.2783
# 16          16                         Recognition of Performance  0.0000
# 17          17                           Getting Business Permits       -
# 18          18                                    Peace and Order  0.6404
# 19          19                                  Social Protection       -
# 20          20                                       Road Network  0.0000
# 21          21                                  Distance to Ports  2.9851
# 22          22                    Availability of Basic Utilities  3.3333
# 23          23                            Transportation Vehicles  0.0125
# 24          24                                          Education  0.1964
# 25          25                                             Health  0.1183
# 26          26                                     LGU Investment  0.7562
# 27          27                             Accommodation Capacity  0.0000
# 28          28                    Information Technology Capacity  0.0000
# 29          29                      Financial Technology Capacity  0.0457
# 30          30                                      Land Use Plan       -
# 31          31                       Disaster Risk Reduction Plan       -
# 32          32                              Annual Disaster Drill       -
# 33          33                               Early Warning System       -
# 34          34                                   Budget for DRRMP       -
# 35          35                             Local Risk Assessments       -
# 36          36                           Emergency Infrastructure       -
# 37          37                                          Utilities       -
# 38          38                                Employed Population       -
# 39          39                                    Sanitary System       -
# 40          40                 Start Up and Innovation Facilities       -
# 41          41   Innovation Financing: R&D Expenditures Allotment       -
# 42          42                                     STEM graduates       -
# 43          43                 Intellectual Property Registration       -
# 44          44                           ICT Use: E-BPLS Software       -
# 45          45                                Internet Capability       -
# 46          46             Availability of Basic Internet Service       -
# 47          47                          Online Payment Facilities       -
# 48          48                                           ICT Plan       -
# 49          49                                     New Technology       -
# 50           0                                 Local Economy Size  0.0000
# 51           1                               Local Economy Growth  0.0000
# 52           2              Active Establishments in the Locality       -
# 53           3                          Safety Compliant Business       -
# 54           4                              Employment Generation  0.0000
# 55           5                                     Cost of Living  3.4004
# 56           6                             Cost of Doing Business  1.6154
# 57           7                                Financial Deepening  0.0233
# 58           8                                       Productivity  0.0000
# 59           9  Presence of Business and Professional Organiza...  0.0000
#
#       2015    2016    2017    2018    2019    2020    2021    2022  \
# 0   0.1057  0.2782  0.0039  0.0072  0.0051  0.0013  0.0067  0.0105
# 1   0.1973  0.1708  0.0012  0.0224  0.0024  0.1419  0.0045  0.0001
# 2        -       -  0.2120  0.2337  0.0000  0.1653  0.2606  0.0662
# 3        -       -  0.1943  0.1253  0.2553  0.1643  0.1683     0.0
# 4   0.0000  0.0692  0.0218  0.0197  0.0000  0.0651  0.1052  0.0624
# 5   2.7616  3.0833  1.5203  1.9907  0.9127  0.3017  1.6250  1.9279
# 6   2.0367  2.6063  2.2277  2.1771  1.9655  2.2798  2.3654  1.9004
# 7   0.2993  0.2491  0.1894  0.0423  0.1339  0.1390  0.1231  0.0793
# 8   0.0000  0.0017  0.0145  0.0047  0.0004  0.0413  0.0690  0.0341
# 9   0.0096  0.0031  0.0000  0.0218  0.0007  0.0216  0.1089  0.0117
# 10  3.3333  3.3041  2.3718  0.0000  2.2000  2.4242  2.2619  1.8214
# 11  3.3333  3.3333  2.5000  0.0000  2.5000  0.6250  1.8750  1.6667
# 12  2.9166  2.1850  2.2597  0.0000  1.9499  2.2404  2.1365     2.0
# 13  0.0000  1.6003  1.4320  0.0000  0.0074  0.0083  0.0061  0.0028
# 14  0.0588  0.0454  0.1098  0.0000  0.0614  0.0587  0.1064  0.0019
# 15  0.3632  0.2872  0.2879  0.0000  0.1451  0.0488  0.0145  0.0022
# 16  0.3175  0.2381  0.2879  0.0000  0.0595  0.0023  0.0000     0.0
# 17       -  1.1111  0.7434  0.0000  2.3451  2.3385  1.8169     1.5
# 18  0.0847  0.0518  0.4161  0.0000  0.0012  0.0072  0.0283  0.0644
# 19       -  0.1392  0.1104  0.0000  0.0007  0.0024  0.1047  0.0014
# 20  0.0000  0.0004  0.0000  0.0000  0.1006  0.0006  0.1846  0.0001
# 21  2.9589  2.8501  2.1655  0.0000  2.3204  2.4933  2.3721  1.8963
# 22  3.3333  3.3333  2.5000  0.0000  2.1047  2.3125  2.2948  0.0945
# 23  0.0095  0.0363  0.0204  0.0000  0.0029  0.0026  0.0030  0.0032
# 24  0.2012  0.0806  0.0997  0.0000  0.1300  0.1185  0.0835  0.0749
# 25  0.0431  0.0473  0.0623  0.0000  0.0689  0.0830  0.0816  0.0978
# 26  0.6345  0.6470  0.4592  0.0000  0.3137  0.1665  0.0220  0.0012
# 27  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000     0.0
# 28  0.0000  0.4300  0.2976  0.0000  0.0806  0.2679  0.0909  0.0176
# 29  0.0741  0.0694  0.0463  0.0000  0.0671  0.0631  0.0436  0.0172
# 30       -       -  1.8750  0.0000  2.4231  2.5000  2.4545  1.9848
# 31       -       -  2.5000  0.0000  2.4537  2.5000  2.4737  1.9998
# 32       -       -  2.5000  0.0000  2.2500  2.5000  1.2542   1.002
# 33       -       -  2.5000  0.0000  2.5000  2.5000  1.2537  1.0087
# 34       -       -  0.0017  0.0000  0.2189  0.0852  0.0215     0.0
# 35       -       -  2.5000  0.0000  2.5000  2.5000  2.5000     2.0
# 36       -       -  0.8750  0.0000  0.4984  0.5004  0.0531  0.0292
# 37       -       -  0.9949  0.0000  1.8558  1.8706  1.2478  1.5007
# 38       -       -  0.0457  0.0000  0.0401  0.0385  0.0060  0.0061
# 39       -       -  1.5706  0.0000  1.4921  0.9946  1.2502  1.0002
# 40       -       -       -       -       -       -       -  0.1281
# 41       -       -       -       -       -       -       -     0.0
# 42       -       -       -       -       -       -       -  0.0195
# 43       -       -       -       -       -       -       -  0.0221
# 44       -       -       -       -       -       -       -     2.0
# 45       -       -       -       -       -       -       -  0.0095
# 46       -       -       -       -       -       -       -     0.0
# 47       -       -       -       -       -       -       -     0.0
# 48       -       -       -       -       -       -       -  2.0001
# 49       -       -       -       -       -       -       -     0.0
# 50  0.0172  0.0296  0.0089  0.0027  0.0025  0.0368  0.0070  0.0015
# 51  0.0000  0.0970  0.0109  0.0102  0.0071  0.3312  0.0066     0.0
# 52       -       -  0.0479  0.0477  0.0267  0.0368  0.0588  0.0498
# 53       -       -  0.0369  0.0282  0.0398  0.0255  0.0676     0.0
# 54  0.0000  0.0157  0.0042  0.0008  0.0181  0.0166  0.0191  0.0171
# 55  2.9554  3.5000  1.9257  2.3611  1.8254  0.0000  0.5938  1.6875
# 56  2.3808  3.0309  2.2561  2.2200  2.0960  2.2618  2.3642   1.899
# 57  0.2532  0.2264  0.1263  0.0184  0.0588  0.0593  0.0380  0.0443
# 58  0.0000  0.0025  0.0278  0.0579  0.0002  0.0088  0.0150  0.0042
# 59  0.0000  0.0000  0.0860  0.0235  0.0106  0.0077  0.0106   0.005
#
#    City_Municipality
# 0            Aborlan
# 1            Aborlan
# 2            Aborlan
# 3            Aborlan
# 4            Aborlan
# 5            Aborlan
# 6            Aborlan
# 7            Aborlan
# 8            Aborlan
# 9            Aborlan
# 10           Aborlan
# 11           Aborlan
# 12           Aborlan
# 13           Aborlan
# 14           Aborlan
# 15           Aborlan
# 16           Aborlan
# 17           Aborlan
# 18           Aborlan
# 19           Aborlan
# 20           Aborlan
# 21           Aborlan
# 22           Aborlan
# 23           Aborlan
# 24           Aborlan
# 25           Aborlan
# 26           Aborlan
# 27           Aborlan
# 28           Aborlan
# 29           Aborlan
# 30           Aborlan
# 31           Aborlan
# 32           Aborlan
# 33           Aborlan
# 34           Aborlan
# 35           Aborlan
# 36           Aborlan
# 37           Aborlan
# 38           Aborlan
# 39           Aborlan
# 40           Aborlan
# 41           Aborlan
# 42           Aborlan
# 43           Aborlan
# 44           Aborlan
# 45           Aborlan
# 46           Aborlan
# 47           Aborlan
# 48           Aborlan
# 49           Aborlan
# 50      Abra De Ilog
# 51      Abra De Ilog
# 52      Abra De Ilog
# 53      Abra De Ilog
# 54      Abra De Ilog
# 55      Abra De Ilog
# 56      Abra De Ilog
# 57      Abra De Ilog
# 58      Abra De Ilog
# 59      Abra De Ilog

# %% [markdown]
# We will need to drop the column **Unnamed: 0**. This column is created because there is a missing header name in the .csv files.
#
# We can use a simple `del` to do the job.

# %%
del df['Unnamed: 0']
df.head(2)
# Out:
#      Pillar / Indicator    2014    2015    2016    2017    2018    2019  \
# 0    Local Economy Size  0.2443  0.1057  0.2782  0.0039  0.0072  0.0051
# 1  Local Economy Growth  0.1861  0.1973  0.1708  0.0012  0.0224  0.0024
#
#      2020    2021    2022 City_Municipality
# 0  0.0013  0.0067  0.0105           Aborlan
# 1  0.1419  0.0045  0.0001           Aborlan

# %% [markdown]
# Lets check the shape of the data.

# %%
df.shape
# Out:
# (81600, 11)

# %% [markdown]
# ## Missing Values
# ### We have set a threshold of 50% missing values
# Lets check for **Missing** values.

# %%
df.isnull().sum()
# Out:
# Pillar / Indicator    0
# 2014                  0
# 2015                  0
# 2016                  0
# 2017                  0
# 2018                  0
# 2019                  0
# 2020                  0
# 2021                  0
# 2022                  0
# City_Municipality     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81600 entries, 0 to 81599
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Pillar / Indicator  81600 non-null  object
#  1   2014                81600 non-null  object
#  2   2015                81600 non-null  object
#  3   2016                81600 non-null  object
#  4   2017                81600 non-null  object
#  5   2018                81600 non-null  object
#  6   2019                81600 non-null  object
#  7   2020                81600 non-null  object
#  8   2021                81600 non-null  object
#  9   2022                81600 non-null  object
#  10  City_Municipality   81600 non-null  object
# dtypes: object(11)
# memory usage: 6.8+ MB

# %% [markdown]
# These results are misleading as we know by a quick glance at the Dataframe shows missing values.
#
# If we look closely, the missing values contain the **"-"** character.
#
# Lets investigate using **"-"** as our search query.

# %%
for column in df.columns:
    count = df[column].str.count("-").sum()
    perc = round(df[column].str.count("-").sum() / 81600 * 100, 2)
    print(f"Column {column}: {count} characters, {perc}%")
# Out:
# Column Pillar / Indicator: 1632 characters, 2.0%
# Column 2014: 68300 characters, 83.7%
# Column 2015: 52636 characters, 64.5%
# Column 2016: 42882 characters, 52.55%
# Column 2017: 22200 characters, 27.21%
# Column 2018: 21360 characters, 26.18%
# Column 2019: 21040 characters, 25.78%
# Column 2020: 21080 characters, 25.83%
# Column 2021: 17400 characters, 21.32%
# Column 2022: 161 characters, 0.2%
# Column City_Municipality: 1250 characters, 1.53%

# %% [markdown]
# We have three columns with 50% or more missing values.
#
# Lets drop these columns.

# %%
df.drop(columns=['2014', '2015', '2016',], inplace=True)

# %% [markdown]
# And check again to confirm we have dropped the columns.

# %%
for column in df.columns:
    count = df[column].str.count("-").sum()
    perc = round(df[column].str.count("-").sum() / 81600 * 100, 2)
    print(f"Column {column}: {count} characters, {perc}%")
# Out:
# Column Pillar / Indicator: 1632 characters, 2.0%
# Column 2017: 22200 characters, 27.21%
# Column 2018: 21360 characters, 26.18%
# Column 2019: 21040 characters, 25.78%
# Column 2020: 21080 characters, 25.83%
# Column 2021: 17400 characters, 21.32%
# Column 2022: 161 characters, 0.2%
# Column City_Municipality: 1250 characters, 1.53%

# %%
df.shape
# Out:
# (81600, 8)

# %% [markdown]
# Now we can work on the dataframe to convert the years into a single column and map the values.
#
# First we will create a list of column names.

# %%
cols = df.columns.values.tolist()
cols
# Out:
# ['Pillar / Indicator',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2022',
#  'City_Municipality']

# %% [markdown]
# By setting **'City_Municipality'** and **'Pillar / Indicator'** as indexes we can stack the years and values.
#
# We will create a new DataFrame **df1** in the process.

# %%
df1 = df[cols].set_index(['City_Municipality', 'Pillar / Indicator']).stack().reset_index()
df1
# Out:
#        City_Municipality  Pillar / Indicator level_2       0
# 0                Aborlan  Local Economy Size    2017  0.0039
# 1                Aborlan  Local Economy Size    2018  0.0072
# 2                Aborlan  Local Economy Size    2019  0.0051
# 3                Aborlan  Local Economy Size    2020  0.0013
# 4                Aborlan  Local Economy Size    2021  0.0067
# ...                  ...                 ...     ...     ...
# 489595         Zumarraga      New Technology    2018       -
# 489596         Zumarraga      New Technology    2019       -
# 489597         Zumarraga      New Technology    2020       -
# 489598         Zumarraga      New Technology    2021       -
# 489599         Zumarraga      New Technology    2022     0.0
#
# [489600 rows x 4 columns]

# %% [markdown]
# Lets rename the columns.

# %%
df1 = df1.rename(columns={'level_2': 'Year', 0: 'Value'})
df1.head(1)
# Out:
#   City_Municipality  Pillar / Indicator  Year   Value
# 0           Aborlan  Local Economy Size  2017  0.0039

# %% [markdown]
# We are now ready to convert the **Pillar / Indicator** values into column names (features).

# %%
df2 = df1.set_index(['City_Municipality', 'Year', 'Pillar / Indicator'], drop=True).unstack('Pillar / Indicator')
df2
# Out:
#                                         Value  \
# Pillar / Indicator     Accommodation Capacity
# City_Municipality Year
# Aborlan           2017                 0.0000
#                   2018                 0.0000
#                   2019                 0.0000
#                   2020                 0.0000
#                   2021                 0.0000
# ...                                       ...
# Zumarraga         2018                 0.0000
#                   2019                 0.0104
#                   2020                 0.0000
#                   2021                 0.0000
#                   2022                    0.0
#
#                                                               \
# Pillar / Indicator     Active Establishments in the Locality
# City_Municipality Year
# Aborlan           2017                                0.2120
#                   2018                                0.2337
#                   2019                                0.0000
#                   2020                                0.1653
#                   2021                                0.2606
# ...                                                      ...
# Zumarraga         2018                                0.0004
#                   2019                                0.0093
#                   2020                                1.0019
#                   2021                                0.1886
#                   2022                                0.2099
#
#                                               \
# Pillar / Indicator     Annual Disaster Drill
# City_Municipality Year
# Aborlan           2017                2.5000
#                   2018                0.0000
#                   2019                2.2500
#                   2020                2.5000
#                   2021                1.2542
# ...                                      ...
# Zumarraga         2018                0.0000
#                   2019                2.4107
#                   2020                2.5000
#                   2021                0.0000
#                   2022                   0.0
#
#                                                                \
# Pillar / Indicator     Availability of Basic Internet Service
# City_Municipality Year
# Aborlan           2017                                      -
#                   2018                                      -
#                   2019                                      -
#                   2020                                      -
#                   2021                                      -
# ...                                                       ...
# Zumarraga         2018                                      -
#                   2019                                      -
#                   2020                                      -
#                   2021                                      -
#                   2022                                    0.0
#
#                                                                          \
# Pillar / Indicator     Availability of Basic Utilities Budget for DRRMP
# City_Municipality Year
# Aborlan           2017                          2.5000           0.0017
#                   2018                          0.0000           0.0000
#                   2019                          2.1047           0.2189
#                   2020                          2.3125           0.0852
#                   2021                          2.2948           0.0215
# ...                                                ...              ...
# Zumarraga         2018                          0.0000           0.0000
#                   2019                          1.4719           0.0632
#                   2020                          1.9531           0.0636
#                   2021                          1.3688           0.0039
#                   2022                          0.2666           0.0017
#
#                                                     \
# Pillar / Indicator     Capacity of Health Services
# City_Municipality Year
# Aborlan           2017                      0.1098
#                   2018                      0.0000
#                   2019                      0.0614
#                   2020                      0.0587
#                   2021                      0.1064
# ...                                            ...
# Zumarraga         2018                      0.0000
#                   2019                      0.0324
#                   2020                      0.1629
#                   2021                      0.0830
#                   2022                      0.0004
#
#                                                     \
# Pillar / Indicator     Capacity of School Services
# City_Municipality Year
# Aborlan           2017                      0.2879
#                   2018                      0.0000
#                   2019                      0.1451
#                   2020                      0.0488
#                   2021                      0.0145
# ...                                            ...
# Zumarraga         2018                      0.0000
#                   2019                      0.2339
#                   2020                      0.1926
#                   2021                      0.1112
#                   2022                       0.008
#
#                                                             \
# Pillar / Indicator     Capacity to Generate Local Resource
# City_Municipality Year
# Aborlan           2017                              1.4320
#                   2018                              0.0000
#                   2019                              0.0074
#                   2020                              0.0083
#                   2021                              0.0061
# ...                                                    ...
# Zumarraga         2018                              0.0000
#                   2019                              0.7070
#                   2020                              0.3451
#                   2021                              0.0018
#                   2022                              0.0006
#
#                                                             ...               \
# Pillar / Indicator     Compliance to ARTA Citizens Charter  ... Productivity
# City_Municipality Year                                      ...
# Aborlan           2017                              2.2597  ...       0.0145
#                   2018                              0.0000  ...       0.0047
#                   2019                              1.9499  ...       0.0004
#                   2020                              2.2404  ...       0.0413
#                   2021                              2.1365  ...       0.0690
# ...                                                    ...  ...          ...
# Zumarraga         2018                              0.0000  ...       0.0000
#                   2019                              2.3612  ...       0.0033
#                   2020                              2.3957  ...       0.0298
#                   2021                              2.1877  ...       0.0000
#                   2022                                 2.0  ...       0.0605
#
#                                                                                \
# Pillar / Indicator     Recognition of Performance Road Network STEM graduates
# City_Municipality Year
# Aborlan           2017                     0.2879       0.0000              -
#                   2018                     0.0000       0.0000              -
#                   2019                     0.0595       0.1006              -
#                   2020                     0.0023       0.0006              -
#                   2021                     0.0000       0.1846              -
# ...                                           ...          ...            ...
# Zumarraga         2018                     0.0000       0.0000              -
#                   2019                     0.0000       0.0202              -
#                   2020                     0.2262       0.0024              -
#                   2021                     0.0000       0.0126              -
#                   2022                     0.1042          0.0            0.0
#
#                                                                   \
# Pillar / Indicator     Safety Compliant Business Sanitary System
# City_Municipality Year
# Aborlan           2017                    0.1943          1.5706
#                   2018                    0.1253          0.0000
#                   2019                    0.2553          1.4921
#                   2020                    0.1643          0.9946
#                   2021                    0.1683          1.2502
# ...                                          ...             ...
# Zumarraga         2018                    0.0000          0.0000
#                   2019                    0.0000          1.0144
#                   2020                    0.0000          1.5045
#                   2021                    0.0000          1.2567
#                   2022                       0.0          1.0002
#
#                                                                              \
# Pillar / Indicator     Social Protection Start Up and Innovation Facilities
# City_Municipality Year
# Aborlan           2017            0.1104                                  -
#                   2018            0.0000                                  -
#                   2019            0.0007                                  -
#                   2020            0.0024                                  -
#                   2021            0.1047                                  -
# ...                                  ...                                ...
# Zumarraga         2018            0.0000                                  -
#                   2019            0.7160                                  -
#                   2020            0.1281                                  -
#                   2021            1.6311                                  -
#                   2022               0.0                                0.0
#
#
# Pillar / Indicator     Transportation Vehicles Utilities
# City_Municipality Year
# Aborlan           2017                  0.0204    0.9949
#                   2018                  0.0000    0.0000
#                   2019                  0.0029    1.8558
#                   2020                  0.0026    1.8706
#                   2021                  0.0030    1.2478
# ...                                        ...       ...
# Zumarraga         2018                  0.0000    0.0000
#                   2019                  0.0014    1.8799
#                   2020                  0.0015    1.8754
#                   2021                  0.0034    1.0391
#                   2022                   0.002    1.5008
#
# [9792 rows x 50 columns]

# %% [markdown]
# We have created a **Multindex** DataFrame, we need to convert back to a single index DataFrame.
#
# First we need a list of the new column names we have created.

# %%
c_names = df['Pillar / Indicator'].unique().tolist()
c_names
# Out:
# ['Local Economy Size',
#  'Local Economy Growth',
#  'Active Establishments in the Locality',
#  'Safety Compliant Business',
#  'Employment Generation',
#  'Cost of Living',
#  'Cost of Doing Business',
#  'Financial Deepening',
#  'Productivity',
#  'Presence of Business and Professional Organizations',
#  'Compliance to National Directives',
#  'Presence of Investment Promotion Unit',
#  'Compliance to ARTA Citizens Charter',
#  'Capacity to Generate Local Resource',
#  'Capacity of Health Services',
#  'Capacity of School Services',
#  'Recognition of Performance',
#  'Getting Business Permits',
#  'Peace and Order',
#  'Social Protection',
#  'Road Network',
#  'Distance to Ports',
#  'Availability of Basic Utilities',
#  'Transportation Vehicles',
#  'Education',
#  'Health',
#  'LGU Investment',
#  'Accommodation Capacity',
#  'Information Technology Capacity',
#  'Financial Technology Capacity',
#  'Land Use Plan',
#  'Disaster Risk Reduction Plan',
#  'Annual Disaster Drill',
#  'Early Warning System',
#  'Budget for DRRMP',
#  'Local Risk Assessments',
#  'Emergency Infrastructure',
#  'Utilities',
#  'Employed Population',
#  'Sanitary System',
#  'Start Up and Innovation Facilities',
#  'Innovation Financing: R&D Expenditures Allotment',
#  'STEM graduates',
#  'Intellectual Property Registration',
#  'ICT Use: E-BPLS Software',
#  'Internet Capability',
#  'Availability of Basic Internet Service',
#  'Online Payment Facilities',
#  'ICT Plan',
#  'New Technology']

# %% [markdown]
# We can now use this list to map and join the indexes.

# %%
df2.reset_index( drop=False, inplace=True)
df2.reindex([
    'Local Economy Size',
	'Local Economy Growth',
	'Active Establishments in the Locality',
	'Safety Compliant Business',
	'Employment Generation',
	'Cost of Living',
	'Cost of Doing Business',
	'Financial Deepening',
	'Productivity',
	'Presence of Business and Professional Organizations',
	'Compliance to National Directives',
	'Presence of Investment Promotion Unit',
	'Compliance to ARTA Citizens Charter',
	'Capacity to Generate Local Resource',
	'Capacity of Health Services',
	'Capacity of School Services',
	'Recognition of Performance',
	'Getting Business Permits',
	'Peace and Order',
	'Social Protection',
	'Road Network',
	'Distance to Ports',
	'Availability of Basic Utilities',
	'Transportation Vehicles',
	'Education',
	'Health',
	'LGU Investment',
	'Accommodation Capacity',
	'Information Technology Capacity',
	'Financial Technology Capacity',
	'Land Use Plan',
	'Disaster Risk Reduction Plan',
	'Annual Disaster Drill',
	'Early Warning System',
	'Budget for DRRMP',
	'Local Risk Assessments',
	'Emergency Infrastructure',
	'Utilities',
	'Employed Population',
	'Sanitary System',
	'Start Up and Innovation Facilities',
	'Innovation Financing: R&D Expenditures Allotment',
	'STEM graduates',
	'Intellectual Property Registration',
	'ICT Use: E-BPLS Software',
	'Internet Capability',
	'Availability of Basic Internet Service',
	'Online Payment Facilities',
	'ICT Plan',
	'New Technology'], axis=1)
df2
# Out:
#                    City_Municipality  Year                  Value  \
# Pillar / Indicator                         Accommodation Capacity
# 0                            Aborlan  2017                 0.0000
# 1                            Aborlan  2018                 0.0000
# 2                            Aborlan  2019                 0.0000
# 3                            Aborlan  2020                 0.0000
# 4                            Aborlan  2021                 0.0000
# ...                              ...   ...                    ...
# 9787                       Zumarraga  2018                 0.0000
# 9788                       Zumarraga  2019                 0.0104
# 9789                       Zumarraga  2020                 0.0000
# 9790                       Zumarraga  2021                 0.0000
# 9791                       Zumarraga  2022                    0.0
#
#                                                           \
# Pillar / Indicator Active Establishments in the Locality
# 0                                                 0.2120
# 1                                                 0.2337
# 2                                                 0.0000
# 3                                                 0.1653
# 4                                                 0.2606
# ...                                                  ...
# 9787                                              0.0004
# 9788                                              0.0093
# 9789                                              1.0019
# 9790                                              0.1886
# 9791                                              0.2099
#
#                                           \
# Pillar / Indicator Annual Disaster Drill
# 0                                 2.5000
# 1                                 0.0000
# 2                                 2.2500
# 3                                 2.5000
# 4                                 1.2542
# ...                                  ...
# 9787                              0.0000
# 9788                              2.4107
# 9789                              2.5000
# 9790                              0.0000
# 9791                                 0.0
#
#                                                            \
# Pillar / Indicator Availability of Basic Internet Service
# 0                                                       -
# 1                                                       -
# 2                                                       -
# 3                                                       -
# 4                                                       -
# ...                                                   ...
# 9787                                                    -
# 9788                                                    -
# 9789                                                    -
# 9790                                                    -
# 9791                                                  0.0
#
#                                                                      \
# Pillar / Indicator Availability of Basic Utilities Budget for DRRMP
# 0                                           2.5000           0.0017
# 1                                           0.0000           0.0000
# 2                                           2.1047           0.2189
# 3                                           2.3125           0.0852
# 4                                           2.2948           0.0215
# ...                                            ...              ...
# 9787                                        0.0000           0.0000
# 9788                                        1.4719           0.0632
# 9789                                        1.9531           0.0636
# 9790                                        1.3688           0.0039
# 9791                                        0.2666           0.0017
#
#                                                                             \
# Pillar / Indicator Capacity of Health Services Capacity of School Services
# 0                                       0.1098                      0.2879
# 1                                       0.0000                      0.0000
# 2                                       0.0614                      0.1451
# 3                                       0.0587                      0.0488
# 4                                       0.1064                      0.0145
# ...                                        ...                         ...
# 9787                                    0.0000                      0.0000
# 9788                                    0.0324                      0.2339
# 9789                                    0.1629                      0.1926
# 9790                                    0.0830                      0.1112
# 9791                                    0.0004                       0.008
#
#                     ...                                                       \
# Pillar / Indicator  ... Productivity Recognition of Performance Road Network
# 0                   ...       0.0145                     0.2879       0.0000
# 1                   ...       0.0047                     0.0000       0.0000
# 2                   ...       0.0004                     0.0595       0.1006
# 3                   ...       0.0413                     0.0023       0.0006
# 4                   ...       0.0690                     0.0000       0.1846
# ...                 ...          ...                        ...          ...
# 9787                ...       0.0000                     0.0000       0.0000
# 9788                ...       0.0033                     0.0000       0.0202
# 9789                ...       0.0298                     0.2262       0.0024
# 9790                ...       0.0000                     0.0000       0.0126
# 9791                ...       0.0605                     0.1042          0.0
#
#                                                                              \
# Pillar / Indicator STEM graduates Safety Compliant Business Sanitary System
# 0                               -                    0.1943          1.5706
# 1                               -                    0.1253          0.0000
# 2                               -                    0.2553          1.4921
# 3                               -                    0.1643          0.9946
# 4                               -                    0.1683          1.2502
# ...                           ...                       ...             ...
# 9787                            -                    0.0000          0.0000
# 9788                            -                    0.0000          1.0144
# 9789                            -                    0.0000          1.5045
# 9790                            -                    0.0000          1.2567
# 9791                          0.0                       0.0          1.0002
#
#                                                                          \
# Pillar / Indicator Social Protection Start Up and Innovation Facilities
# 0                             0.1104                                  -
# 1                             0.0000                                  -
# 2                             0.0007                                  -
# 3                             0.0024                                  -
# 4                             0.1047                                  -
# ...                              ...                                ...
# 9787                          0.0000                                  -
# 9788                          0.7160                                  -
# 9789                          0.1281                                  -
# 9790                          1.6311                                  -
# 9791                             0.0                                0.0
#
#
# Pillar / Indicator Transportation Vehicles Utilities
# 0                                   0.0204    0.9949
# 1                                   0.0000    0.0000
# 2                                   0.0029    1.8558
# 3                                   0.0026    1.8706
# 4                                   0.0030    1.2478
# ...                                    ...       ...
# 9787                                0.0000    0.0000
# 9788                                0.0014    1.8799
# 9789                                0.0015    1.8754
# 9790                                0.0034    1.0391
# 9791                                 0.002    1.5008
#
# [9792 rows x 52 columns]

# %% [markdown]
# Time to `map` and `join` the DataFrame. We will remove all the words **'Value'** from the column names and remove the whitespace from the start and end of the names.

# %%
df2.columns = df2.columns.map(' '.join)
df2.columns = df2.columns.str.replace(r'Value', '')
df2.columns = df2.columns.str.lstrip()
df2.columns = df2.columns.str.rstrip()
df2
# Out:
#      City_Municipality  Year Accommodation Capacity  \
# 0              Aborlan  2017                 0.0000
# 1              Aborlan  2018                 0.0000
# 2              Aborlan  2019                 0.0000
# 3              Aborlan  2020                 0.0000
# 4              Aborlan  2021                 0.0000
# ...                ...   ...                    ...
# 9787         Zumarraga  2018                 0.0000
# 9788         Zumarraga  2019                 0.0104
# 9789         Zumarraga  2020                 0.0000
# 9790         Zumarraga  2021                 0.0000
# 9791         Zumarraga  2022                    0.0
#
#      Active Establishments in the Locality Annual Disaster Drill  \
# 0                                   0.2120                2.5000
# 1                                   0.2337                0.0000
# 2                                   0.0000                2.2500
# 3                                   0.1653                2.5000
# 4                                   0.2606                1.2542
# ...                                    ...                   ...
# 9787                                0.0004                0.0000
# 9788                                0.0093                2.4107
# 9789                                1.0019                2.5000
# 9790                                0.1886                0.0000
# 9791                                0.2099                   0.0
#
#      Availability of Basic Internet Service Availability of Basic Utilities  \
# 0                                         -                          2.5000
# 1                                         -                          0.0000
# 2                                         -                          2.1047
# 3                                         -                          2.3125
# 4                                         -                          2.2948
# ...                                     ...                             ...
# 9787                                      -                          0.0000
# 9788                                      -                          1.4719
# 9789                                      -                          1.9531
# 9790                                      -                          1.3688
# 9791                                    0.0                          0.2666
#
#      Budget for DRRMP Capacity of Health Services Capacity of School Services  \
# 0              0.0017                      0.1098                      0.2879
# 1              0.0000                      0.0000                      0.0000
# 2              0.2189                      0.0614                      0.1451
# 3              0.0852                      0.0587                      0.0488
# 4              0.0215                      0.1064                      0.0145
# ...               ...                         ...                         ...
# 9787           0.0000                      0.0000                      0.0000
# 9788           0.0632                      0.0324                      0.2339
# 9789           0.0636                      0.1629                      0.1926
# 9790           0.0039                      0.0830                      0.1112
# 9791           0.0017                      0.0004                       0.008
#
#       ... Productivity Recognition of Performance Road Network STEM graduates  \
# 0     ...       0.0145                     0.2879       0.0000              -
# 1     ...       0.0047                     0.0000       0.0000              -
# 2     ...       0.0004                     0.0595       0.1006              -
# 3     ...       0.0413                     0.0023       0.0006              -
# 4     ...       0.0690                     0.0000       0.1846              -
# ...   ...          ...                        ...          ...            ...
# 9787  ...       0.0000                     0.0000       0.0000              -
# 9788  ...       0.0033                     0.0000       0.0202              -
# 9789  ...       0.0298                     0.2262       0.0024              -
# 9790  ...       0.0000                     0.0000       0.0126              -
# 9791  ...       0.0605                     0.1042          0.0            0.0
#
#      Safety Compliant Business Sanitary System Social Protection  \
# 0                       0.1943          1.5706            0.1104
# 1                       0.1253          0.0000            0.0000
# 2                       0.2553          1.4921            0.0007
# 3                       0.1643          0.9946            0.0024
# 4                       0.1683          1.2502            0.1047
# ...                        ...             ...               ...
# 9787                    0.0000          0.0000            0.0000
# 9788                    0.0000          1.0144            0.7160
# 9789                    0.0000          1.5045            0.1281
# 9790                    0.0000          1.2567            1.6311
# 9791                       0.0          1.0002               0.0
#
#      Start Up and Innovation Facilities Transportation Vehicles Utilities
# 0                                     -                  0.0204    0.9949
# 1                                     -                  0.0000    0.0000
# 2                                     -                  0.0029    1.8558
# 3                                     -                  0.0026    1.8706
# 4                                     -                  0.0030    1.2478
# ...                                 ...                     ...       ...
# 9787                                  -                  0.0000    0.0000
# 9788                                  -                  0.0014    1.8799
# 9789                                  -                  0.0015    1.8754
# 9790                                  -                  0.0034    1.0391
# 9791                                0.0                   0.002    1.5008
#
# [9792 rows x 52 columns]

# %% [markdown]
# Delete the unwanted columns.

# %%
del df2[
    'Start Up and Innovation Facilities'],df2[
        'New Technology'],df2[
            'Online Payment Facilities'],df2[
                'ICT Plan'],df2[
                    'ICT Use: E-BPLS Software'],df2[
                        'Information Technology Capacity'],df2[
                            'Innovation Financing: R&D Expenditures Allotment'],df2[
                                'Intellectual Property Registration'],df2[
                                    'Internet Capability'],df2[
                                        'STEM graduates']
df2.head(2)
# Out:
#   City_Municipality  Year Accommodation Capacity  \
# 0           Aborlan  2017                 0.0000
# 1           Aborlan  2018                 0.0000
#
#   Active Establishments in the Locality Annual Disaster Drill  \
# 0                                0.2120                2.5000
# 1                                0.2337                0.0000
#
#   Availability of Basic Internet Service Availability of Basic Utilities  \
# 0                                      -                          2.5000
# 1                                      -                          0.0000
#
#   Budget for DRRMP Capacity of Health Services Capacity of School Services  \
# 0           0.0017                      0.1098                      0.2879
# 1           0.0000                      0.0000                      0.0000
#
#    ... Presence of Business and Professional Organizations  \
# 0  ...                                             0.0000
# 1  ...                                             0.0218
#
#   Presence of Investment Promotion Unit Productivity  \
# 0                                2.5000       0.0145
# 1                                0.0000       0.0047
#
#   Recognition of Performance Road Network Safety Compliant Business  \
# 0                     0.2879       0.0000                    0.1943
# 1                     0.0000       0.0000                    0.1253
#
#   Sanitary System Social Protection Transportation Vehicles Utilities
# 0          1.5706            0.1104                  0.0204    0.9949
# 1          0.0000            0.0000                  0.0000    0.0000
#
# [2 rows x 42 columns]

# %%
df2.shape
# Out:
# (9792, 42)

# %% [markdown]
# ## Export to a .csv file

# %%
df2.to_csv('complete_dataset.csv', index=False)

# %% [markdown]
# ### Create a .csv file of unique City_Municipality values

# %%
city_unique = pd.DataFrame(df2['City_Municipality'].unique()).to_csv('city_names.csv', index=False)
