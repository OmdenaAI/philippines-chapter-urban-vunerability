# %% [markdown]
# # Merge Geodata

# %% [markdown]
# Now we have a clean set of data we can merge the cleaned geodata.
#
# First we need to import the dependencies.

# %%
import geopandas as gp
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Using Geopandas we can read in the shape file.

# %%
gdf0 = gp.read_file('ph_cities_v2/ph_cities_v2.shp')
gdf0
# Out:
#        FID                                           geometry
# 0        0  MULTIPOLYGON (((118.57998 9.37215, 118.57976 9...
# 1        1  POLYGON ((120.60896 13.35233, 120.60711 13.398...
# 2        2  POLYGON ((120.43443 14.68814, 120.42332 14.685...
# 3        3  MULTIPOLYGON (((121.39392 18.48335, 121.39868 ...
# 4        4  POLYGON ((124.92778 10.66676, 124.92364 10.677...
# ...    ...                                                ...
# 1629  1629  MULTIPOLYGON (((122.06639 6.86972, 122.06639 6...
# 1630  1630  POLYGON ((123.13098 9.06249, 123.13156 9.06276...
# 1631  1631  POLYGON ((120.85121 15.45757, 120.85025 15.455...
# 1632  1632  POLYGON ((122.66113 10.77914, 122.66028 10.779...
# 1633  1633  MULTIPOLYGON (((124.87373 11.62500, 124.87399 ...
#
# [1634 rows x 2 columns]

# %%
gdf = gp.read_file('../../data/geolocation/ph_cities_joined_v2/ph_cities_v2.shp')
gdf
# Out:
#             psgc          name         city_munic            province  \
# 0     1705301000       Aborlan            Aborlan             Palawan
# 1     1705101000  Abra De Ilog       Abra De Ilog  Occidental Mindoro
# 2      300801000        Abucay             Abucay              Bataan
# 3      201501000        Abulug             Abulug             Cagayan
# 4      803701000        Abuyog             Abuyog               Leyte
# ...          ...           ...                ...                 ...
# 1629   931700000     Zamboanga  City of Zamboanga   Zamboanga del Sur
# 1630   704625000  Zamboanguita       Zamboanguita     Negros Oriental
# 1631   304932000      Zaragoza           Zaragoza         Nueva Ecija
# 1632   603047000       Zarraga            Zarraga              Iloilo
# 1633   806023000     Zumarraga          Zumarraga               Samar
#
#                           clean_idx   longitude   latitude  \
# 0                  aborlan, palawan  118.548417   9.437101
# 1     abradeilog, occidentalmindoro  120.726826  13.443721
# 2                    abucay, bataan  120.534870  14.721315
# 3                   abulug, cagayan  121.457273  18.443485
# 4                     abuyog, leyte  125.011485  10.747102
# ...                             ...         ...        ...
# 1629     zamboanga, zamboangadelsur  122.079000   6.921400
# 1630   zamboanguita, negrosoriental  123.199424   9.100465
# 1631           zaragoza, nuevaecija  120.793554  15.447583
# 1632                zarraga, iloilo  122.609582  10.822379
# 1633               zumarraga, samar  124.841531  11.639055
#
#                        coords  \
# 0      9.4371009, 118.5484168
# 1     13.4437209, 120.7268262
# 2     14.7213146, 120.5348704
# 3     18.4434854, 121.4572732
# 4      10.747102, 125.0114853
# ...                       ...
# 1629          6.9214, 122.079
# 1630   9.1004649, 123.1994244
# 1631  15.4475833, 120.7935538
# 1632  10.8223786, 122.6095819
# 1633  11.6390554, 124.8415308
#
#                                                geometry
# 0     MULTIPOLYGON (((118.57998 9.37215, 118.57982 9...
# 1     POLYGON ((120.60896 13.35233, 120.60797 13.373...
# 2     POLYGON ((120.45676 14.69671, 120.45620 14.696...
# 3     MULTIPOLYGON (((121.40276 18.40896, 121.40276 ...
# 4     POLYGON ((125.04650 10.56751, 125.04588 10.576...
# ...                                                 ...
# 1629  MULTIPOLYGON (((122.06639 6.86972, 122.06639 6...
# 1630  POLYGON ((123.20750 9.10485, 123.20722 9.10443...
# 1631  POLYGON ((120.81170 15.47132, 120.81309 15.470...
# 1632  POLYGON ((122.65892 10.79784, 122.65959 10.796...
# 1633  MULTIPOLYGON (((124.87373 11.62500, 124.87370 ...
#
# [1634 rows x 9 columns]

# %%
gdf = gdf.drop('geometry', axis=1).assign(geometry=gdf0['geometry'])
gdf = gdf.assign(FID=gdf0['FID'])
gdf
# Out:
#             psgc          name         city_munic            province  \
# 0     1705301000       Aborlan            Aborlan             Palawan
# 1     1705101000  Abra De Ilog       Abra De Ilog  Occidental Mindoro
# 2      300801000        Abucay             Abucay              Bataan
# 3      201501000        Abulug             Abulug             Cagayan
# 4      803701000        Abuyog             Abuyog               Leyte
# ...          ...           ...                ...                 ...
# 1629   931700000     Zamboanga  City of Zamboanga   Zamboanga del Sur
# 1630   704625000  Zamboanguita       Zamboanguita     Negros Oriental
# 1631   304932000      Zaragoza           Zaragoza         Nueva Ecija
# 1632   603047000       Zarraga            Zarraga              Iloilo
# 1633   806023000     Zumarraga          Zumarraga               Samar
#
#                           clean_idx   longitude   latitude  \
# 0                  aborlan, palawan  118.548417   9.437101
# 1     abradeilog, occidentalmindoro  120.726826  13.443721
# 2                    abucay, bataan  120.534870  14.721315
# 3                   abulug, cagayan  121.457273  18.443485
# 4                     abuyog, leyte  125.011485  10.747102
# ...                             ...         ...        ...
# 1629     zamboanga, zamboangadelsur  122.079000   6.921400
# 1630   zamboanguita, negrosoriental  123.199424   9.100465
# 1631           zaragoza, nuevaecija  120.793554  15.447583
# 1632                zarraga, iloilo  122.609582  10.822379
# 1633               zumarraga, samar  124.841531  11.639055
#
#                        coords  \
# 0      9.4371009, 118.5484168
# 1     13.4437209, 120.7268262
# 2     14.7213146, 120.5348704
# 3     18.4434854, 121.4572732
# 4      10.747102, 125.0114853
# ...                       ...
# 1629          6.9214, 122.079
# 1630   9.1004649, 123.1994244
# 1631  15.4475833, 120.7935538
# 1632  10.8223786, 122.6095819
# 1633  11.6390554, 124.8415308
#
#                                                geometry   FID
# 0     MULTIPOLYGON (((118.57998 9.37215, 118.57976 9...     0
# 1     POLYGON ((120.60896 13.35233, 120.60711 13.398...     1
# 2     POLYGON ((120.43443 14.68814, 120.42332 14.685...     2
# 3     MULTIPOLYGON (((121.39392 18.48335, 121.39868 ...     3
# 4     POLYGON ((124.92778 10.66676, 124.92364 10.677...     4
# ...                                                 ...   ...
# 1629  MULTIPOLYGON (((122.06639 6.86972, 122.06639 6...  1629
# 1630  POLYGON ((123.13098 9.06249, 123.13156 9.06276...  1630
# 1631  POLYGON ((120.85121 15.45757, 120.85025 15.455...  1631
# 1632  POLYGON ((122.66113 10.77914, 122.66028 10.779...  1632
# 1633  MULTIPOLYGON (((124.87373 11.62500, 124.87399 ...  1633
#
# [1634 rows x 10 columns]

# %% [markdown]
# Check the shape od our DataFrame.

# %%
gdf.shape
# Out:
# (1634, 10)

# %% [markdown]
# Now we can read in the dataset.

# %%
df = pd.read_csv('../../data/dti-competitive-index/2-merged/complete_dataset.csv')
df
# Out:
#      city_municipality  year accommodation_capacity  \
# 0              Aborlan  2017                 0.0000
# 1              Aborlan  2018                 0.0000
# 2              Aborlan  2019                 0.0000
# 3              Aborlan  2020                 0.0000
# 4              Aborlan  2021                 0.0000
# ...                ...   ...                    ...
# 9787         Zumarraga  2018                 0.0000
# 9788         Zumarraga  2019                 0.0104
# 9789         Zumarraga  2020                 0.0000
# 9790         Zumarraga  2021                 0.0000
# 9791         Zumarraga  2022                    0.0
#
#      active_establishments_in_the_locality annual_disaster_drill  \
# 0                                   0.2120                2.5000
# 1                                   0.2337                0.0000
# 2                                   0.0000                2.2500
# 3                                   0.1653                2.5000
# 4                                   0.2606                1.2542
# ...                                    ...                   ...
# 9787                                0.0004                0.0000
# 9788                                0.0093                2.4107
# 9789                                1.0019                2.5000
# 9790                                0.1886                0.0000
# 9791                                0.2099                   0.0
#
#      availability_of_basic_internet_service availability_of_basic_utilities  \
# 0                                         -                          2.5000
# 1                                         -                          0.0000
# 2                                         -                          2.1047
# 3                                         -                          2.3125
# 4                                         -                          2.2948
# ...                                     ...                             ...
# 9787                                      -                          0.0000
# 9788                                      -                          1.4719
# 9789                                      -                          1.9531
# 9790                                      -                          1.3688
# 9791                                    0.0                          0.2666
#
#      budget_for_drrmp capacity_of_health_services capacity_of_school_services  \
# 0              0.0017                      0.1098                      0.2879
# 1              0.0000                      0.0000                      0.0000
# 2              0.2189                      0.0614                      0.1451
# 3              0.0852                      0.0587                      0.0488
# 4              0.0215                      0.1064                      0.0145
# ...               ...                         ...                         ...
# 9787           0.0000                      0.0000                      0.0000
# 9788           0.0632                      0.0324                      0.2339
# 9789           0.0636                      0.1629                      0.1926
# 9790           0.0039                      0.0830                      0.1112
# 9791           0.0017                      0.0004                       0.008
#
#       ... presence_of_business_and_professional_organizations  \
# 0     ...                                             0.0000
# 1     ...                                             0.0218
# 2     ...                                             0.0007
# 3     ...                                             0.0216
# 4     ...                                             0.1089
# ...   ...                                                ...
# 9787  ...                                             0.0000
# 9788  ...                                             0.0000
# 9789  ...                                             0.0027
# 9790  ...                                             0.0272
# 9791  ...                                                0.0
#
#      presence_of_investment_promotion_unit productivity  \
# 0                                   2.5000       0.0145
# 1                                   0.0000       0.0047
# 2                                   2.5000       0.0004
# 3                                   0.6250       0.0413
# 4                                   1.8750       0.0690
# ...                                    ...          ...
# 9787                                0.0000       0.0000
# 9788                                0.0000       0.0033
# 9789                                1.2500       0.0298
# 9790                                0.6250       0.0000
# 9791                                1.9991       0.0605
#
#      recognition_of_performance road_network safety_compliant_business  \
# 0                        0.2879       0.0000                    0.1943
# 1                        0.0000       0.0000                    0.1253
# 2                        0.0595       0.1006                    0.2553
# 3                        0.0023       0.0006                    0.1643
# 4                        0.0000       0.1846                    0.1683
# ...                         ...          ...                       ...
# 9787                     0.0000       0.0000                    0.0000
# 9788                     0.0000       0.0202                    0.0000
# 9789                     0.2262       0.0024                    0.0000
# 9790                     0.0000       0.0126                    0.0000
# 9791                     0.1042          0.0                       0.0
#
#      sanitary_system social_protection transportation_vehicles utilities
# 0             1.5706            0.1104                  0.0204    0.9949
# 1             0.0000            0.0000                  0.0000    0.0000
# 2             1.4921            0.0007                  0.0029    1.8558
# 3             0.9946            0.0024                  0.0026    1.8706
# 4             1.2502            0.1047                  0.0030    1.2478
# ...              ...               ...                     ...       ...
# 9787          0.0000            0.0000                  0.0000    0.0000
# 9788          1.0144            0.7160                  0.0014    1.8799
# 9789          1.5045            0.1281                  0.0015    1.8754
# 9790          1.2567            1.6311                  0.0034    1.0391
# 9791          1.0002               0.0                   0.002    1.5008
#
# [9792 rows x 42 columns]

# %% [markdown]
# Check the shape od our DataFrame.

# %%
df.shape
# Out:
# (9792, 42)

# %% [markdown]
# Lets have a quick count of the unique city names by using the `len` parameter.

# %%
len(df['city_municipality'].unique())
# Out:
# 1632

# %%
len(gdf['name'].unique())
# Out:
# 1634

# %% [markdown]
# We can see there is a difference, lets have a look why.

# %%
city_list_geo = gdf['name'].unique().tolist()

# %%
city_list = df['city_municipality'].unique().tolist()

# %%
def compare_lists(list1, list2):
    # Make a copy of list1
    differences = list1.copy()
    # Iterate over the elements in list2
    for element in list2:
        # If the element exists in list1, remove it from differences
        if element in differences:
            differences.remove(element)
    # Return the list of differences
    return differences

# %%
differences = compare_lists(city_list_geo, city_list)
print(differences)
# Out:
# ["Brooke's Point", "T'Boli"]

# %% [markdown]
# There are two cities missing from the statistical data **"Brooke's Point"** and **"T'Boli"**.

# %% [markdown]
# ### Merge
# We can now merge the dataframes.

# %%
gdf = gdf.merge(df,
                how="left",
                left_on="name",
                right_on="city_municipality")

# %% [markdown]
# Lets have a look.

# %%
gdf
# Out:
#             psgc       name city_munic province         clean_idx   longitude  \
# 0     1705301000    Aborlan    Aborlan  Palawan  aborlan, palawan  118.548417
# 1     1705301000    Aborlan    Aborlan  Palawan  aborlan, palawan  118.548417
# 2     1705301000    Aborlan    Aborlan  Palawan  aborlan, palawan  118.548417
# 3     1705301000    Aborlan    Aborlan  Palawan  aborlan, palawan  118.548417
# 4     1705301000    Aborlan    Aborlan  Palawan  aborlan, palawan  118.548417
# ...          ...        ...        ...      ...               ...         ...
# 9789   806023000  Zumarraga  Zumarraga    Samar  zumarraga, samar  124.841531
# 9790   806023000  Zumarraga  Zumarraga    Samar  zumarraga, samar  124.841531
# 9791   806023000  Zumarraga  Zumarraga    Samar  zumarraga, samar  124.841531
# 9792   806023000  Zumarraga  Zumarraga    Samar  zumarraga, samar  124.841531
# 9793   806023000  Zumarraga  Zumarraga    Samar  zumarraga, samar  124.841531
#
#        latitude                   coords  \
# 0      9.437101   9.4371009, 118.5484168
# 1      9.437101   9.4371009, 118.5484168
# 2      9.437101   9.4371009, 118.5484168
# 3      9.437101   9.4371009, 118.5484168
# 4      9.437101   9.4371009, 118.5484168
# ...         ...                      ...
# 9789  11.639055  11.6390554, 124.8415308
# 9790  11.639055  11.6390554, 124.8415308
# 9791  11.639055  11.6390554, 124.8415308
# 9792  11.639055  11.6390554, 124.8415308
# 9793  11.639055  11.6390554, 124.8415308
#
#                                                geometry   FID  ...  \
# 0     MULTIPOLYGON (((118.57998 9.37215, 118.57976 9...     0  ...
# 1     MULTIPOLYGON (((118.57998 9.37215, 118.57976 9...     0  ...
# 2     MULTIPOLYGON (((118.57998 9.37215, 118.57976 9...     0  ...
# 3     MULTIPOLYGON (((118.57998 9.37215, 118.57976 9...     0  ...
# 4     MULTIPOLYGON (((118.57998 9.37215, 118.57976 9...     0  ...
# ...                                                 ...   ...  ...
# 9789  MULTIPOLYGON (((124.87373 11.62500, 124.87399 ...  1633  ...
# 9790  MULTIPOLYGON (((124.87373 11.62500, 124.87399 ...  1633  ...
# 9791  MULTIPOLYGON (((124.87373 11.62500, 124.87399 ...  1633  ...
# 9792  MULTIPOLYGON (((124.87373 11.62500, 124.87399 ...  1633  ...
# 9793  MULTIPOLYGON (((124.87373 11.62500, 124.87399 ...  1633  ...
#
#      presence_of_business_and_professional_organizations  \
# 0                                                0.0000
# 1                                                0.0218
# 2                                                0.0007
# 3                                                0.0216
# 4                                                0.1089
# ...                                                 ...
# 9789                                             0.0000
# 9790                                             0.0000
# 9791                                             0.0027
# 9792                                             0.0272
# 9793                                                0.0
#
#       presence_of_investment_promotion_unit productivity  \
# 0                                    2.5000       0.0145
# 1                                    0.0000       0.0047
# 2                                    2.5000       0.0004
# 3                                    0.6250       0.0413
# 4                                    1.8750       0.0690
# ...                                     ...          ...
# 9789                                 0.0000       0.0000
# 9790                                 0.0000       0.0033
# 9791                                 1.2500       0.0298
# 9792                                 0.6250       0.0000
# 9793                                 1.9991       0.0605
#
#      recognition_of_performance road_network safety_compliant_business  \
# 0                        0.2879       0.0000                    0.1943
# 1                        0.0000       0.0000                    0.1253
# 2                        0.0595       0.1006                    0.2553
# 3                        0.0023       0.0006                    0.1643
# 4                        0.0000       0.1846                    0.1683
# ...                         ...          ...                       ...
# 9789                     0.0000       0.0000                    0.0000
# 9790                     0.0000       0.0202                    0.0000
# 9791                     0.2262       0.0024                    0.0000
# 9792                     0.0000       0.0126                    0.0000
# 9793                     0.1042          0.0                       0.0
#
#      sanitary_system social_protection transportation_vehicles utilities
# 0             1.5706            0.1104                  0.0204    0.9949
# 1             0.0000            0.0000                  0.0000    0.0000
# 2             1.4921            0.0007                  0.0029    1.8558
# 3             0.9946            0.0024                  0.0026    1.8706
# 4             1.2502            0.1047                  0.0030    1.2478
# ...              ...               ...                     ...       ...
# 9789          0.0000            0.0000                  0.0000    0.0000
# 9790          1.0144            0.7160                  0.0014    1.8799
# 9791          1.5045            0.1281                  0.0015    1.8754
# 9792          1.2567            1.6311                  0.0034    1.0391
# 9793          1.0002               0.0                   0.002    1.5008
#
# [9794 rows x 52 columns]

# %% [markdown]
# ### Export New DataSet

# %%
gdf.to_csv('complete_dataset_with_geo_data.csv', index=False)
