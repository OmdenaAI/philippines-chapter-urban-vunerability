# %%
import re
from pathlib import Path

import geopandas as gp
import pandas as pd

import folium

# %%
# Setting up directories

WORKINGDIR = Path(os.getcwd())
DATADIR = Path("data", "geolocation")
PROJECTROOT = WORKINGDIR.parents[1]

SHAPEFILE = Path("ph_cities_boundaries", "ph_cities.shp")
COORDSFILE = Path("ph_cities_coordinates", "cities_municipalities_with_coordinates.csv")

# %% [markdown]
# # Helper Functions

# %%
def data_cleaner(text):
    # Make lower caps
    text = text.lower()

    # Remove "city"
    text = text.replace("city", "")

    # Remove " of "
    text = text.replace(" of ", "")

    # Remove punctuation marks
    text = re.sub(r"[^\w\s]", "", text)

    # Remove spaces
    text = text.replace(" ", "")

    # Replace compostela valley with Davao de Oro
    text = text.replace("compostelavalley", "davaodeoro")

    # Replace Maguindanao with del Norte/del Sur
    if "maguindanao" in text:
        text = "maguindanao"

    # Replace North Cotabato with Cotabato
    text = text.replace("northcotabato", "cotabato")

    # Replace santo with sto
    text = text.replace("santo", "sto")

    # Replace santa with sta
    text = text.replace("santa", "sta")

    return text

# %% [markdown]
# # Dataframe for shape/boundaries

# %%
gdf = gp.read_file(Path(PROJECTROOT, DATADIR, SHAPEFILE))
gdf.head()
# Out:
#   NAME_1     NAME_2     ENGTYPE_2  \
# 0   Abra    Bangued  Municipality
# 1   Abra    Boliney  Municipality
# 2   Abra      Bucay  Municipality
# 3   Abra     Bucloc  Municipality
# 4   Abra  Daguioman  Municipality
#
#                                             geometry
# 0  POLYGON ((120.61134 17.49558, 120.60941 17.496...
# 1  POLYGON ((120.81400 17.34210, 120.76862 17.340...
# 2  POLYGON ((120.67766 17.45736, 120.67324 17.469...
# 3  POLYGON ((120.78922 17.44525, 120.80331 17.449...
# 4  POLYGON ((120.90749 17.41933, 120.89281 17.446...

# %%
gdf.plot(legend=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Dataframe for longitude/latitude

# %%
df = pd.read_csv(Path(PROJECTROOT, DATADIR, COORDSFILE))

# Remove unnecessary index column
df.drop(columns=["Unnamed: 0"], inplace=True)

# %%
df.head()
# Out:
#         psgc      province city_municipality                      concat  \
# 0  102801000  Ilocos Norte             Adams          Ilocos Norte|Adams
# 1  102802000  Ilocos Norte           Bacarra        Ilocos Norte|Bacarra
# 2  102803000  Ilocos Norte             Badoc          Ilocos Norte|Badoc
# 3  102804000  Ilocos Norte            Bangui         Ilocos Norte|Bangui
# 4  102805000  Ilocos Norte     City of Batac  Ilocos Norte|City of Batac
#
#     corr_code geog_level old_names city_cls income_cls  urban_rural 2015_pop  \
# 0  12801000.0        Mun       NaN      NaN        5th          NaN    1,792
# 1  12802000.0        Mun       NaN      NaN        3rd          NaN   32,215
# 2  12803000.0        Mun       NaN      NaN        3rd          NaN   31,616
# 3  12804000.0        Mun       NaN      NaN        4th          NaN   14,672
# 4  12805000.0       City       NaN       CC        5th          NaN   55,201
#
#   2015_pop_tag 2020_pop 2020_pop_tag status                  search_term  \
# 0          NaN    2,189          NaN    NaN          Adams, Ilocos Norte
# 1          NaN   33,496          NaN    NaN        Bacarra, Ilocos Norte
# 2          NaN   32,530          NaN    NaN          Badoc, Ilocos Norte
# 3          NaN   15,019          NaN    NaN         Bangui, Ilocos Norte
# 4          NaN   55,484          NaN    NaN  City of Batac, Ilocos Norte
#
#     longitude   latitude
# 0  120.903571  18.461311
# 1  120.610659  18.251738
# 2  120.474089  17.926701
# 3  120.765756  18.536739
# 4  120.581750  18.037300

# %%
df["clean_province"] = df["province"].apply(data_cleaner)
gdf["clean_province"] = gdf["NAME_1"].apply(data_cleaner)

df["clean_city"] = df["city_municipality"].apply(data_cleaner)
gdf["clean_city"] = gdf["NAME_2"].apply(data_cleaner)

# %%
df["clean_index"] = (
    df["clean_city"].astype(str) + ", " + df["clean_province"].astype(str)
)
gdf["clean_index"] = (
    gdf["clean_city"].astype(str) + ", " + gdf["clean_province"].astype(str)
)

# %%
df = df.merge(gdf, how="left", on="clean_index")

# %%
df.loc[df["geometry"].isnull()]
# Out:
#             psgc             province            city_municipality  \
# 106    105530000           Pangasinan                   Pozorrubio
# 270    304917000          Nueva Ecija        Science City of Muñoz
# 404    402123000               Cavite         Gen. Mariano Alvarez
# 542   1705321000              Palawan                     Kalayaan
# 545   1705324000              Palawan            Sofronio Española
# 623    501731000        Camarines Sur                       Sagñay
# 744    603017000               Iloilo                       Dueñas
# 810    701201000                Bohol                 Alburquerque
# 835    701226000                Bohol                       Getafe
# 844    701235000                Bohol   President Carlos P. Garcia
# 877    702220000                 Cebu                      Cordova
# 894    702237000                 Cebu                 Pinamungajan
# 1049   806018000                Samar                   Santo Niño
# 1093   907209000  Zamboanga del Norte                        Piñan
# 1098   907214000  Zamboanga del Norte            Sergio Osmeña Sr.
# 1216  1004210000   Misamis Occidental               City of Ozamiz
# 1255  1102317000      Davao del Norte  Island Garden City of Samal
# 1294  1108601000     Davao Occidental                Don Marcelino
# 1295  1108602000     Davao Occidental             Jose Abad Santos
# 1296  1108603000     Davao Occidental                       Malita
# 1297  1108604000     Davao Occidental                  Santa Maria
# 1298  1108605000     Davao Occidental                    Sarangani
# 1327  1206318000       South Cotabato                   Santo Niño
# 1354  1380100000  Metropolitan Manila             City of Caloocan
# 1525  1900712000              Basilan               Hadji Muhtamad
# 1526  1900713000              Basilan                  Tabuan-Lasa
# 1562  1903637000        Lanao del Sur              Amai Manabilang
# 1585  1906619000                 Sulu                         Omar
# 1612  1908803000  Maguindanao del Sur         Datu Abdullah Sangki
# 1614  1908805000  Maguindanao del Sur         Datu Hoffer Ampatuan
# 1617  1908808000  Maguindanao del Sur                  Datu Salibo
# 1630  1908821000  Maguindanao del Sur     Shariff Saydona Mustapha
#
#                                             concat    corr_code geog_level  \
# 106                          Pangasinan|Pozorrubio   15530000.0        Mun
# 270              Nueva Ecija|Science City of Muñoz   34917000.0       City
# 404                    Cavite|Gen. Mariano Alvarez   42123000.0        Mun
# 542                               Palawan|Kalayaan  175321000.0        Mun
# 545                      Palawan|Sofronio Española  175324000.0        Mun
# 623                           Camarines Sur|Sagñay   51731000.0        Mun
# 744                                  Iloilo|Dueñas   63017000.0        Mun
# 810                             Bohol|Alburquerque   71201000.0        Mun
# 835                                   Bohol|Getafe   71226000.0        Mun
# 844               Bohol|President Carlos P. Garcia   71235000.0        Mun
# 877                                   Cebu|Cordova   72220000.0        Mun
# 894                              Cebu|Pinamungajan   72237000.0        Mun
# 1049                              Samar|Santo Niño   86018000.0        Mun
# 1093                     Zamboanga del Norte|Piñan   97209000.0        Mun
# 1098         Zamboanga del Norte|Sergio Osmeña Sr.   97214000.0        Mun
# 1216             Misamis Occidental|City of Ozamiz  104210000.0       City
# 1255   Davao del Norte|Island Garden City of Samal  112317000.0       City
# 1294                Davao Occidental|Don Marcelino  118601000.0        Mun
# 1295             Davao Occidental|Jose Abad Santos  118602000.0        Mun
# 1296                       Davao Occidental|Malita  118603000.0        Mun
# 1297                  Davao Occidental|Santa Maria  118604000.0        Mun
# 1298                    Davao Occidental|Sarangani  118605000.0        Mun
# 1327                     South Cotabato|Santo Niño  126318000.0        Mun
# 1354          Metropolitan Manila|City of Caloocan  137501000.0       City
# 1525                        Basilan|Hadji Muhtamad  150712000.0        Mun
# 1526                           Basilan|Tabuan-Lasa  150713000.0        Mun
# 1562                 Lanao del Sur|Amai Manabilang  153637000.0        Mun
# 1585                                     Sulu|Omar  156619000.0        Mun
# 1612      Maguindanao del Sur|Datu Abdullah Sangki  153828000.0        Mun
# 1614      Maguindanao del Sur|Datu Hoffer Ampatuan  153835000.0        Mun
# 1617               Maguindanao del Sur|Datu Salibo  153836000.0        Mun
# 1630  Maguindanao del Sur|Shariff Saydona Mustapha  153837000.0        Mun
#
#       old_names city_cls income_cls  urban_rural  ...   latitude  \
# 106         NaN      NaN        1st          NaN  ...  16.110281
# 270         NaN       CC        4th          NaN  ...  15.713541
# 404         NaN      NaN        1st          NaN  ...  14.295648
# 542         NaN      NaN        5th          NaN  ...   9.742915
# 545         NaN      NaN        2nd          NaN  ...   8.958755
# 623         NaN      NaN        4th          NaN  ...  13.603393
# 744         NaN      NaN        4th          NaN  ...  11.066244
# 810         NaN      NaN        5th          NaN  ...   9.610419
# 835         NaN      NaN        3rd          NaN  ...  10.149711
# 844      Pitogo      NaN        4th          NaN  ...  10.120566
# 877         NaN      NaN        3rd          NaN  ...  10.251462
# 894         NaN      NaN        2nd          NaN  ...  10.270094
# 1049        NaN      NaN        5th          NaN  ...  11.973885
# 1093  New Piñan      NaN        4th          NaN  ...   8.481654
# 1098        NaN      NaN        2nd          NaN  ...   8.295667
# 1216        NaN       CC        3rd          NaN  ...   8.147018
# 1255        NaN       CC        4th          NaN  ...   7.078026
# 1294        NaN      NaN        3rd          NaN  ...   6.197851
# 1295   Trinidad      NaN        1st          NaN  ...   5.912649
# 1296        NaN      NaN        1st          NaN  ...   6.414375
# 1297        NaN      NaN        2nd          NaN  ...   6.551019
# 1298        NaN      NaN        4th          NaN  ...   5.412290
# 1327        NaN      NaN        3rd          NaN  ...   6.427948
# 1354        NaN      HUC        1st          NaN  ...  14.756600
# 1525        NaN      NaN          -          NaN  ...   6.659597
# 1526        NaN      NaN          -          NaN  ...   6.316046
# 1562   Bumbaran      NaN        3rd          NaN  ...   7.787288
# 1585        NaN      NaN          -          NaN  ...   6.009757
# 1612        NaN      NaN          -          NaN  ...   6.766656
# 1614        NaN      NaN          -          NaN  ...   6.858064
# 1617        NaN      NaN          -          NaN  ...   6.976731
# 1630        NaN      NaN          -          NaN  ...   6.881631
#
#         clean_province_x            clean_city_x  \
# 106           pangasinan              pozorrubio
# 270           nuevaecija            sciencemuñoz
# 404               cavite       genmarianoalvarez
# 542              palawan                kalayaan
# 545              palawan        sofronioespañola
# 623         camarinessur                  sagñay
# 744               iloilo                  dueñas
# 810                bohol            alburquerque
# 835                bohol                  getafe
# 844                bohol  presidentcarlospgarcia
# 877                 cebu                 cordova
# 894                 cebu            pinamungajan
# 1049               samar                 stoniño
# 1093   zamboangadelnorte                   piñan
# 1098   zamboangadelnorte          sergioosmeñasr
# 1216   misamisoccidental                  ozamiz
# 1255       davaodelnorte       islandgardensamal
# 1294     davaooccidental            donmarcelino
# 1295     davaooccidental            joseabadstos
# 1296     davaooccidental                  malita
# 1297     davaooccidental                stamaria
# 1298     davaooccidental               sarangani
# 1327       southcotabato                 stoniño
# 1354  metropolitanmanila                caloocan
# 1525             basilan           hadjimuhtamad
# 1526             basilan              tabuanlasa
# 1562         lanaodelsur          amaimanabilang
# 1585                sulu                    omar
# 1612         maguindanao      datuabdullahsangki
# 1614         maguindanao      datuhofferampatuan
# 1617         maguindanao              datusalibo
# 1630         maguindanao  shariffsaydonamustapha
#
#                               clean_index NAME_1 NAME_2  ENGTYPE_2  geometry  \
# 106                pozorrubio, pangasinan    NaN    NaN        NaN      None
# 270              sciencemuñoz, nuevaecija    NaN    NaN        NaN      None
# 404             genmarianoalvarez, cavite    NaN    NaN        NaN      None
# 542                     kalayaan, palawan    NaN    NaN        NaN      None
# 545             sofronioespañola, palawan    NaN    NaN        NaN      None
# 623                  sagñay, camarinessur    NaN    NaN        NaN      None
# 744                        dueñas, iloilo    NaN    NaN        NaN      None
# 810                   alburquerque, bohol    NaN    NaN        NaN      None
# 835                         getafe, bohol    NaN    NaN        NaN      None
# 844         presidentcarlospgarcia, bohol    NaN    NaN        NaN      None
# 877                         cordova, cebu    NaN    NaN        NaN      None
# 894                    pinamungajan, cebu    NaN    NaN        NaN      None
# 1049                       stoniño, samar    NaN    NaN        NaN      None
# 1093             piñan, zamboangadelnorte    NaN    NaN        NaN      None
# 1098    sergioosmeñasr, zamboangadelnorte    NaN    NaN        NaN      None
# 1216            ozamiz, misamisoccidental    NaN    NaN        NaN      None
# 1255     islandgardensamal, davaodelnorte    NaN    NaN        NaN      None
# 1294        donmarcelino, davaooccidental    NaN    NaN        NaN      None
# 1295        joseabadstos, davaooccidental    NaN    NaN        NaN      None
# 1296              malita, davaooccidental    NaN    NaN        NaN      None
# 1297            stamaria, davaooccidental    NaN    NaN        NaN      None
# 1298           sarangani, davaooccidental    NaN    NaN        NaN      None
# 1327               stoniño, southcotabato    NaN    NaN        NaN      None
# 1354         caloocan, metropolitanmanila    NaN    NaN        NaN      None
# 1525               hadjimuhtamad, basilan    NaN    NaN        NaN      None
# 1526                  tabuanlasa, basilan    NaN    NaN        NaN      None
# 1562          amaimanabilang, lanaodelsur    NaN    NaN        NaN      None
# 1585                           omar, sulu    NaN    NaN        NaN      None
# 1612      datuabdullahsangki, maguindanao    NaN    NaN        NaN      None
# 1614      datuhofferampatuan, maguindanao    NaN    NaN        NaN      None
# 1617              datusalibo, maguindanao    NaN    NaN        NaN      None
# 1630  shariffsaydonamustapha, maguindanao    NaN    NaN        NaN      None
#
#      clean_province_y clean_city_y
# 106               NaN          NaN
# 270               NaN          NaN
# 404               NaN          NaN
# 542               NaN          NaN
# 545               NaN          NaN
# 623               NaN          NaN
# 744               NaN          NaN
# 810               NaN          NaN
# 835               NaN          NaN
# 844               NaN          NaN
# 877               NaN          NaN
# 894               NaN          NaN
# 1049              NaN          NaN
# 1093              NaN          NaN
# 1098              NaN          NaN
# 1216              NaN          NaN
# 1255              NaN          NaN
# 1294              NaN          NaN
# 1295              NaN          NaN
# 1296              NaN          NaN
# 1297              NaN          NaN
# 1298              NaN          NaN
# 1327              NaN          NaN
# 1354              NaN          NaN
# 1525              NaN          NaN
# 1526              NaN          NaN
# 1562              NaN          NaN
# 1585              NaN          NaN
# 1612              NaN          NaN
# 1614              NaN          NaN
# 1617              NaN          NaN
# 1630              NaN          NaN
#
# [32 rows x 27 columns]

# %%
# This is a df that contains matches that I had to do manually
df_nulls = pd.read_csv("conflict_index.csv")
df_nulls
# Out:
#     df_index                         name  gdf_index
# 0        810                 Alburquerque      206.0
# 1       1562              Amai Manabilang      808.0
# 2       1354             City of Caloocan      945.0
# 3       1216               City of Ozamiz      972.0
# 4        877                      Cordova      453.0
# 5       1612         Datu Abdullah Sangki      889.0
# 6       1614         Datu Hoffer Ampatuan        NaN
# 7       1617                  Datu Salibo        NaN
# 8       1294                Don Marcelino      512.0
# 9        744                       Dueñas      654.0
# 10       404         Gen. Mariano Alvarez      418.0
# 11       835                       Getafe      232.0
# 12      1525               Hadji Muhtamad        NaN
# 13      1255  Island Garden City of Samal        NaN
# 14      1295             Jose Abad Santos      514.0
# 15       542                     Kalayaan        NaN
# 16      1296                       Malita      518.0
# 17      1585                         Omar        NaN
# 18       894                 Pinamungajan      470.0
# 19      1093                        Piñan     1571.0
# 20       106                   Pozorrubio     1262.0
# 21       844   President Carlos P. Garcia      241.0
# 22       623                       Sagñay      371.0
# 23      1297                  Santa Maria      522.0
# 24      1327                   Santo Nino     1419.0
# 25      1049                   Santo Nino     1379.0
# 26      1298                    Sarangani      523.0
# 27       270        Science City of Muñoz     1130.0
# 28      1098            Sergio Osmeña Sr.     1576.0
# 29      1630     Shariff Saydona Mustapha        NaN
# 30       545            Sofronio Española     1208.0
# 31      1526                  Tabuan-Lasa        NaN

# %%
gdf_cols = [
    "NAME_1",
    "NAME_2",
    "ENGTYPE_2",
    "geometry",
]

# %%
non_nulls = df_nulls.loc[~df_nulls["gdf_index"].isnull()]
non_nulls
# Out:
#     df_index                        name  gdf_index
# 0        810                Alburquerque      206.0
# 1       1562             Amai Manabilang      808.0
# 2       1354            City of Caloocan      945.0
# 3       1216              City of Ozamiz      972.0
# 4        877                     Cordova      453.0
# 5       1612        Datu Abdullah Sangki      889.0
# 8       1294               Don Marcelino      512.0
# 9        744                      Dueñas      654.0
# 10       404        Gen. Mariano Alvarez      418.0
# 11       835                      Getafe      232.0
# 14      1295            Jose Abad Santos      514.0
# 16      1296                      Malita      518.0
# 18       894                Pinamungajan      470.0
# 19      1093                       Piñan     1571.0
# 20       106                  Pozorrubio     1262.0
# 21       844  President Carlos P. Garcia      241.0
# 22       623                      Sagñay      371.0
# 23      1297                 Santa Maria      522.0
# 24      1327                  Santo Nino     1419.0
# 25      1049                  Santo Nino     1379.0
# 26      1298                   Sarangani      523.0
# 27       270       Science City of Muñoz     1130.0
# 28      1098           Sergio Osmeña Sr.     1576.0
# 30       545           Sofronio Española     1208.0

# %%
non_nulls["df_index"]
# Out:
# 0      810
# 1     1562
# 2     1354
# 3     1216
# 4      877
# 5     1612
# 8     1294
# 9      744
# 10     404
# 11     835
# 14    1295
# 16    1296
# 18     894
# 19    1093
# 20     106
# 21     844
# 22     623
# 23    1297
# 24    1327
# 25    1049
# 26    1298
# 27     270
# 28    1098
# 30     545
# Name: df_index, dtype: int64

# %%
for df_index in non_nulls["df_index"]:
    gdf_index = int(
        non_nulls["gdf_index"].loc[non_nulls["df_index"] == df_index].values[0]
    )

    for col in gdf_cols:
        df[col].iat[df_index] = gdf[col].iat[gdf_index]

# %%
df.loc[df["geometry"].isnull()]
# Out:
#             psgc             province            city_municipality  \
# 542   1705321000              Palawan                     Kalayaan
# 1255  1102317000      Davao del Norte  Island Garden City of Samal
# 1525  1900712000              Basilan               Hadji Muhtamad
# 1526  1900713000              Basilan                  Tabuan-Lasa
# 1585  1906619000                 Sulu                         Omar
# 1614  1908805000  Maguindanao del Sur         Datu Hoffer Ampatuan
# 1617  1908808000  Maguindanao del Sur                  Datu Salibo
# 1630  1908821000  Maguindanao del Sur     Shariff Saydona Mustapha
#
#                                             concat    corr_code geog_level  \
# 542                               Palawan|Kalayaan  175321000.0        Mun
# 1255   Davao del Norte|Island Garden City of Samal  112317000.0       City
# 1525                        Basilan|Hadji Muhtamad  150712000.0        Mun
# 1526                           Basilan|Tabuan-Lasa  150713000.0        Mun
# 1585                                     Sulu|Omar  156619000.0        Mun
# 1614      Maguindanao del Sur|Datu Hoffer Ampatuan  153835000.0        Mun
# 1617               Maguindanao del Sur|Datu Salibo  153836000.0        Mun
# 1630  Maguindanao del Sur|Shariff Saydona Mustapha  153837000.0        Mun
#
#      old_names city_cls income_cls  urban_rural  ...  latitude  \
# 542        NaN      NaN        5th          NaN  ...  9.742915
# 1255       NaN       CC        4th          NaN  ...  7.078026
# 1525       NaN      NaN          -          NaN  ...  6.659597
# 1526       NaN      NaN          -          NaN  ...  6.316046
# 1585       NaN      NaN          -          NaN  ...  6.009757
# 1614       NaN      NaN          -          NaN  ...  6.858064
# 1617       NaN      NaN          -          NaN  ...  6.976731
# 1630       NaN      NaN          -          NaN  ...  6.881631
#
#      clean_province_x            clean_city_x  \
# 542           palawan                kalayaan
# 1255    davaodelnorte       islandgardensamal
# 1525          basilan           hadjimuhtamad
# 1526          basilan              tabuanlasa
# 1585             sulu                    omar
# 1614      maguindanao      datuhofferampatuan
# 1617      maguindanao              datusalibo
# 1630      maguindanao  shariffsaydonamustapha
#
#                               clean_index NAME_1 NAME_2  ENGTYPE_2  geometry  \
# 542                     kalayaan, palawan    NaN    NaN        NaN      None
# 1255     islandgardensamal, davaodelnorte    NaN    NaN        NaN      None
# 1525               hadjimuhtamad, basilan    NaN    NaN        NaN      None
# 1526                  tabuanlasa, basilan    NaN    NaN        NaN      None
# 1585                           omar, sulu    NaN    NaN        NaN      None
# 1614      datuhofferampatuan, maguindanao    NaN    NaN        NaN      None
# 1617              datusalibo, maguindanao    NaN    NaN        NaN      None
# 1630  shariffsaydonamustapha, maguindanao    NaN    NaN        NaN      None
#
#      clean_province_y clean_city_y
# 542               NaN          NaN
# 1255              NaN          NaN
# 1525              NaN          NaN
# 1526              NaN          NaN
# 1585              NaN          NaN
# 1614              NaN          NaN
# 1617              NaN          NaN
# 1630              NaN          NaN
#
# [8 rows x 27 columns]

# %%
gdf_ = gp.GeoDataFrame(df)

# %%
keep_cols = [
    "psgc",
    "province",
    "city_municipality",
    "geometry",
    "longitude",
    "latitude",
    "clean_province_x",
    "clean_city_x",
    "clean_index",
]

# %%
gdf_ = gdf_[keep_cols]
gdf_["coords"] = gdf_["latitude"].astype(str) + ", " + gdf_["longitude"].astype(str)

# %%
OUTPUTFILE = Path("ph_cities_joined", "ph_cities.shp")

# %%
rename_dict = {
    "city_municipality": "city_mun",
    "clean_province_x": "clean_prov",
    "clean_city_x": "clean_city",
    "clean_index": "clean_idx",
}

# %%
gdf.rename(columns=rename_dict, inplace=True)

# %%
gdf_.to_file(Path(PROJECTROOT, DATADIR, OUTPUTFILE), index=False)
# Out:
# /var/folders/d8/ppdd00vj50s7x6lk402s3p9h0000gn/T/ipykernel_12102/371977953.py:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf_.to_file(Path(PROJECTROOT, DATADIR, OUTPUTFILE), index=False)

# %%
gdf_ = gp.read_file(Path(PROJECTROOT, DATADIR, OUTPUTFILE))

# %%
gdf_.head()
# Out:
#         psgc      province     city_munic   longitude   latitude   clean_prov  \
# 0  102801000  Ilocos Norte          Adams  120.903571  18.461311  ilocosnorte
# 1  102802000  Ilocos Norte        Bacarra  120.610659  18.251738  ilocosnorte
# 2  102803000  Ilocos Norte          Badoc  120.474089  17.926701  ilocosnorte
# 3  102804000  Ilocos Norte         Bangui  120.765756  18.536739  ilocosnorte
# 4  102805000  Ilocos Norte  City of Batac  120.581750  18.037300  ilocosnorte
#
#   clean_city            clean_inde                   coords  \
# 0      adams    adams, ilocosnorte   18.4613108, 120.903571
# 1    bacarra  bacarra, ilocosnorte  18.2517377, 120.6106589
# 2      badoc    badoc, ilocosnorte  17.9267006, 120.4740893
# 3     bangui   bangui, ilocosnorte  18.5367387, 120.7657563
# 4      batac    batac, ilocosnorte       18.0373, 120.58175
#
#                                             geometry
# 0  POLYGON ((120.96105 18.44746, 120.96137 18.446...
# 1  POLYGON ((120.64023 18.25566, 120.63957 18.254...
# 2  MULTIPOLYGON (((120.54331 17.91912, 120.54858 ...
# 3  POLYGON ((120.79987 18.51717, 120.79823 18.514...
# 4  POLYGON ((120.62589 18.06064, 120.62514 18.058...

# %% [markdown]
# # Mapping

# %%
ph = folium.Map(location=[12.8797,121.7740], tiles="OpenStreetMap", zoom_start=5)
ph
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b430678f78436430f121e9a071e9f3e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b430678f78436430f121e9a071e9f3e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b430678f78436430f121e9a071e9f3e9 = L.map(
#                 &quot;map_b430678f78436430f121e9a071e9f3e9&quot;,
#                 {
#                     center: [12.8797, 121.774],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_abae0d34c81f827d6af89a50501be046 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b430678f78436430f121e9a071e9f3e9);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# add marker one by one on the map
for i in range(0,len(gdf_)):
   folium.Marker(
      location=[gdf_.iloc[i]['latitude'], gdf_.iloc[i]['longitude']],
      popup=gdf_.iloc[i]['city_munic'],
   ).add_to(ph)

# Show the map again
ph
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b430678f78436430f121e9a071e9f3e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b430678f78436430f121e9a071e9f3e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b430678f78436430f121e9a071e9f3e9 = L.map(
#                 &quot;map_b430678f78436430f121e9a071e9f3e9&quot;,
#                 {
#                     center: [12.8797, 121.774],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_abae0d34c81f827d6af89a50501be046 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b430678f78436430f121e9a071e9f3e9);
#
#
#             var marker_856baa16f4699b4535325a061961bd67 = L.marker(
#                 [18.4613108, 120.903571],
#                 {}
#             ).addTo(map_b430678f78436430f121e9a071e9f3e9);
#
#
#         var popup_c8954232900390203597538d3cf00822 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_395c49e1d603605efc8862a6d85ca67b = $(`&lt;div id=&quot;html_395c49e1d603605efc8862a6d85ca67b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adams&lt;/div&gt;`)[0];
#                 popup_c8954232900390203597538d3cf00822.setContent(html_395c49e1d603605efc8862a6d85ca67b);
#
#
#
#         marker_856baa16f4699b4535325a061961bd67.bindPopup(popup_c8954232900390203597538d3cf00822)
#         ;
#
#
#
#
#             var marker_e85bbb22b02c63218b0b65cedc75d8ee = L.marker(
#                 [18.2517377, 120.6106589],
#                 {}
#             ).addTo(map_b430678f78436430f121e9a071e9f3e9);
#
#
#         var popup_54026d163433e16c4a7910192aaace4c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_26cc6a8790aba61b118dfaaa08bddb6e = $(`&lt;div id=&quot;html_26cc6a8790aba61b118dfaaa08bddb6e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bacarra&lt;/div&gt;`)[0];
#                 popup_54026d163433e16c4a7910192aaace4c.setContent(html_26cc6a8790aba61b118dfaaa08bddb6e);
#
#
#
#         marker_e85bbb22b02c63218b0b65cedc75d8ee.bindPopup(popup_54026d163433e16c4a7910192aaace4c)
#         ;
#
#
#
#
#             var marker_6ef1acb65f1f0e5fdbd27437a4a6acf2 = L.marker(
#                 [17.9267006, 120.4740893],
#                 {}
#             ).addTo(map_b430678f78436430f121e9a071e9f3e9);
#
#
#         var popup_fe5da6360b06a7c73a30ce1854dde13d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e1a31145e1c3e485ac8192dee5a10221 = $(`&lt;div id=&quot;html_e1a31145e1c3e485ac8192dee5a10221&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Badoc&lt;/div&gt;`)[0];
#                 popup_fe5da6360b06a7c73a30ce1854dde13d.setContent(html_e1a31145e1c3e485ac8192dee5a10221);
#
#
#
#         marker_6ef1acb65f1f0e5fdbd27437a4a6acf2.bindPopup(popup_fe5da6360b06a7c73a30ce1854dde13d)
#         ;
#
#
#
#
#             var marker_a45844557b20fbfcbc2131baeb72e8b3 = L.marker(
#                 [18.5367387, 120.7657563],
#                 {}
#             ).addTo(map_b430678f78436430f121e9a071e9f3e9);
#
#
#         var popup_9af9f8671aa9122b19c006d705c11b7c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c78c306448146c2c142808e729b114ed = $(`&lt;div id=&quot;html_c78c306448146c2c142808e729b114ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bangui&lt;/div&gt;`)[0];
#                 popup_9af9f8671aa9122b19c006d705c11b7c.setContent(html_c78c306448146c2c142808e729b114ed);
#
#
#
#         marker_a45844557b20fbfcbc2131baeb72e8b3.bindPopup(popup_9af9f8671aa9122b19c006d705c11b7c)
#         ;
#
#
#
#
#             var marker_19f66f0495635129052639163ac5f5c8 = L.marker(
#                 [18.0373, 120.58175],
#                 {}
#             ).addTo(map_b430678f78436430f121e9a071e9f3e9);
#
#
#         var popup_bd46e592106cb9fadc072219febdb746 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f7532df53df8ba8b9f76f948c4436e4a = $(`&lt;div id=&quot;html_f7532df53df8ba8b9f76f948c4436e4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City of Batac&lt;/div&gt;`)[0];
#                 popup_bd46e592106cb9fadc072219febdb746.setContent(html_f7532df53df8ba8b9f76f948c4436e4a);
#
#
#
#         marker_19f66f0495635129052639163ac5f5c8.bindPopup(popup_bd46e592106cb9fadc072219febdb746)
#         ;
#
#
#
#
#             var marker_6f148c2b3dc384961a087871ff4648a8 = L.marker(
#                 [18.5110086, 120.6436311],
#                 {}
#             ).addTo(map_b430678f78436430f121e9a071e9f3e9);
#
#
#         var popup_afe2e08ae71e3fb78475c44732dde1ba = L.popup({&quot;
