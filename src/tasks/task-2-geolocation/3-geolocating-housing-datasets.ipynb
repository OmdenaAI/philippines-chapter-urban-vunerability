# %%
import pandas as pd
import numpy as np
import os
from pathlib import Path
import geopandas as gp
import re

from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# %%
# Setting up directories

WORKINGDIR = Path(os.getcwd())
PROJECTROOT = WORKINGDIR.parents[1]
HOUSING_DATASETS = Path(PROJECTROOT, "data", "gathered-datasets", "housing-census")

# Reference df
COMPLETE_DATASET = Path(PROJECTROOT, "data", "cleaned-datasets","ph-shp-file", "ph-shp-file.shp")

# Housing datasets
LIGHTING_SOURCE = Path(HOUSING_DATASETS, "housing-census-fuel-lighting-2015-flattened.csv")
HOUSETYPE = Path(HOUSING_DATASETS, "housing-census-housetype-2015-flattened.csv")
HOUSING_MATERIAL = Path(HOUSING_DATASETS, "housing-census-housing-material-2015-flattened.csv")
HOUSING_TENURE = Path(HOUSING_DATASETS, "housing-census-housing-tenure-2015-flattened.csv")
WATER_SUPPLY_COOKING = Path(HOUSING_DATASETS, "housing-census-water-supply-cooking-2015-flattened.csv")
WATER_SUPPLY_DRINKING = Path(HOUSING_DATASETS, "housing-census-water-supply-drinking-2015-flattened.csv")

# %%
def data_cleaner(text):
    # Make lower caps
    text = text.lower()

    # Remove "city"
    text = text.replace("city", "")

    # Remove " of "
    text = text.replace(" of ", "")
    
    # Remove all strings within parentheses
    text = text.split(" (")[0]
    
    # Remove (Capital)
    text = text.replace(" (capital)", "")

    # Remove punctuation marks
    text = re.sub(r"[^\w\s]", "", text)

    # Remove spaces
    text = text.replace(" ", "")

    # Replace compostela valley with Davao de Oro
    text = text.replace("compostelavalley", "davaodeoro")

    # Replace Maguindanao with del Norte/del Sur
    if "maguindanao" in text:
        text = "maguindanao"

    # Replace santo with sto
    text = text.replace("santo", "sto")

    # Replace santa with sta
    text = text.replace("santa", "sta")



    return text

# %%
def compare_lists(list1, list2):
    return [element for element in list1 if element not in list2]

# %% [markdown]
# ## Import reference df

# %%
ref_df = gp.read_file(COMPLETE_DATASET)
ref_df.head()
# Out:
#            name    city_munic            province  \
# 0       Aborlan       Aborlan             Palawan
# 1  Abra De Ilog  Abra De Ilog  Occidental Mindoro
# 2        Abucay        Abucay              Bataan
# 3        Abulug        Abulug             Cagayan
# 4        Abuyog        Abuyog               Leyte
#
#                        clean_idx                   coords  \
# 0               aborlan, palawan   9.4371009, 118.5484168
# 1  abradeilog, occidentalmindoro  13.4437209, 120.7268262
# 2                 abucay, bataan  14.7213146, 120.5348704
# 3                abulug, cagayan  18.4434854, 121.4572732
# 4                  abuyog, leyte   10.747102, 125.0114853
#
#                                             geometry
# 0  MULTIPOLYGON (((118.57998 9.37215, 118.57982 9...
# 1  POLYGON ((120.60896 13.35233, 120.60797 13.373...
# 2  POLYGON ((120.45676 14.69671, 120.45620 14.696...
# 3  MULTIPOLYGON (((121.40276 18.40896, 121.40276 ...
# 4  POLYGON ((125.04650 10.56751, 125.04588 10.576...

# %%
ref_df_idx = ref_df.clean_idx.drop_duplicates().unique().tolist()

# %% [markdown]
# ## Lighting source

# %%
lighting_source_df = pd.read_csv(LIGHTING_SOURCE)
lighting_source_df.drop(columns=["Unnamed: 0"], inplace=True)

# %%
lighting_source_df.head()
# Out:
#                   city                    region_name             province  \
# 0       CITY OF MANILA  NCR - National Capital Region  METROPOLITAN MANILA
# 1  CITY OF MANDALUYONG  NCR - National Capital Region  METROPOLITAN MANILA
# 2     CITY OF MARIKINA  NCR - National Capital Region  METROPOLITAN MANILA
# 3        CITY OF PASIG  NCR - National Capital Region  METROPOLITAN MANILA
# 4          QUEZON CITY  NCR - National Capital Region  METROPOLITAN MANILA
#
#    Electricity_count  Kerosene (Gaas)_count  \
# 0           428934.0                 2365.0
# 1            99089.0                  217.0
# 2            96774.0                  488.0
# 3           178773.0                  605.0
# 4           671386.0                 3265.0
#
#    Liquified Petroleum Gas (LPG)_count  \
# 0                               1369.0
# 1                                161.0
# 2                                592.0
# 3                                586.0
# 4                               3687.0
#
#    Oil (vegetable animal and others)_count  Solar panel_count  \
# 0                                     34.0               66.0
# 1                                      6.0              112.0
# 2                                      7.0               24.0
# 3                                      9.0               64.0
# 4                                     99.0              249.0
#
#    Solar lamp_count  Others_count  None_count  Not Reported_count  year
# 0              98.0        1018.0      1012.0               258.0  2015
# 1             491.0         101.0       166.0                13.0  2015
# 2              35.0         264.0        44.0                10.0  2015
# 3             111.0         258.0       163.0                43.0  2015
# 4             247.0        1605.0       604.0              1902.0  2015

# %%
lighting_source_df["clean_province"] = (
    lighting_source_df["province"].apply(data_cleaner)
)

lighting_source_df["clean_city"] = lighting_source_df["city"].apply(
    data_cleaner
)

lighting_source_df["clean_idx"] = (
    lighting_source_df["clean_city"].astype(str)
    + ", "
    + lighting_source_df["clean_province"].astype(str)
)

# %%
lighting_source_df.sort_values("clean_idx")
# Out:
#                 city                      region_name  \
# 613          ABORLAN           REGION IV-B (MIMAROPA)
# 587     ABRA DE ILOG           REGION IV-B (MIMAROPA)
# 319           ABUCAY       REGION III (Central Luzon)
# 225           ABULUG       REGION II (Cagayan Valley)
# 948           ABUYOG    REGION VIII (Eastern Visayas)
# ...              ...                              ...
# 1114  ZAMBOANGA CITY  REGION IX (Zamboanga Peninsula)
# 917     ZAMBOANGUITA     REGION VII (Central Visayas)
# 385         ZARAGOZA       REGION III (Central Luzon)
# 748          ZARRAGA      REGION VI (Western Visayas)
# 1037       ZUMARRAGA    REGION VIII (Eastern Visayas)
#
#                                           province  Electricity_count  \
# 613       PALAWAN (excluding Puerto Princesa City)             5606.0
# 587                             OCCIDENTAL MINDORO             4773.0
# 319                                         BATAAN             9256.0
# 225                                        CAGAYAN             6729.0
# 948                LEYTE (excluding Tacloban City)            11369.0
# ...                                            ...                ...
# 1114  ZAMBOANGA DEL SUR (excluding Zamboanga City)           168368.0
# 917                                NEGROS ORIENTAL             4304.0
# 385                                    NUEVA ECIJA            11438.0
# 748                 ILOILO (excluding Iloilo City)             5544.0
# 1037                         SAMAR (WESTERN SAMAR)             2982.0
#
#       Kerosene (Gaas)_count  Liquified Petroleum Gas (LPG)_count  \
# 613                  1436.0                                  NaN
# 587                  1333.0                                 30.0
# 319                   165.0                                  4.0
# 225                   643.0                                  3.0
# 948                  2062.0                                  7.0
# ...                     ...                                  ...
# 1114                17544.0                                867.0
# 917                  1951.0                                  NaN
# 385                   257.0                                  5.0
# 748                   296.0                                  1.0
# 1037                  309.0                                  4.0
#
#       Oil (vegetable animal and others)_count  Solar panel_count  \
# 613                                       NaN              669.0
# 587                                      18.0               20.0
# 319                                       NaN                1.0
# 225                                       1.0                8.0
# 948                                       NaN               12.0
# ...                                       ...                ...
# 1114                                     33.0             1115.0
# 917                                       2.0              111.0
# 385                                       1.0                3.0
# 748                                       NaN                2.0
# 1037                                      NaN                1.0
#
#       Solar lamp_count  Others_count  None_count  Not Reported_count  year  \
# 613              472.0         111.0         NaN                 NaN  2015
# 587              550.0         578.0        27.0                 NaN  2015
# 319                1.0          19.0         7.0                 NaN  2015
# 225               18.0           3.0         NaN                 NaN  2015
# 948               43.0          10.0         5.0                 NaN  2015
# ...                ...           ...         ...                 ...   ...
# 1114            1765.0         382.0       489.0                 5.0  2015
# 917              212.0          27.0         NaN                 NaN  2015
# 385                4.0          12.0         3.0                 NaN  2015
# 748                3.0           7.0         NaN                 NaN  2015
# 1037               5.0           NaN         1.0                 NaN  2015
#
#          clean_province    clean_city                      clean_idx
# 613             palawan       aborlan               aborlan, palawan
# 587   occidentalmindoro    abradeilog  abradeilog, occidentalmindoro
# 319              bataan        abucay                 abucay, bataan
# 225             cagayan        abulug                abulug, cagayan
# 948               leyte        abuyog                  abuyog, leyte
# ...                 ...           ...                            ...
# 1114    zamboangadelsur     zamboanga     zamboanga, zamboangadelsur
# 917      negrosoriental  zamboanguita   zamboanguita, negrosoriental
# 385          nuevaecija      zaragoza           zaragoza, nuevaecija
# 748              iloilo       zarraga                zarraga, iloilo
# 1037              samar     zumarraga               zumarraga, samar
#
# [1503 rows x 16 columns]

# %%
lighting_source_df_idx = lighting_source_df.clean_idx.drop_duplicates().unique().tolist()

# %%
def quirino_to_isabela(idx):
  to_change = [
    'ramon, quirino',
 'reinamercedes, quirino',
 'roxas, quirino',
 'sanagustin, quirino',
 'sanguillermo, quirino',
 'sanisidro, quirino',
 'sanmanuel, quirino',
 'sanmariano, quirino',
 'sanmateo, quirino',
 'sanpablo, quirino',
 'stamaria, quirino',
 'santiago, quirino',
 'stotomas, quirino',
 'tumauini, quirino',
  ]
  
  if idx in to_change:
    return idx.replace("quirino", "isabela")
  else:
    return idx

# %%
def rizal_to_laguna(idx):
    to_change = [
         'sanpablo, rizal',
 'sanpedro, rizal',
 'stacruz, rizal',
 'stamaria, rizal',
 'starosa, rizal',
 'siniloan, rizal',
 'victoria, rizal',
        
    ]
    
    if idx in to_change:
        return idx.replace("rizal", "laguna")
    else:
        return idx

# %%
def bohol_to_cebu(idx):
    to_change = [
        'cebu, bohol',
 'alcantara, bohol',
 'alcoy, bohol',
 'alegria, bohol',
 'aloguinsan, bohol',
 'argao, bohol',
 'asturias, bohol',
 'badian, bohol',
 'balamban, bohol',
 'bantayan, bohol',
 'barili, bohol',
 'bogo, bohol',
 'boljoon, bohol',
 'borbon, bohol',
 'carcar, bohol',
 'catmon, bohol',
 'compostela, bohol',
 'consolacion, bohol',
 'cordova, bohol',
 'daanbantayan, bohol',
 'dalaguete, bohol',
 'dumanjug, bohol',
 'ginatilan, bohol',
 'liloan, bohol',
 'madridejos, bohol',
 'malabuyoc, bohol',
 'medellin, bohol',
 'minglanilla, bohol',
 'moalboal, bohol',
 'naga, bohol',
 'oslob, bohol',
 'pinamungahan, bohol',
 'poro, bohol',
 'ronda, bohol',
 'samboan, bohol',
 'sanfernando, bohol',
 'sanfrancisco, bohol',
 'sanremigio, bohol',
 'stafe, bohol',
 'stander, bohol',
 'sibonga, bohol',
 'sogod, bohol',
 'tabogon, bohol',
 'tabuelan, bohol',
 'talisay, bohol',
 'toledo, bohol',
 'tuburan, bohol',
 'tudela, bohol',
 'lapulapu, bohol',
 'mandaue, bohol',
    ]
    
    if idx in to_change:
        return idx.replace("bohol", "cebu")
    else:
        return idx

# %%
def replace_idx(idx):
    idx = idx.replace('prescarlospgarcia, bohol',"presidentcarlospgarcia, bohol")
    idx = idx.replace('stonio, samar',"stoniño, samar")
    
    idx = idx.replace('pian, zamboangadelnorte', "piñan, zamboangadelnorte")
    idx = idx.replace('isabela, zamboangasibugay', "isabela, basilan")
    idx = idx.replace('ozamis, misamisoccidental', "ozamiz, misamisoccidental")
    idx = idx.replace('cotabato, sarangani', 'cotabato, maguindanao')
    idx = idx.replace('bumbaran, lanaodelsur',"amaimanabilang, lanaodelsur")
    idx = idx.replace("pinamungahan, cebu", 'pinamungajan, cebu')
 
    return idx

# %%
lighting_source_df["clean_idx"] = lighting_source_df["clean_idx"].apply(bohol_to_cebu).apply(replace_idx).apply(quirino_to_isabela).apply(rizal_to_laguna).apply(bohol_to_cebu)

# %%
lighting_source_df_idx = lighting_source_df.clean_idx.drop_duplicates().unique().tolist()

# %%
not_in_ref = compare_lists(lighting_source_df_idx, ref_df_idx)
not_in_ref
# Out:
# []

# %%
ref_df
# Out:
#               name         city_munic            province  \
# 0          Aborlan            Aborlan             Palawan
# 1     Abra De Ilog       Abra De Ilog  Occidental Mindoro
# 2           Abucay             Abucay              Bataan
# 3           Abulug             Abulug             Cagayan
# 4           Abuyog             Abuyog               Leyte
# ...            ...                ...                 ...
# 1629     Zamboanga  City of Zamboanga   Zamboanga del Sur
# 1630  Zamboanguita       Zamboanguita     Negros Oriental
# 1631      Zaragoza           Zaragoza         Nueva Ecija
# 1632       Zarraga            Zarraga              Iloilo
# 1633     Zumarraga          Zumarraga               Samar
#
#                           clean_idx                   coords  \
# 0                  aborlan, palawan   9.4371009, 118.5484168
# 1     abradeilog, occidentalmindoro  13.4437209, 120.7268262
# 2                    abucay, bataan  14.7213146, 120.5348704
# 3                   abulug, cagayan  18.4434854, 121.4572732
# 4                     abuyog, leyte   10.747102, 125.0114853
# ...                             ...                      ...
# 1629     zamboanga, zamboangadelsur          6.9214, 122.079
# 1630   zamboanguita, negrosoriental   9.1004649, 123.1994244
# 1631           zaragoza, nuevaecija  15.4475833, 120.7935538
# 1632                zarraga, iloilo  10.8223786, 122.6095819
# 1633               zumarraga, samar  11.6390554, 124.8415308
#
#                                                geometry
# 0     MULTIPOLYGON (((118.57998 9.37215, 118.57982 9...
# 1     POLYGON ((120.60896 13.35233, 120.60797 13.373...
# 2     POLYGON ((120.45676 14.69671, 120.45620 14.696...
# 3     MULTIPOLYGON (((121.40276 18.40896, 121.40276 ...
# 4     POLYGON ((125.04650 10.56751, 125.04588 10.576...
# ...                                                 ...
# 1629  MULTIPOLYGON (((122.06639 6.86972, 122.06639 6...
# 1630  POLYGON ((123.20750 9.10485, 123.20722 9.10443...
# 1631  POLYGON ((120.81170 15.47132, 120.81309 15.470...
# 1632  POLYGON ((122.65892 10.79784, 122.65959 10.796...
# 1633  MULTIPOLYGON (((124.87373 11.62500, 124.87370 ...
#
# [1634 rows x 6 columns]

# %%
lighting_source_df = ref_df[["clean_idx", "name"]].merge(lighting_source_df, 
                                                       how='left',
                                                       on='clean_idx')

# %%
lighting_source_df.head(10)
# Out:
#                        clean_idx          name          city  \
# 0               aborlan, palawan       Aborlan       ABORLAN
# 1  abradeilog, occidentalmindoro  Abra De Ilog  ABRA DE ILOG
# 2                 abucay, bataan        Abucay        ABUCAY
# 3                abulug, cagayan        Abulug        ABULUG
# 4                  abuyog, leyte        Abuyog        ABUYOG
# 5             adams, ilocosnorte         Adams         ADAMS
# 6               agdangan, quezon      Agdangan      AGDANGAN
# 7               aglipay, quirino       Aglipay       AGLIPAY
# 8               agno, pangasinan          Agno          AGNO
# 9            agoncillo, batangas     Agoncillo     AGONCILLO
#
#                      region_name                                  province  \
# 0         REGION IV-B (MIMAROPA)  PALAWAN (excluding Puerto Princesa City)
# 1         REGION IV-B (MIMAROPA)                        OCCIDENTAL MINDORO
# 2     REGION III (Central Luzon)                                    BATAAN
# 3     REGION II (Cagayan Valley)                                   CAGAYAN
# 4  REGION VIII (Eastern Visayas)           LEYTE (excluding Tacloban City)
# 5       REGION I (Ilocos Region)                              ILOCOS NORTE
# 6       REGION IV-A (CALABARZON)            QUEZON (excluding Lucena City)
# 7     REGION II (Cagayan Valley)                                   QUIRINO
# 8       REGION I (Ilocos Region)                                PANGASINAN
# 9       REGION IV-A (CALABARZON)                                  BATANGAS
#
#    Electricity_count  Kerosene (Gaas)_count  \
# 0             5606.0                 1436.0
# 1             4773.0                 1333.0
# 2             9256.0                  165.0
# 3             6729.0                  643.0
# 4            11369.0                 2062.0
# 5              366.0                   44.0
# 6             2733.0                  256.0
# 7             5690.0                  754.0
# 8             5730.0                  838.0
# 9             7687.0                   82.0
#
#    Liquified Petroleum Gas (LPG)_count  \
# 0                                  NaN
# 1                                 30.0
# 2                                  4.0
# 3                                  3.0
# 4                                  7.0
# 5                                  NaN
# 6                                  NaN
# 7                                  1.0
# 8                                  2.0
# 9                                  2.0
#
#    Oil (vegetable animal and others)_count  Solar panel_count  \
# 0                                      NaN              669.0
# 1                                     18.0               20.0
# 2                                      NaN                1.0
# 3                                      1.0                8.0
# 4                                      NaN               12.0
# 5                                      NaN                1.0
# 6                                      NaN               33.0
# 7                                      NaN               44.0
# 8                                      1.0                3.0
# 9                                      NaN                1.0
#
#    Solar lamp_count  Others_count  None_count  Not Reported_count    year  \
# 0             472.0         111.0         NaN                 NaN  2015.0
# 1             550.0         578.0        27.0                 NaN  2015.0
# 2               1.0          19.0         7.0                 NaN  2015.0
# 3              18.0           3.0         NaN                 NaN  2015.0
# 4              43.0          10.0         5.0                 NaN  2015.0
# 5               NaN           NaN         NaN                 NaN  2015.0
# 6             135.0          10.0         4.0                 NaN  2015.0
# 7              54.0          29.0         5.0                 NaN  2015.0
# 8               2.0          43.0         5.0                 NaN  2015.0
# 9               1.0          15.0        38.0                 NaN  2015.0
#
#       clean_province  clean_city
# 0            palawan     aborlan
# 1  occidentalmindoro  abradeilog
# 2             bataan      abucay
# 3            cagayan      abulug
# 4              leyte      abuyog
# 5        ilocosnorte       adams
# 6             quezon    agdangan
# 7            quirino     aglipay
# 8         pangasinan        agno
# 9           batangas   agoncillo

# %%
drop_cols =["clean_idx", "region_name", "province", "clean_province", "clean_city"]
lighting_source_df.drop(columns=drop_cols, inplace=True)

lighting_source_df.to_csv(Path(PROJECTROOT, "data", "cleaned-datasets", "housing-census-fuel-lighting-2015.csv"))

# %% [markdown]
# ## Housing material

# %%
housing_matl_df = pd.read_csv(HOUSING_MATERIAL)
housing_matl_df.drop(columns=["Unnamed: 0"], inplace=True)

# %%
housing_matl_df.head(10)
# Out:
#              city                    region_name             province  \
# 0  CITY OF MANILA  NCR - National Capital Region  METROPOLITAN MANILA
# 1  CITY OF MANILA  NCR - National Capital Region  METROPOLITAN MANILA
# 2  CITY OF MANILA  NCR - National Capital Region  METROPOLITAN MANILA
# 3  CITY OF MANILA  NCR - National Capital Region  METROPOLITAN MANILA
# 4  CITY OF MANILA  NCR - National Capital Region  METROPOLITAN MANILA
# 5  CITY OF MANILA  NCR - National Capital Region  METROPOLITAN MANILA
# 6  CITY OF MANILA  NCR - National Capital Region  METROPOLITAN MANILA
# 7  CITY OF MANILA  NCR - National Capital Region  METROPOLITAN MANILA
# 8  CITY OF MANILA  NCR - National Capital Region  METROPOLITAN MANILA
# 9  CITY OF MANILA  NCR - National Capital Region  METROPOLITAN MANILA
#
#    outer_wall_materials                             roof_materials    count  \
# 0  Concrete/brick/stone                   Galvanized iron/aluminum  21164.0
# 1  Concrete/brick/stone                    Tile/concrete/clay tile   3284.0
# 2  Concrete/brick/stone     Half galvanized iron and half concrete      4.0
# 3  Concrete/brick/stone                  Bamboo/cogon/ nipa/anahaw     55.0
# 4  Concrete/brick/stone                                   Asbestos     19.0
# 5  Concrete/brick/stone  Makeshift/ salvaged/ improvised materials     42.0
# 6  Concrete/brick/stone                                     Trapal     75.0
# 7  Concrete/brick/stone                                     Others      NaN
# 8  Concrete/brick/stone                               Not Reported      NaN
# 9                  Wood                   Galvanized iron/aluminum   1168.0
#
#    year
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015
# 5  2015
# 6  2015
# 7  2015
# 8  2015
# 9  2015

# %%
housing_matl_df = housing_matl_df.loc[~housing_matl_df["province"].isnull()]
housing_matl_df = housing_matl_df.loc[~housing_matl_df["city"].isnull()]

# %%
housing_matl_df["clean_province"] = (
    housing_matl_df["province"].apply(data_cleaner)
)

housing_matl_df["clean_city"] = housing_matl_df["city"].apply(
    data_cleaner
)

housing_matl_df["clean_idx"] = (
    housing_matl_df["clean_city"].astype(str)
    + ", "
    + housing_matl_df["clean_province"].astype(str)
)

# %%
housing_matl_df["clean_idx"] = housing_matl_df["clean_idx"].apply(bohol_to_cebu).apply(replace_idx).apply(quirino_to_isabela).apply(rizal_to_laguna).apply(bohol_to_cebu)

# %%
housing_matl_idx = housing_matl_df.clean_idx.drop_duplicates().unique().tolist()

# %%
not_in_ref = compare_lists(housing_matl_idx, ref_df_idx)
not_in_ref
# Out:
# []

# %%
housing_matl_df = ref_df[["clean_idx", "name"]].merge(housing_matl_df, 
                                                       how='left',
                                                       on='clean_idx')

# %%
housing_matl_df.head(10)
# Out:
#           clean_idx     name     city             region_name  \
# 0  aborlan, palawan  Aborlan  ABORLAN  REGION IV-B (MIMAROPA)
# 1  aborlan, palawan  Aborlan  ABORLAN  REGION IV-B (MIMAROPA)
# 2  aborlan, palawan  Aborlan  ABORLAN  REGION IV-B (MIMAROPA)
# 3  aborlan, palawan  Aborlan  ABORLAN  REGION IV-B (MIMAROPA)
# 4  aborlan, palawan  Aborlan  ABORLAN  REGION IV-B (MIMAROPA)
# 5  aborlan, palawan  Aborlan  ABORLAN  REGION IV-B (MIMAROPA)
# 6  aborlan, palawan  Aborlan  ABORLAN  REGION IV-B (MIMAROPA)
# 7  aborlan, palawan  Aborlan  ABORLAN  REGION IV-B (MIMAROPA)
# 8  aborlan, palawan  Aborlan  ABORLAN  REGION IV-B (MIMAROPA)
# 9  aborlan, palawan  Aborlan  ABORLAN  REGION IV-B (MIMAROPA)
#
#                                    province  outer_wall_materials  \
# 0  PALAWAN (excluding Puerto Princesa City)  Concrete/brick/stone
# 1  PALAWAN (excluding Puerto Princesa City)  Concrete/brick/stone
# 2  PALAWAN (excluding Puerto Princesa City)  Concrete/brick/stone
# 3  PALAWAN (excluding Puerto Princesa City)  Concrete/brick/stone
# 4  PALAWAN (excluding Puerto Princesa City)  Concrete/brick/stone
# 5  PALAWAN (excluding Puerto Princesa City)  Concrete/brick/stone
# 6  PALAWAN (excluding Puerto Princesa City)  Concrete/brick/stone
# 7  PALAWAN (excluding Puerto Princesa City)  Concrete/brick/stone
# 8  PALAWAN (excluding Puerto Princesa City)  Concrete/brick/stone
# 9  PALAWAN (excluding Puerto Princesa City)                  Wood
#
#                               roof_materials  count    year clean_province  \
# 0                   Galvanized iron/aluminum   11.0  2015.0        palawan
# 1                    Tile/concrete/clay tile    7.0  2015.0        palawan
# 2     Half galvanized iron and half concrete   11.0  2015.0        palawan
# 3                  Bamboo/cogon/ nipa/anahaw    NaN  2015.0        palawan
# 4                                   Asbestos    NaN  2015.0        palawan
# 5  Makeshift/ salvaged/ improvised materials    NaN  2015.0        palawan
# 6                                     Trapal    NaN  2015.0        palawan
# 7                                     Others    NaN  2015.0        palawan
# 8                               Not Reported    NaN  2015.0        palawan
# 9                   Galvanized iron/aluminum    NaN  2015.0        palawan
#
#   clean_city
# 0    aborlan
# 1    aborlan
# 2    aborlan
# 3    aborlan
# 4    aborlan
# 5    aborlan
# 6    aborlan
# 7    aborlan
# 8    aborlan
# 9    aborlan

# %%
housing_matl_df.drop(columns=drop_cols, inplace=True)

housing_matl_df.to_csv(Path(PROJECTROOT, "data", "cleaned-datasets", "housing-census-housing-material-2015.csv"))

# %% [markdown]
# ## Housing tenure

# %%
housing_tenure_df = pd.read_csv(HOUSING_TENURE)
housing_tenure_df.drop(columns=["Unnamed: 0"], inplace=True)

# %%
housing_tenure_df.head(10)
# Out:
#              city                    region_name              province  \
# 0  CITY OF MANILA  NCR - National Capital Region   METROPOLITAN MANILA
# 1  CITY OF MANILA  NCR - National Capital Region   METROPOLITAN MANILA
# 2  CITY OF MANILA  NCR - National Capital Region   METROPOLITAN MANILA
# 3  CITY OF MANILA  NCR - National Capital Region   METROPOLITAN MANILA
# 4  CITY OF MANILA  NCR - National Capital Region   METROPOLITAN MANILA
# 5  CITY OF MANILA  NCR - National Capital Region   METROPOLITAN MANILA
# 6  CITY OF MANILA  NCR - National Capital Region   METROPOLITAN MANILA
# 7  CITY OF MANILA  NCR - National Capital Region   METROPOLITAN MANILA
# 8  CITY OF MANILA  NCR - National Capital Region   METROPOLITAN MANILA
# 9  CITY OF MANILA  NCR - National Capital Region   METROPOLITAN MANILA
#
#                                      tenure_type  \
# 0  Own or owner like possession of house and lot
# 1  Own or owner like possession of house and lot
# 2  Own or owner like possession of house and lot
# 3  Own or owner like possession of house and lot
# 4  Own or owner like possession of house and lot
# 5  Own or owner like possession of house and lot
# 6  Own or owner like possession of house and lot
# 7                  Rent house/room including lot
# 8                  Rent house/room including lot
# 9                  Rent house/room including lot
#
#                               bldg_type     count  year
# 0                          Single house   57658.0  2015
# 1                                Duplex   27215.0  2015
# 2                Multi-unit residential   78569.0  2015
# 3  Commercial/ industrial/ agricultural     426.0  2015
# 4          Institutional living quarter      24.0  2015
# 5                                Others     158.0  2015
# 6                          Not Reported     354.0  2015
# 7                          Single house   34840.0  2015
# 8                                Duplex   21217.0  2015
# 9                Multi-unit residential  130042.0  2015

# %%
housing_tenure_df = housing_tenure_df.loc[~housing_tenure_df["province"].isnull()]
housing_tenure_df = housing_tenure_df.loc[~housing_tenure_df["city"].isnull()]

# %%
housing_tenure_df["clean_province"] = (
    housing_tenure_df["province"].apply(data_cleaner)
)

housing_tenure_df["clean_city"] = housing_tenure_df["city"].apply(
    data_cleaner
)

housing_tenure_df["clean_idx"] = (
    housing_tenure_df["clean_city"].astype(str)
    + ", "
    + housing_tenure_df["clean_province"].astype(str)
)

# %%
housing_tenure_df["clean_idx"] = housing_tenure_df["clean_idx"].apply(bohol_to_cebu).apply(replace_idx).apply(quirino_to_isabela).apply(rizal_to_laguna).apply(bohol_to_cebu)

# %%
housing_tenure_idx = housing_tenure_df.clean_idx.drop_duplicates().unique().tolist()

# %%
not_in_ref = compare_lists(housing_tenure_idx, ref_df_idx)
not_in_ref
# Out:
# ['997, zamboangasibugay']

# %%
housing_tenure_df = ref_df[["clean_idx", "name"]].merge(housing_tenure_df, 
                                                       how='left',
                                                       on='clean_idx')

# %%
housing_tenure_df.head(10)
# Out:
#           clean_idx     name     city             region_name  \
# 0  aborlan, palawan  Aborlan  ABORLAN  REGION IV-B (MIMAROPA)
# 1  aborlan, palawan  Aborlan  ABORLAN  REGION IV-B (MIMAROPA)
# 2  aborlan, palawan  Aborlan  ABORLAN  REGION IV-B (MIMAROPA)
# 3  aborlan, palawan  Aborlan  ABORLAN  REGION IV-B (MIMAROPA)
# 4  aborlan, palawan  Aborlan  ABORLAN  REGION IV-B (MIMAROPA)
# 5  aborlan, palawan  Aborlan  ABORLAN  REGION IV-B (MIMAROPA)
# 6  aborlan, palawan  Aborlan  ABORLAN  REGION IV-B (MIMAROPA)
# 7  aborlan, palawan  Aborlan  ABORLAN  REGION IV-B (MIMAROPA)
# 8  aborlan, palawan  Aborlan  ABORLAN  REGION IV-B (MIMAROPA)
# 9  aborlan, palawan  Aborlan  ABORLAN  REGION IV-B (MIMAROPA)
#
#                                     province  \
# 0   PALAWAN (excluding Puerto Princesa City)
# 1   PALAWAN (excluding Puerto Princesa City)
# 2   PALAWAN (excluding Puerto Princesa City)
# 3   PALAWAN (excluding Puerto Princesa City)
# 4   PALAWAN (excluding Puerto Princesa City)
# 5   PALAWAN (excluding Puerto Princesa City)
# 6   PALAWAN (excluding Puerto Princesa City)
# 7   PALAWAN (excluding Puerto Princesa City)
# 8   PALAWAN (excluding Puerto Princesa City)
# 9   PALAWAN (excluding Puerto Princesa City)
#
#                                      tenure_type  \
# 0  Own or owner like possession of house and lot
# 1  Own or owner like possession of house and lot
# 2  Own or owner like possession of house and lot
# 3  Own or owner like possession of house and lot
# 4  Own or owner like possession of house and lot
# 5  Own or owner like possession of house and lot
# 6  Own or owner like possession of house and lot
# 7                  Rent house/room including lot
# 8                  Rent house/room including lot
# 9                  Rent house/room including lot
#
#                               bldg_type   count    year clean_province  \
# 0                          Single house  4785.0  2015.0        palawan
# 1                                Duplex   118.0  2015.0        palawan
# 2                Multi-unit residential    61.0  2015.0        palawan
# 3  Commercial/ industrial/ agricultural     1.0  2015.0        palawan
# 4          Institutional living quarter     NaN  2015.0        palawan
# 5                                Others     NaN  2015.0        palawan
# 6                          Not Reported     3.0  2015.0        palawan
# 7                          Single house   130.0  2015.0        palawan
# 8                                Duplex    56.0  2015.0        palawan
# 9                Multi-unit residential   233.0  2015.0        palawan
#
#   clean_city
# 0    aborlan
# 1    aborlan
# 2    aborlan
# 3    aborlan
# 4    aborlan
# 5    aborlan
# 6    aborlan
# 7    aborlan
# 8    aborlan
# 9    aborlan

# %%
housing_tenure_df.drop(columns=drop_cols, inplace=True)

housing_tenure_df.to_csv(Path(PROJECTROOT, "data", "cleaned-datasets", "housing-census-housing-tenure-2015.csv"))

# %% [markdown]
# ## Water supply for cooking

# %%
water_cooking_df = pd.read_csv(WATER_SUPPLY_COOKING)
water_cooking_df.drop(columns=["Unnamed: 0"], inplace=True)

# %%
water_cooking_df.head(10)
# Out:
#                   city                    region_name             province  \
# 0       CITY OF MANILA  NCR - National Capital Region  METROPOLITAN MANILA
# 1  CITY OF MANDALUYONG  NCR - National Capital Region  METROPOLITAN MANILA
# 2     CITY OF MARIKINA  NCR - National Capital Region  METROPOLITAN MANILA
# 3        CITY OF PASIG  NCR - National Capital Region  METROPOLITAN MANILA
# 4          QUEZON CITY  NCR - National Capital Region  METROPOLITAN MANILA
# 5     CITY OF SAN JUAN  NCR - National Capital Region  METROPOLITAN MANILA
# 6        CALOOCAN CITY  NCR - National Capital Region  METROPOLITAN MANILA
# 7      CITY OF MALABON  NCR - National Capital Region  METROPOLITAN MANILA
# 8      CITY OF NAVOTAS  NCR - National Capital Region  METROPOLITAN MANILA
# 9   CITY OF VALENZUELA  NCR - National Capital Region  METROPOLITAN MANILA
#
#    Own use faucet community water system_count  \
# 0                                     347935.0
# 1                                      89749.0
# 2                                      89537.0
# 3                                     162226.0
# 4                                     561729.0
# 5                                      24496.0
# 6                                     283142.0
# 7                                      62428.0
# 8                                      42529.0
# 9                                     111294.0
#
#    Shared faucet community water system_count  \
# 0                                     69597.0
# 1                                      7551.0
# 2                                      6991.0
# 3                                     13063.0
# 4                                    102919.0
# 5                                      3008.0
# 6                                     66524.0
# 7                                     19561.0
# 8                                     13190.0
# 9                                     31136.0
#
#    Own use tubed/piped deep well_count  Shared tubed/piped deep well_count  \
# 0                               1181.0                              1488.0
# 1                                107.0                               254.0
# 2                                290.0                               389.0
# 3                                197.0                               435.0
# 4                               2375.0                              3006.0
# 5                                  NaN                                 NaN
# 6                               5172.0                              5595.0
# 7                                412.0                               416.0
# 8                                 73.0                               367.0
# 9                               2056.0                              3234.0
#
#    Tubed/piped shallow well_count  Dug well_count  Protected spring_count  \
# 0                           100.0            48.0                   233.0
# 1                            55.0             1.0                    36.0
# 2                            14.0            16.0                    91.0
# 3                            94.0            34.0                    43.0
# 4                           334.0           343.0                   293.0
# 5                             NaN             NaN                     NaN
# 6                           191.0           290.0                    15.0
# 7                            18.0            11.0                     NaN
# 8                            28.0             3.0                    60.0
# 9                            33.0           309.0                     NaN
#
#    Unprotected spring_count  Lake river rain and others_count  Peddler_count  \
# 0                       9.0                              13.0         9313.0
# 1                       2.0                               NaN          875.0
# 2                       NaN                               NaN          224.0
# 3                       NaN                               NaN         1321.0
# 4                       4.0                              17.0         4548.0
# 5                       NaN                               NaN          783.0
# 6                       NaN                               NaN         2740.0
# 7                       NaN                               NaN         1728.0
# 8                       NaN                               1.0         3864.0
# 9                       NaN                               NaN         2352.0
#
#    Bottled water_count  Others_count  Not Reported_count  year
# 0               5068.0         169.0                 NaN  2015
# 1               1637.0          89.0                 NaN  2015
# 2                657.0          29.0                 NaN  2015
# 3               2954.0         245.0                 NaN  2015
# 4               6572.0         904.0                 NaN  2015
# 5                336.0           NaN                 NaN  2015
# 6               3974.0         235.0                 NaN  2015
# 7               1575.0          42.0                 NaN  2015
# 8                785.0           4.0                 NaN  2015
# 9               2582.0          45.0                 NaN  2015

# %%
water_cooking_df = water_cooking_df.loc[~water_cooking_df["province"].isnull()]
water_cooking_df = water_cooking_df.loc[~water_cooking_df["city"].isnull()]

# %%
water_cooking_df["clean_province"] = (
    water_cooking_df["province"].apply(data_cleaner)
)

water_cooking_df["clean_city"] = water_cooking_df["city"].apply(
    data_cleaner
)

water_cooking_df["clean_idx"] = (
    water_cooking_df["clean_city"].astype(str)
    + ", "
    + water_cooking_df["clean_province"].astype(str)
)

# %%
water_cooking_df["clean_idx"] = water_cooking_df["clean_idx"].apply(bohol_to_cebu).apply(replace_idx).apply(quirino_to_isabela).apply(rizal_to_laguna).apply(bohol_to_cebu)

# %%
water_cooking_idx = water_cooking_df.clean_idx.drop_duplicates().unique().tolist()

# %%
not_in_ref = compare_lists(water_cooking_idx, ref_df_idx)
not_in_ref
# Out:
# []

# %%
water_cooking_df = ref_df[["clean_idx", "name"]].merge(water_cooking_df, 
                                                       how='left',
                                                       on='clean_idx')

# %%
water_cooking_df.head(10)
# Out:
#                        clean_idx          name          city  \
# 0               aborlan, palawan       Aborlan       ABORLAN
# 1  abradeilog, occidentalmindoro  Abra De Ilog  ABRA DE ILOG
# 2                 abucay, bataan        Abucay        ABUCAY
# 3                abulug, cagayan        Abulug        ABULUG
# 4                  abuyog, leyte        Abuyog        ABUYOG
# 5             adams, ilocosnorte         Adams         ADAMS
# 6               agdangan, quezon      Agdangan      AGDANGAN
# 7               aglipay, quirino       Aglipay       AGLIPAY
# 8               agno, pangasinan          Agno          AGNO
# 9            agoncillo, batangas     Agoncillo     AGONCILLO
#
#                      region_name                                  province  \
# 0         REGION IV-B (MIMAROPA)  PALAWAN (excluding Puerto Princesa City)
# 1         REGION IV-B (MIMAROPA)                        OCCIDENTAL MINDORO
# 2     REGION III (Central Luzon)                                    BATAAN
# 3     REGION II (Cagayan Valley)                                   CAGAYAN
# 4  REGION VIII (Eastern Visayas)           LEYTE (excluding Tacloban City)
# 5       REGION I (Ilocos Region)                              ILOCOS NORTE
# 6       REGION IV-A (CALABARZON)            QUEZON (excluding Lucena City)
# 7     REGION II (Cagayan Valley)                                   QUIRINO
# 8       REGION I (Ilocos Region)                                PANGASINAN
# 9       REGION IV-A (CALABARZON)                                  BATANGAS
#
#    Own use faucet community water system_count  \
# 0                                       2447.0
# 1                                       1282.0
# 2                                       1146.0
# 3                                        632.0
# 4                                        806.0
# 5                                        380.0
# 6                                        374.0
# 7                                        450.0
# 8                                        411.0
# 9                                       6071.0
#
#    Shared faucet community water system_count  \
# 0                                      1564.0
# 1                                       461.0
# 2                                      1518.0
# 3                                       273.0
# 4                                      3322.0
# 5                                        31.0
# 6                                       716.0
# 7                                       256.0
# 8                                       105.0
# 9                                       606.0
#
#    Own use tubed/piped deep well_count  Shared tubed/piped deep well_count  \
# 0                               1007.0                              2060.0
# 1                                917.0                              2612.0
# 2                                628.0                              5777.0
# 3                               2274.0                              1987.0
# 4                                947.0                              3260.0
# 5                                  NaN                                 NaN
# 6                                339.0                              1340.0
# 7                               1473.0                              2512.0
# 8                               1432.0                              1231.0
# 9                                253.0                               615.0
#
#    Tubed/piped shallow well_count  ...  Protected spring_count  \
# 0                           413.0  ...                   150.0
# 1                           848.0  ...                   538.0
# 2                            33.0  ...                   129.0
# 3                           236.0  ...                     NaN
# 4                           153.0  ...                  1779.0
# 5                             NaN  ...                     NaN
# 6                            80.0  ...                     1.0
# 7                           659.0  ...                   461.0
# 8                            60.0  ...                   257.0
# 9                           200.0  ...                     NaN
#
#    Unprotected spring_count  Lake river rain and others_count  Peddler_count  \
# 0                      13.0                             101.0            4.0
# 1                     197.0                             174.0            NaN
# 2                       NaN                              12.0            1.0
# 3                       1.0                               NaN            NaN
# 4                     499.0                               9.0           50.0
# 5                       NaN                               NaN            NaN
# 6                       6.0                              34.0            3.0
# 7                     594.0                               1.0            2.0
# 8                      54.0                              14.0            NaN
# 9                       NaN                              43.0            NaN
#
#    Bottled water_count  Others_count  Not Reported_count    year  \
# 0                 11.0           NaN                 NaN  2015.0
# 1                  NaN           1.0                 NaN  2015.0
# 2                203.0           2.0                 NaN  2015.0
# 3                 73.0           NaN                 NaN  2015.0
# 4                275.0           NaN                 NaN  2015.0
# 5                  NaN           NaN                 NaN  2015.0
# 6                 54.0           NaN                 NaN  2015.0
# 7                 28.0           1.0                 NaN  2015.0
# 8                 82.0           1.0                 NaN  2015.0
# 9                 20.0           3.0                 NaN  2015.0
#
#       clean_province  clean_city
# 0            palawan     aborlan
# 1  occidentalmindoro  abradeilog
# 2             bataan      abucay
# 3            cagayan      abulug
# 4              leyte      abuyog
# 5        ilocosnorte       adams
# 6             quezon    agdangan
# 7            quirino     aglipay
# 8         pangasinan        agno
# 9           batangas   agoncillo
#
# [10 rows x 21 columns]

# %%
water_cooking_df.drop(columns=drop_cols, inplace=True)

water_cooking_df.to_csv(Path(PROJECTROOT, "data", "cleaned-datasets", "housing-census-water-supply-cooking-2015.csv"))

# %% [markdown]
# ## Water supply for drinking

# %%
water_drinking_df = pd.read_csv(WATER_SUPPLY_DRINKING)
water_drinking_df.drop(columns=["Unnamed: 0"], inplace=True)

# %%
water_drinking_df.head(10)
# Out:
#                   city                    region_name             province  \
# 0       CITY OF MANILA  NCR - National Capital Region  METROPOLITAN MANILA
# 1  CITY OF MANDALUYONG  NCR - National Capital Region  METROPOLITAN MANILA
# 2     CITY OF MARIKINA  NCR - National Capital Region  METROPOLITAN MANILA
# 3        CITY OF PASIG  NCR - National Capital Region  METROPOLITAN MANILA
# 4          QUEZON CITY  NCR - National Capital Region  METROPOLITAN MANILA
# 5     CITY OF SAN JUAN  NCR - National Capital Region  METROPOLITAN MANILA
# 6        CALOOCAN CITY  NCR - National Capital Region  METROPOLITAN MANILA
# 7      CITY OF MALABON  NCR - National Capital Region  METROPOLITAN MANILA
# 8      CITY OF NAVOTAS  NCR - National Capital Region  METROPOLITAN MANILA
# 9   CITY OF VALENZUELA  NCR - National Capital Region  METROPOLITAN MANILA
#
#    Own use faucet community water system_count  \
# 0                                     188513.0
# 1                                      56381.0
# 2                                      68434.0
# 3                                      99263.0
# 4                                     401143.0
# 5                                      15950.0
# 6                                     212602.0
# 7                                      30322.0
# 8                                      19461.0
# 9                                      72828.0
#
#    Shared faucet community water system_count  \
# 0                                     52760.0
# 1                                      6412.0
# 2                                      6373.0
# 3                                     11296.0
# 4                                     90313.0
# 5                                      2444.0
# 6                                     57637.0
# 7                                     11656.0
# 8                                      7915.0
# 9                                     24330.0
#
#    Own use tubed/piped deep well_count  Shared tubed/piped deep well_count  \
# 0                                883.0                               834.0
# 1                                 48.0                               216.0
# 2                                229.0                               397.0
# 3                                234.0                               435.0
# 4                               1591.0                              2165.0
# 5                                  NaN                                 NaN
# 6                               3628.0                              4241.0
# 7                                363.0                               276.0
# 8                                 50.0                               321.0
# 9                                868.0                              2173.0
#
#    Tubed/piped shallow well_count  Dug well_count  Protected spring_count  \
# 0                            91.0            50.0                   622.0
# 1                            48.0             2.0                   233.0
# 2                            24.0            15.0                   318.0
# 3                            55.0            31.0                   846.0
# 4                           325.0           337.0                  1576.0
# 5                             NaN             NaN                     NaN
# 6                           247.0           483.0                    14.0
# 7                             9.0            21.0                     1.0
# 8                            18.0             4.0                   268.0
# 9                            36.0            40.0                     NaN
#
#    Unprotected spring_count  Lake, river, rain and others_count  \
# 0                       6.0                                29.0
# 1                       1.0                                 4.0
# 2                       NaN                                 2.0
# 3                       5.0                                10.0
# 4                      23.0                                42.0
# 5                       NaN                                 NaN
# 6                       NaN                                 NaN
# 7                       NaN                                 NaN
# 8                       NaN                                 2.0
# 9                       NaN                                 NaN
#
#    Peddler_count  Bottled water_count  Others_count  Not Reported_count  year
# 0        11449.0             179153.0         764.0                 NaN  2015
# 1         2720.0              33300.0         991.0                 NaN  2015
# 2         1380.0              20907.0         159.0                 NaN  2015
# 3         2403.0              64530.0        1504.0                 NaN  2015
# 4         9656.0             170761.0        5112.0                 NaN  2015
# 5          773.0               9456.0           NaN                 NaN  2015
# 6         3794.0              84570.0         662.0                 NaN  2015
# 7         3377.0              40000.0         166.0                 NaN  2015
# 8         2788.0              29983.0          94.0                 NaN  2015
# 9         3305.0              49366.0          95.0                 NaN  2015

# %%
water_drinking_df = water_drinking_df.loc[~water_drinking_df["province"].isnull()]
water_drinking_df = water_drinking_df.loc[~water_drinking_df["city"].isnull()]

# %%
water_drinking_df["clean_province"] = (
    water_drinking_df["province"].apply(data_cleaner)
)

water_drinking_df["clean_city"] = water_drinking_df["city"].apply(
    data_cleaner
)

water_drinking_df["clean_idx"] = (
    water_drinking_df["clean_city"].astype(str)
    + ", "
    + water_drinking_df["clean_province"].astype(str)
)

# %%
water_drinking_df["clean_idx"] = water_drinking_df["clean_idx"].apply(bohol_to_cebu).apply(replace_idx).apply(quirino_to_isabela).apply(rizal_to_laguna).apply(bohol_to_cebu)

# %%
water_drinking_idx = water_drinking_df.clean_idx.drop_duplicates().unique().tolist()

# %%
not_in_ref = compare_lists(water_cooking_idx, ref_df_idx)
not_in_ref
# Out:
# []

# %%
water_drinking_df = ref_df[["clean_idx", "name"]].merge(water_drinking_df, 
                                                       how='left',
                                                       on='clean_idx')

# %%
water_drinking_df.head(10)
# Out:
#                        clean_idx          name          city  \
# 0               aborlan, palawan       Aborlan       ABORLAN
# 1  abradeilog, occidentalmindoro  Abra De Ilog  ABRA DE ILOG
# 2                 abucay, bataan        Abucay        ABUCAY
# 3                abulug, cagayan        Abulug        ABULUG
# 4                  abuyog, leyte        Abuyog        ABUYOG
# 5             adams, ilocosnorte         Adams         ADAMS
# 6               agdangan, quezon      Agdangan      AGDANGAN
# 7               aglipay, quirino       Aglipay       AGLIPAY
# 8               agno, pangasinan          Agno          AGNO
# 9            agoncillo, batangas     Agoncillo     AGONCILLO
#
#                      region_name                                  province  \
# 0         REGION IV-B (MIMAROPA)  PALAWAN (excluding Puerto Princesa City)
# 1         REGION IV-B (MIMAROPA)                        OCCIDENTAL MINDORO
# 2     REGION III (Central Luzon)                                    BATAAN
# 3     REGION II (Cagayan Valley)                                   CAGAYAN
# 4  REGION VIII (Eastern Visayas)           LEYTE (excluding Tacloban City)
# 5       REGION I (Ilocos Region)                              ILOCOS NORTE
# 6       REGION IV-A (CALABARZON)            QUEZON (excluding Lucena City)
# 7     REGION II (Cagayan Valley)                                   QUIRINO
# 8       REGION I (Ilocos Region)                                PANGASINAN
# 9       REGION IV-A (CALABARZON)                                  BATANGAS
#
#    Own use faucet community water system_count  \
# 0                                       2130.0
# 1                                       1076.0
# 2                                        966.0
# 3                                        345.0
# 4                                        665.0
# 5                                        380.0
# 6                                        144.0
# 7                                        197.0
# 8                                        160.0
# 9                                       5641.0
#
#    Shared faucet community water system_count  \
# 0                                      1621.0
# 1                                       459.0
# 2                                      1488.0
# 3                                       130.0
# 4                                      3264.0
# 5                                        31.0
# 6                                       525.0
# 7                                       189.0
# 8                                       102.0
# 9                                       621.0
#
#    Own use tubed/piped deep well_count  Shared tubed/piped deep well_count  \
# 0                                932.0                              2286.0
# 1                                846.0                              2749.0
# 2                                448.0                              5914.0
# 3                               1609.0                              1608.0
# 4                                518.0                              2725.0
# 5                                  NaN                                 NaN
# 6                                188.0                              1009.0
# 7                               1221.0                              2346.0
# 8                               1246.0                              1171.0
# 9                                242.0                               650.0
#
#    Tubed/piped shallow well_count  ...  Protected spring_count  \
# 0                           403.0  ...                   164.0
# 1                           773.0  ...                   613.0
# 2                            30.0  ...                   119.0
# 3                           156.0  ...                    13.0
# 4                            96.0  ...                  1955.0
# 5                             NaN  ...                     NaN
# 6                            71.0  ...                     1.0
# 7                           583.0  ...                   474.0
# 8                            56.0  ...                   263.0
# 9                           197.0  ...                     2.0
#
#    Unprotected spring_count  Lake, river, rain and others_count  \
# 0                      15.0                                88.0
# 1                     188.0                               250.0
# 2                       1.0                                 4.0
# 3                       2.0                                 NaN
# 4                     521.0                                10.0
# 5                       NaN                                 NaN
# 6                       6.0                                36.0
# 7                     592.0                                 1.0
# 8                      52.0                                13.0
# 9                       NaN                                 4.0
#
#    Peddler_count  Bottled water_count  Others_count  Not Reported_count  \
# 0           14.0                183.0           NaN                 NaN
# 1            1.0                 67.0           6.0                 NaN
# 2            NaN                477.0           2.0                 NaN
# 3            NaN               2217.0           NaN                 NaN
# 4          134.0               1809.0           8.0                 NaN
# 5            NaN                  NaN           NaN                 NaN
# 6           39.0               1022.0           1.0                 NaN
# 7           16.0                834.0           NaN                 NaN
# 8            2.0                856.0           2.0                 NaN
# 9          126.0                325.0           4.0                 NaN
#
#      year     clean_province  clean_city
# 0  2015.0            palawan     aborlan
# 1  2015.0  occidentalmindoro  abradeilog
# 2  2015.0             bataan      abucay
# 3  2015.0            cagayan      abulug
# 4  2015.0              leyte      abuyog
# 5  2015.0        ilocosnorte       adams
# 6  2015.0             quezon    agdangan
# 7  2015.0            quirino     aglipay
# 8  2015.0         pangasinan        agno
# 9  2015.0           batangas   agoncillo
#
# [10 rows x 21 columns]
