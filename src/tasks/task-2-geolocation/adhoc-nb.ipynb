# %%
import os
import re
from pathlib import Path

import geopandas as gp
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
# Setting up directories

WORKINGDIR = Path(os.getcwd())
PROJECTROOT = WORKINGDIR.parents[1]

NAMESFILE = Path("tasks", "task-1-data-collection", "city_names.csv")
SHAPEFILE = Path("data", "geolocation", "ph_cities_joined", "ph_cities.shp")
SHAPEFILE_V2 = Path("data", "geolocation", "ph_cities_joined_v2", "ph_cities_v2.shp")

# %%
gdf = gp.read_file(Path(PROJECTROOT, SHAPEFILE_V2))

# %%
gdf.loc[gdf["province"]=="Abra"]
# Out:
#             psgc              name    city_munic province           clean_idx  \
# 154   1400101000           Bangued       Bangued     Abra       bangued, abra
# 229   1400102000           Boliney       Boliney     Abra       boliney, abra
# 246   1400103000             Bucay         Bucay     Abra         bucay, abra
# 247   1400104000            Bucloc        Bucloc     Abra        bucloc, abra
# 416   1400105000         Daguioman     Daguioman     Abra     daguioman, abra
# 423   1400106000           Danglas       Danglas     Abra       danglas, abra
# 467   1400107000      Dolores (AA)       Dolores     Abra       dolores, abra
# 676   1400109000             Lacub         Lacub     Abra         lacub, abra
# 677   1400110000       Lagangilang   Lagangilang     Abra   lagangilang, abra
# 679   1400111000           Lagayan       Lagayan     Abra       lagayan, abra
# 693   1400112000          Langiden      Langiden     Abra      langiden, abra
# 701   1400108000       La Paz (AA)        La Paz     Abra         lapaz, abra
# 740   1400113000       Licuan-Baay   Licuan-Baay     Abra    licuanbaay, abra
# 769   1400114000              Luba          Luba     Abra          luba, abra
# 851   1400115000         Malibcong     Malibcong     Abra     malibcong, abra
# 868   1400116000            Manabo        Manabo     Abra        manabo, abra
# 1091  1400117000        Penarrubia    Peñarrubia     Abra    peñarrubia, abra
# 1096  1400118000           Pidigan       Pidigan     Abra       pidigan, abra
# 1100  1400119000        Pilar (AA)         Pilar     Abra         pilar, abra
# 1210  1400120000        Sallapadan    Sallapadan     Abra    sallapadan, abra
# 1255  1400121000   San Isidro (AA)    San Isidro     Abra     sanisidro, abra
# 1280  1400122000     San Juan (AA)      San Juan     Abra       sanjuan, abra
# 1321  1400123000  San Quintin (AA)   San Quintin     Abra    sanquintin, abra
# 1541  1400124000             Tayum         Tayum     Abra         tayum, abra
# 1551  1400125000             Tineg         Tineg     Abra         tineg, abra
# 1576  1400126000              Tubo          Tubo     Abra          tubo, abra
# 1623  1400127000      Villaviciosa  Villaviciosa     Abra  villaviciosa, abra
#
#        longitude   latitude                   coords  \
# 154   120.617999  17.596566  17.5965664, 120.6179987
# 229   120.819836  17.379058  17.3790583, 120.8198364
# 246   120.718753  17.538434  17.5384336, 120.7187526
# 247   120.857251  17.440940  17.4409401, 120.8572514
# 416   120.926294  17.458889   17.458889, 120.9262943
# 423   120.664474  17.693304  17.6933042, 120.6644745
# 467   120.708625  17.649047  17.6490473, 120.7086252
# 676   120.945660  17.664378  17.6643781, 120.9456603
# 677   120.733656  17.612692  17.6126919, 120.7336564
# 679   120.705981  17.720616   17.720616, 120.7059814
# 693   120.563939  17.576107   17.5761072, 120.563939
# 701   120.683834  17.670779  17.6707795, 120.6838341
# 740   120.905438  17.609082  17.6090816, 120.9054377
# 769   120.694646  17.317322  17.3173222, 120.6946459
# 851   120.989069  17.563315   17.563315, 120.9890692
# 868   120.704104  17.432547  17.4325474, 120.7041038
# 1091  120.652673  17.563834   17.5638344, 120.652673
# 1096  120.589944  17.570304   17.570304, 120.5899441
# 1100  120.595453  17.415246  17.4152463, 120.5954528
# 1210  120.759934  17.455144  17.4551443, 120.7599337
# 1255  120.601743  17.465610  17.4656098, 120.6017435
# 1280  120.730620  17.682288   17.682288, 120.7306199
# 1321  120.520321  17.542746  17.5427457, 120.5203211
# 1541  120.653549  17.618071  17.6180712, 120.6535488
# 1551  120.943593  17.782906   17.7829065, 120.943593
# 1576  120.724844  17.258215  17.2582154, 120.7248438
# 1623  120.625685  17.437846  17.4378456, 120.6256845
#
#                                                geometry
# 154   POLYGON ((120.61134 17.49558, 120.60941 17.496...
# 229   POLYGON ((120.81400 17.34210, 120.76862 17.340...
# 246   POLYGON ((120.67766 17.45736, 120.67324 17.469...
# 247   POLYGON ((120.78922 17.44525, 120.80331 17.449...
# 416   POLYGON ((120.90749 17.41933, 120.89281 17.446...
# 423   POLYGON ((120.66962 17.68363, 120.66330 17.676...
# 467   POLYGON ((120.74984 17.62309, 120.74963 17.622...
# 676   POLYGON ((120.98426 17.65344, 120.96807 17.651...
# 677   POLYGON ((120.71872 17.58940, 120.71870 17.589...
# 679   POLYGON ((120.80346 17.78373, 120.78590 17.764...
# 693   POLYGON ((120.58949 17.59388, 120.59043 17.593...
# 701   POLYGON ((120.60815 17.63317, 120.60463 17.633...
# 740   POLYGON ((120.85412 17.48698, 120.83900 17.496...
# 769   POLYGON ((120.70740 17.28237, 120.68825 17.263...
# 851   POLYGON ((120.99123 17.49674, 120.98920 17.498...
# 868   POLYGON ((120.66891 17.42015, 120.66516 17.428...
# 1091  POLYGON ((120.69678 17.53218, 120.69691 17.529...
# 1096  POLYGON ((120.60549 17.50203, 120.60297 17.502...
# 1100  POLYGON ((120.59741 17.31132, 120.59519 17.310...
# 1210  POLYGON ((120.76375 17.41648, 120.76293 17.416...
# 1255  POLYGON ((120.57851 17.44546, 120.57861 17.449...
# 1280  POLYGON ((120.73288 17.66570, 120.72484 17.665...
# 1321  POLYGON ((120.57793 17.48964, 120.58414 17.482...
# 1541  POLYGON ((120.70557 17.62365, 120.70664 17.623...
# 1551  POLYGON ((120.87500 17.73459, 120.84119 17.677...
# 1576  POLYGON ((120.75676 17.15788, 120.74939 17.157...
# 1623  POLYGON ((120.61429 17.31070, 120.61111 17.311...
