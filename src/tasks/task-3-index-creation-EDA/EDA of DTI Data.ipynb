# %%
# Supress Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Import Required Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Read and Inspect The Dataset

# %%
dti = pd.read_csv("merged-dti-data.csv")
dti.head()
# Out:
#   city_municipality  2018 - Local Economy Size  2018 - Local Economy Growth  \
# 0           Aborlan                     0.0072                       0.0224
# 1      Abra De Ilog                     0.0027                       0.0102
# 2            Abucay                     0.0488                       0.0020
# 3            Abulug                     0.0651                       0.0052
# 4            Abuyog                     0.0115                       0.0208
#
#    2018 - Active Establishments in the Locality  \
# 0                                        0.2337
# 1                                        0.0477
# 2                                        0.0053
# 3                                        0.0053
# 4                                        0.1813
#
#    2018 - Safety Compliant Business  2018 - Employment Generation  \
# 0                            0.1253                        0.0197
# 1                            0.0282                        0.0008
# 2                            0.2363                        0.2299
# 3                            0.2440                        0.1548
# 4                            0.3592                        0.0499
#
#    2018 - Cost of Living  2018 - Cost of Doing Business  \
# 0                 1.9907                         2.1771
# 1                 2.3611                         2.2200
# 2                 1.1111                         1.8373
# 3                 1.2963                         2.0402
# 4                 1.0185                         1.1430
#
#    2018 - Financial Deepening  2018 - Productivity  ...  \
# 0                      0.0423               0.0047  ...
# 1                      0.0184               0.0579  ...
# 2                      0.0965               0.0198  ...
# 3                      0.1762               0.0103  ...
# 4                      0.1049               0.0028  ...
#
#    2022 - Start Up and Innovation Facilities  \
# 0                                     0.1281
# 1                                     0.0000
# 2                                     0.0533
# 3                                     0.0267
# 4                                     0.0000
#
#    2022 - Innovation Financing: R&D Expenditures Allotment  \
# 0                                             0.0000
# 1                                             0.0000
# 2                                             0.0038
# 3                                             0.0000
# 4                                             0.0000
#
#    2022 - STEM graduates  2022 - Intellectual Property Registration  \
# 0                 0.0195                                     0.0221
# 1                 0.0000                                     0.0009
# 2                 0.0047                                     0.0483
# 3                 0.0023                                     0.0000
# 4                 0.0522                                     0.0000
#
#    2022 - ICT Use: E-BPLS Software  2022 - Internet Capability  \
# 0                              2.0                      0.0095
# 1                              2.0                      0.0095
# 2                              2.0                      0.1957
# 3                              0.0                      0.1087
# 4                              2.0                      1.0476
#
#    2022 - Availability of Basic Internet Service  \
# 0                                         0.0000
# 1                                         0.0000
# 2                                         0.1194
# 3                                         0.0000
# 4                                         0.0037
#
#    2022 - Online Payment Facilities  2022 - ICT Plan  2022 - New Technology
# 0                               0.0           2.0001                    0.0
# 1                               0.0           0.0000                    0.0
# 2                               0.0           2.0001                    0.0
# 3                               0.0           0.6667                    0.0
# 4                               0.0           1.3334                    0.0
#
# [5 rows x 211 columns]

# %%
# Setting the index as city_municipality
dti = pd.DataFrame(dti).set_index('city_municipality')

# %%
# Finding the rows that has 100% null values
dti[dti.isna().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [2018 - Local Economy Size, 2018 - Local Economy Growth, 2018 - Active Establishments in the Locality, 2018 - Safety Compliant Business, 2018 - Employment Generation, 2018 - Cost of Living, 2018 - Cost of Doing Business, 2018 - Financial Deepening, 2018 - Productivity, 2018 - Presence of Business and Professional Organizations, 2018 - Compliance to National Directives, 2018 - Presence of Investment Promotion Unit, 2018 - Compliance to ARTA Citizens Charter, 2018 - Capacity to Generate Local Resource, 2018 - Capacity of Health Services, 2018 - Capacity of School Services, 2018 - Recognition of Performance, 2018 - Getting Business Permits, 2018 - Peace and Order, 2018 - Social Protection, 2018 - Road Network, 2018 - Distance to Ports, 2018 - Availability of Basic Utilities, 2018 - Transportation Vehicles, 2018 - Education, 2018 - Health, 2018 - LGU Investment, 2018 - Accommodation Capacity, 2018 - Information Technology Capacity, 2018 - Financial Technology Capacity, 2018 - Land Use Plan, 2018 - Disaster Risk Reduction Plan, 2018 - Annual Disaster Drill, 2018 - Early Warning System, 2018 - Budget for DRRMP, 2018 - Local Risk Assessments, 2018 - Emergency Infrastructure, 2018 - Utilities, 2018 - Employed Population, 2018 - Sanitary System, 2019 - Local Economy Size, 2019 - Local Economy Growth, 2019 - Active Establishments in the Locality, 2019 - Safety Compliant Business, 2019 - Employment Generation, 2019 - Cost of Living, 2019 - Cost of Doing Business, 2019 - Financial Deepening, 2019 - Productivity, 2019 - Presence of Business and Professional Organizations, 2019 - Compliance to National Directives, 2019 - Presence of Investment Promotion Unit, 2019 - Compliance to ARTA Citizens Charter, 2019 - Capacity to Generate Local Resource, 2019 - Capacity of Health Services, 2019 - Capacity of School Services, 2019 - Recognition of Performance, 2019 - Getting Business Permits, 2019 - Peace and Order, 2019 - Social Protection, 2019 - Road Network, 2019 - Distance to Ports, 2019 - Availability of Basic Utilities, 2019 - Transportation Vehicles, 2019 - Education, 2019 - Health, 2019 - LGU Investment, 2019 - Accommodation Capacity, 2019 - Information Technology Capacity, 2019 - Financial Technology Capacity, 2019 - Land Use Plan, 2019 - Disaster Risk Reduction Plan, 2019 - Annual Disaster Drill, 2019 - Early Warning System, 2019 - Budget for DRRMP, 2019 - Local Risk Assessments, 2019 - Emergency Infrastructure, 2019 - Utilities, 2019 - Employed Population, 2019 - Sanitary System, 2020 - Local Economy Size, 2020 - Local Economy Growth, 2020 - Active Establishments in the Locality, 2020 - Safety Compliant Business, 2020 - Employment Generation, 2020 - Cost of Living, 2020 - Cost of Doing Business, 2020 - Financial Deepening, 2020 - Productivity, 2020 - Presence of Business and Professional Organizations, 2020 - Compliance to National Directives, 2020 - Presence of Investment Promotion Unit, 2020 - Compliance to ARTA Citizens Charter, 2020 - Capacity to Generate Local Resource, 2020 - Capacity of Health Services, 2020 - Capacity of School Services, 2020 - Recognition of Performance, 2020 - Getting Business Permits, 2020 - Peace and Order, 2020 - Social Protection, ...]
# Index: []
#
# [0 rows x 210 columns]

# %% [markdown]
# No rows have 100% null values. So we can try backfilling and frontfilling for any missing values by extraploating values from recent years.

# %%
#Creating a dataframe with only 2022 data
cols_2022 = dti.columns[dti.columns.str.startswith('2022')].tolist()
dti_2022 = dti[cols_2022]
dti_2022.head()
# Out:
#                    2022 - Local Economy Size  2022 - Local Economy Growth  \
# city_municipality
# Aborlan                               0.0105                       0.0001
# Abra De Ilog                          0.0015                       0.0000
# Abucay                                0.0144                       0.0007
# Abulug                                0.0144                       0.0010
# Abuyog                                0.0058                       0.0000
#
#                    2022 - Active Establishments in the Locality  \
# city_municipality
# Aborlan                                                  0.0662
# Abra De Ilog                                             0.0498
# Abucay                                                   0.7920
# Abulug                                                   0.3012
# Abuyog                                                   0.1413
#
#                    2022 - Safety Compliant Business  \
# city_municipality
# Aborlan                                      0.0000
# Abra De Ilog                                 0.0000
# Abucay                                       0.4603
# Abulug                                       0.2501
# Abuyog                                       0.0000
#
#                    2022 - Employment Generation  2022 - Cost of Living  \
# city_municipality
# Aborlan                                  0.0624                 1.9279
# Abra De Ilog                             0.0171                 1.6875
# Abucay                                   0.8238                 1.9990
# Abulug                                   0.4434                 1.9989
# Abuyog                                   0.0551                 1.7596
#
#                    2022 - Cost of Doing Business  2022 - Financial Deepening  \
# city_municipality
# Aborlan                                   1.9004                      0.0793
# Abra De Ilog                              1.8990                      0.0443
# Abucay                                    1.8962                      0.2252
# Abulug                                    1.8972                      0.4652
# Abuyog                                    1.8405                      0.2431
#
#                    2022 - Productivity  \
# city_municipality
# Aborlan                         0.0341
# Abra De Ilog                    0.0042
# Abucay                          0.3706
# Abulug                          0.2666
# Abuyog                          0.0386
#
#                    2022 - Presence of Business and Professional Organizations  \
# city_municipality
# Aborlan                                                       0.0117
# Abra De Ilog                                                  0.0050
# Abucay                                                        0.0095
# Abulug                                                        0.0000
# Abuyog                                                        0.0061
#
#                    ...  2022 - Start Up and Innovation Facilities  \
# city_municipality  ...
# Aborlan            ...                                     0.1281
# Abra De Ilog       ...                                     0.0000
# Abucay             ...                                     0.0533
# Abulug             ...                                     0.0267
# Abuyog             ...                                     0.0000
#
#                    2022 - Innovation Financing: R&D Expenditures Allotment  \
# city_municipality
# Aborlan                                                       0.0000
# Abra De Ilog                                                  0.0000
# Abucay                                                        0.0038
# Abulug                                                        0.0000
# Abuyog                                                        0.0000
#
#                    2022 - STEM graduates  \
# city_municipality
# Aborlan                           0.0195
# Abra De Ilog                      0.0000
# Abucay                            0.0047
# Abulug                            0.0023
# Abuyog                            0.0522
#
#                    2022 - Intellectual Property Registration  \
# city_municipality
# Aborlan                                               0.0221
# Abra De Ilog                                          0.0009
# Abucay                                                0.0483
# Abulug                                                0.0000
# Abuyog                                                0.0000
#
#                    2022 - ICT Use: E-BPLS Software  \
# city_municipality
# Aborlan                                        2.0
# Abra De Ilog                                   2.0
# Abucay                                         2.0
# Abulug                                         0.0
# Abuyog                                         2.0
#
#                    2022 - Internet Capability  \
# city_municipality
# Aborlan                                0.0095
# Abra De Ilog                           0.0095
# Abucay                                 0.1957
# Abulug                                 0.1087
# Abuyog                                 1.0476
#
#                    2022 - Availability of Basic Internet Service  \
# city_municipality
# Aborlan                                                   0.0000
# Abra De Ilog                                              0.0000
# Abucay                                                    0.1194
# Abulug                                                    0.0000
# Abuyog                                                    0.0037
#
#                    2022 - Online Payment Facilities  2022 - ICT Plan  \
# city_municipality
# Aborlan                                         0.0           2.0001
# Abra De Ilog                                    0.0           0.0000
# Abucay                                          0.0           2.0001
# Abulug                                          0.0           0.6667
# Abuyog                                          0.0           1.3334
#
#                    2022 - New Technology
# city_municipality
# Aborlan                              0.0
# Abra De Ilog                         0.0
# Abucay                               0.0
# Abulug                               0.0
# Abuyog                               0.0
#
# [5 rows x 50 columns]

# %%
# Remove last 10 columns which are not availble for other years
dti_2022 = dti_2022.iloc[:,0:40]
dti_2022.shape
# Out:
# (1632, 40)

# %%
# Remove '2022 - ' from all the column names
dti_2022.columns = dti_2022.columns.str.replace('2022 - ','')
dti_2022.head()
# Out:
#                    Local Economy Size  Local Economy Growth  \
# city_municipality
# Aborlan                        0.0105                0.0001
# Abra De Ilog                   0.0015                0.0000
# Abucay                         0.0144                0.0007
# Abulug                         0.0144                0.0010
# Abuyog                         0.0058                0.0000
#
#                    Active Establishments in the Locality  \
# city_municipality
# Aborlan                                           0.0662
# Abra De Ilog                                      0.0498
# Abucay                                            0.7920
# Abulug                                            0.3012
# Abuyog                                            0.1413
#
#                    Safety Compliant Business  Employment Generation  \
# city_municipality
# Aborlan                               0.0000                 0.0624
# Abra De Ilog                          0.0000                 0.0171
# Abucay                                0.4603                 0.8238
# Abulug                                0.2501                 0.4434
# Abuyog                                0.0000                 0.0551
#
#                    Cost of Living  Cost of Doing Business  \
# city_municipality
# Aborlan                    1.9279                  1.9004
# Abra De Ilog               1.6875                  1.8990
# Abucay                     1.9990                  1.8962
# Abulug                     1.9989                  1.8972
# Abuyog                     1.7596                  1.8405
#
#                    Financial Deepening  Productivity  \
# city_municipality
# Aborlan                         0.0793        0.0341
# Abra De Ilog                    0.0443        0.0042
# Abucay                          0.2252        0.3706
# Abulug                          0.4652        0.2666
# Abuyog                          0.2431        0.0386
#
#                    Presence of Business and Professional Organizations  ...  \
# city_municipality                                                       ...
# Aborlan                                                       0.0117    ...
# Abra De Ilog                                                  0.0050    ...
# Abucay                                                        0.0095    ...
# Abulug                                                        0.0000    ...
# Abuyog                                                        0.0061    ...
#
#                    Land Use Plan  Disaster Risk Reduction Plan  \
# city_municipality
# Aborlan                   1.9848                        1.9998
# Abra De Ilog              1.9848                        1.9998
# Abucay                    1.9595                        1.9998
# Abulug                    1.9865                        0.4993
# Abuyog                    1.9242                        1.9998
#
#                    Annual Disaster Drill  Early Warning System  \
# city_municipality
# Aborlan                            1.002                1.0087
# Abra De Ilog                       1.008                1.0124
# Abucay                             1.002                1.0375
# Abulug                             1.002                1.0040
# Abuyog                             0.000                1.0025
#
#                    Budget for DRRMP  Local Risk Assessments  \
# city_municipality
# Aborlan                         0.0                     2.0
# Abra De Ilog                    0.0                     1.0
# Abucay                          0.0                     2.0
# Abulug                          0.0                     2.0
# Abuyog                          0.0                     2.0
#
#                    Emergency Infrastructure  Utilities  Employed Population  \
# city_municipality
# Aborlan                              0.0292     1.5007               0.0061
# Abra De Ilog                         0.4186     1.5011               0.0632
# Abucay                               0.4144     1.5093               0.0563
# Abulug                               0.5214     1.5000               0.0041
# Abuyog                               0.4103     1.5039               0.0310
#
#                    Sanitary System
# city_municipality
# Aborlan                     1.0002
# Abra De Ilog                1.5002
# Abucay                      1.5000
# Abulug                      1.5000
# Abuyog                      1.5002
#
# [5 rows x 40 columns]

# %%
# Finding the rows that has 100% null values in dti_2022
dti_2022[dti_2022.isna().all(axis=1)]
# Out:
#                    Local Economy Size  Local Economy Growth  \
# city_municipality
# Magdiwang                         NaN                   NaN
# Oras                              NaN                   NaN
# San Pascual (MS)                  NaN                   NaN
#
#                    Active Establishments in the Locality  \
# city_municipality
# Magdiwang                                            NaN
# Oras                                                 NaN
# San Pascual (MS)                                     NaN
#
#                    Safety Compliant Business  Employment Generation  \
# city_municipality
# Magdiwang                                NaN                    NaN
# Oras                                     NaN                    NaN
# San Pascual (MS)                         NaN                    NaN
#
#                    Cost of Living  Cost of Doing Business  \
# city_municipality
# Magdiwang                     NaN                     NaN
# Oras                          NaN                     NaN
# San Pascual (MS)              NaN                     NaN
#
#                    Financial Deepening  Productivity  \
# city_municipality
# Magdiwang                          NaN           NaN
# Oras                               NaN           NaN
# San Pascual (MS)                   NaN           NaN
#
#                    Presence of Business and Professional Organizations  ...  \
# city_municipality                                                       ...
# Magdiwang                                                        NaN    ...
# Oras                                                             NaN    ...
# San Pascual (MS)                                                 NaN    ...
#
#                    Land Use Plan  Disaster Risk Reduction Plan  \
# city_municipality
# Magdiwang                    NaN                           NaN
# Oras                         NaN                           NaN
# San Pascual (MS)             NaN                           NaN
#
#                    Annual Disaster Drill  Early Warning System  \
# city_municipality
# Magdiwang                            NaN                   NaN
# Oras                                 NaN                   NaN
# San Pascual (MS)                     NaN                   NaN
#
#                    Budget for DRRMP  Local Risk Assessments  \
# city_municipality
# Magdiwang                       NaN                     NaN
# Oras                            NaN                     NaN
# San Pascual (MS)                NaN                     NaN
#
#                    Emergency Infrastructure  Utilities  Employed Population  \
# city_municipality
# Magdiwang                               NaN        NaN                  NaN
# Oras                                    NaN        NaN                  NaN
# San Pascual (MS)                        NaN        NaN                  NaN
#
#                    Sanitary System
# city_municipality
# Magdiwang                      NaN
# Oras                           NaN
# San Pascual (MS)               NaN
#
# [3 rows x 40 columns]

# %% [markdown]
# Only 3 rows have 100% null values in dti_2022 dataframe. We will impute those values later.

# %%
#Creating a dataframe with only 2021 data
cols_2021 = dti.columns[dti.columns.str.startswith('2021')].tolist()
dti_2021 = dti[cols_2021]
dti_2021.head()
# Out:
#                    2021 - Local Economy Size  2021 - Local Economy Growth  \
# city_municipality
# Aborlan                               0.0067                       0.0045
# Abra De Ilog                          0.0070                       0.0066
# Abucay                                0.0876                       0.0007
# Abulug                                0.0921                       0.0012
# Abuyog                                0.0111                       0.0027
#
#                    2021 - Active Establishments in the Locality  \
# city_municipality
# Aborlan                                                  0.2606
# Abra De Ilog                                             0.0588
# Abucay                                                   0.7344
# Abulug                                                   0.3498
# Abuyog                                                   0.1457
#
#                    2021 - Safety Compliant Business  \
# city_municipality
# Aborlan                                      0.1683
# Abra De Ilog                                 0.0676
# Abucay                                       0.4760
# Abulug                                       0.3568
# Abuyog                                       0.1349
#
#                    2021 - Employment Generation  2021 - Cost of Living  \
# city_municipality
# Aborlan                                  0.1052                 1.6250
# Abra De Ilog                             0.0191                 0.5938
# Abucay                                   0.5753                 1.0625
# Abulug                                   0.3785                 0.7813
# Abuyog                                   0.0811                 1.9688
#
#                    2021 - Cost of Doing Business  2021 - Financial Deepening  \
# city_municipality
# Aborlan                                   2.3654                      0.1231
# Abra De Ilog                              2.3642                      0.0380
# Abucay                                    2.0565                      0.5657
# Abulug                                    2.1551                      1.2830
# Abuyog                                    1.7724                      0.5127
#
#                    2021 - Productivity  \
# city_municipality
# Aborlan                         0.0690
# Abra De Ilog                    0.0150
# Abucay                          0.5111
# Abulug                          0.3946
# Abuyog                          0.0606
#
#                    2021 - Presence of Business and Professional Organizations  \
# city_municipality
# Aborlan                                                       0.1089
# Abra De Ilog                                                  0.0106
# Abucay                                                        0.0030
# Abulug                                                        0.0030
# Abuyog                                                        0.0439
#
#                    ...  2021 - Land Use Plan  \
# city_municipality  ...
# Aborlan            ...                2.4545
# Abra De Ilog       ...                2.4773
# Abucay             ...                2.4857
# Abulug             ...                2.5000
# Abuyog             ...                2.4091
#
#                    2021 - Disaster Risk Reduction Plan  \
# city_municipality
# Aborlan                                         2.4737
# Abra De Ilog                                    2.4737
# Abucay                                          2.5000
# Abulug                                          2.5000
# Abuyog                                          2.4737
#
#                    2021 - Annual Disaster Drill  2021 - Early Warning System  \
# city_municipality
# Aborlan                                  1.2542                       1.2537
# Abra De Ilog                             1.2750                       1.2683
# Abucay                                   1.2829                       1.2799
# Abulug                                   1.2829                       1.2525
# Abuyog                                   0.0000                       1.2518
#
#                    2021 - Budget for DRRMP  2021 - Local Risk Assessments  \
# city_municipality
# Aborlan                             0.0215                            2.5
# Abra De Ilog                        0.0215                            2.5
# Abucay                              0.0024                            2.5
# Abulug                              0.0025                            2.5
# Abuyog                              0.0236                            2.5
#
#                    2021 - Emergency Infrastructure  2021 - Utilities  \
# city_municipality
# Aborlan                                     0.0531            1.2478
# Abra De Ilog                                0.3294            1.2509
# Abucay                                      0.2674            1.3019
# Abulug                                      0.2912            1.2578
# Abuyog                                      0.2971            1.2604
#
#                    2021 - Employed Population  2021 - Sanitary System
# city_municipality
# Aborlan                                0.0060                  1.2502
# Abra De Ilog                           0.0443                  1.8752
# Abucay                                 0.3219                  1.8751
# Abulug                                 0.0157                  1.8750
# Abuyog                                 0.0389                  1.8753
#
# [5 rows x 40 columns]

# %%
# Finding the rows that has 100% null values
dti_2021[dti_2021.isna().all(axis=1)]
# Out:
#                      2021 - Local Economy Size  2021 - Local Economy Growth  \
# city_municipality
# Akbar                                      NaN                          NaN
# Al-Barka                                   NaN                          NaN
# Compostela (DDO)                           NaN                          NaN
# Hadji Mohammad Ajul                        NaN                          NaN
# Hadji Muhtamad                             NaN                          NaN
# Kapai                                      NaN                          NaN
# Lagayan                                    NaN                          NaN
# Lugus                                      NaN                          NaN
# Lumbaca-Unayan                             NaN                          NaN
# Luuk                                       NaN                          NaN
# Maimbung                                   NaN                          NaN
# Old Panamao                                NaN                          NaN
# Oras                                       NaN                          NaN
# Pandami                                    NaN                          NaN
# Panglima Estino                            NaN                          NaN
# Pangutaran                                 NaN                          NaN
# Parang (SU)                                NaN                          NaN
# Patikul                                    NaN                          NaN
# San Isidro (AA)                            NaN                          NaN
# San Quintin (AA)                           NaN                          NaN
# Siasi                                      NaN                          NaN
# Sibuco                                     NaN                          NaN
# Tabuan-Lasa                                NaN                          NaN
# Tapul                                      NaN                          NaN
# Tongkil                                    NaN                          NaN
# Tuburan (BA)                               NaN                          NaN
# Ungkaya Pukan                              NaN                          NaN
#
#                      2021 - Active Establishments in the Locality  \
# city_municipality
# Akbar                                                         NaN
# Al-Barka                                                      NaN
# Compostela (DDO)                                              NaN
# Hadji Mohammad Ajul                                           NaN
# Hadji Muhtamad                                                NaN
# Kapai                                                         NaN
# Lagayan                                                       NaN
# Lugus                                                         NaN
# Lumbaca-Unayan                                                NaN
# Luuk                                                          NaN
# Maimbung                                                      NaN
# Old Panamao                                                   NaN
# Oras                                                          NaN
# Pandami                                                       NaN
# Panglima Estino                                               NaN
# Pangutaran                                                    NaN
# Parang (SU)                                                   NaN
# Patikul                                                       NaN
# San Isidro (AA)                                               NaN
# San Quintin (AA)                                              NaN
# Siasi                                                         NaN
# Sibuco                                                        NaN
# Tabuan-Lasa                                                   NaN
# Tapul                                                         NaN
# Tongkil                                                       NaN
# Tuburan (BA)                                                  NaN
# Ungkaya Pukan                                                 NaN
#
#                      2021 - Safety Compliant Business  \
# city_municipality
# Akbar                                             NaN
# Al-Barka                                          NaN
# Compostela (DDO)                                  NaN
# Hadji Mohammad Ajul                               NaN
# Hadji Muhtamad                                    NaN
# Kapai                                             NaN
# Lagayan                                           NaN
# Lugus                                             NaN
# Lumbaca-Unayan                                    NaN
# Luuk                                              NaN
# Maimbung                                          NaN
# Old Panamao                                       NaN
# Oras                                              NaN
# Pandami                                           NaN
# Panglima Estino                                   NaN
# Pangutaran                                        NaN
# Parang (SU)                                       NaN
# Patikul                                           NaN
# San Isidro (AA)                                   NaN
# San Quintin (AA)                                  NaN
# Siasi                                             NaN
# Sibuco                                            NaN
# Tabuan-Lasa                                       NaN
# Tapul                                             NaN
# Tongkil                                           NaN
# Tuburan (BA)                                      NaN
# Ungkaya Pukan                                     NaN
#
#                      2021 - Employment Generation  2021 - Cost of Living  \
# city_municipality
# Akbar                                         NaN                    NaN
# Al-Barka                                      NaN                    NaN
# Compostela (DDO)                              NaN                    NaN
# Hadji Mohammad Ajul                           NaN                    NaN
# Hadji Muhtamad                                NaN                    NaN
# Kapai                                         NaN                    NaN
# Lagayan                                       NaN                    NaN
# Lugus                                         NaN                    NaN
# Lumbaca-Unayan                                NaN                    NaN
# Luuk                                          NaN                    NaN
# Maimbung                                      NaN                    NaN
# Old Panamao                                   NaN                    NaN
# Oras                                          NaN                    NaN
# Pandami                                       NaN                    NaN
# Panglima Estino                               NaN                    NaN
# Pangutaran                                    NaN                    NaN
# Parang (SU)                                   NaN                    NaN
# Patikul                                       NaN                    NaN
# San Isidro (AA)                               NaN                    NaN
# San Quintin (AA)                              NaN                    NaN
# Siasi                                         NaN                    NaN
# Sibuco                                        NaN                    NaN
# Tabuan-Lasa                                   NaN                    NaN
# Tapul                                         NaN                    NaN
# Tongkil                                       NaN                    NaN
# Tuburan (BA)                                  NaN                    NaN
# Ungkaya Pukan                                 NaN                    NaN
#
#                      2021 - Cost of Doing Business  \
# city_municipality
# Akbar                                          NaN
# Al-Barka                                       NaN
# Compostela (DDO)                               NaN
# Hadji Mohammad Ajul                            NaN
# Hadji Muhtamad                                 NaN
# Kapai                                          NaN
# Lagayan                                        NaN
# Lugus                                          NaN
# Lumbaca-Unayan                                 NaN
# Luuk                                           NaN
# Maimbung                                       NaN
# Old Panamao                                    NaN
# Oras                                           NaN
# Pandami                                        NaN
# Panglima Estino                                NaN
# Pangutaran                                     NaN
# Parang (SU)                                    NaN
# Patikul                                        NaN
# San Isidro (AA)                                NaN
# San Quintin (AA)                               NaN
# Siasi                                          NaN
# Sibuco                                         NaN
# Tabuan-Lasa                                    NaN
# Tapul                                          NaN
# Tongkil                                        NaN
# Tuburan (BA)                                   NaN
# Ungkaya Pukan                                  NaN
#
#                      2021 - Financial Deepening  2021 - Productivity  \
# city_municipality
# Akbar                                       NaN                  NaN
# Al-Barka                                    NaN                  NaN
# Compostela (DDO)                            NaN                  NaN
# Hadji Mohammad Ajul                         NaN                  NaN
# Hadji Muhtamad                              NaN                  NaN
# Kapai                                       NaN                  NaN
# Lagayan                                     NaN                  NaN
# Lugus                                       NaN                  NaN
# Lumbaca-Unayan                              NaN                  NaN
# Luuk                                        NaN                  NaN
# Maimbung                                    NaN                  NaN
# Old Panamao                                 NaN                  NaN
# Oras                                        NaN                  NaN
# Pandami                                     NaN                  NaN
# Panglima Estino                             NaN                  NaN
# Pangutaran                                  NaN                  NaN
# Parang (SU)                                 NaN                  NaN
# Patikul                                     NaN                  NaN
# San Isidro (AA)                             NaN                  NaN
# San Quintin (AA)                            NaN                  NaN
# Siasi                                       NaN                  NaN
# Sibuco                                      NaN                  NaN
# Tabuan-Lasa                                 NaN                  NaN
# Tapul                                       NaN                  NaN
# Tongkil                                     NaN                  NaN
# Tuburan (BA)                                NaN                  NaN
# Ungkaya Pukan                               NaN                  NaN
#
#                      2021 - Presence of Business and Professional Organizations  \
# city_municipality
# Akbar                                                              NaN
# Al-Barka                                                           NaN
# Compostela (DDO)                                                   NaN
# Hadji Mohammad Ajul                                                NaN
# Hadji Muhtamad                                                     NaN
# Kapai                                                              NaN
# Lagayan                                                            NaN
# Lugus                                                              NaN
# Lumbaca-Unayan                                                     NaN
# Luuk                                                               NaN
# Maimbung                                                           NaN
# Old Panamao                                                        NaN
# Oras                                                               NaN
# Pandami                                                            NaN
# Panglima Estino                                                    NaN
# Pangutaran                                                         NaN
# Parang (SU)                                                        NaN
# Patikul                                                            NaN
# San Isidro (AA)                                                    NaN
# San Quintin (AA)                                                   NaN
# Siasi                                                              NaN
# Sibuco                                                             NaN
# Tabuan-Lasa                                                        NaN
# Tapul                                                              NaN
# Tongkil                                                            NaN
# Tuburan (BA)                                                       NaN
# Ungkaya Pukan                                                      NaN
#
#                      ...  2021 - Land Use Plan  \
# city_municipality    ...
# Akbar                ...                   NaN
# Al-Barka             ...                   NaN
# Compostela (DDO)     ...                   NaN
# Hadji Mohammad Ajul  ...                   NaN
# Hadji Muhtamad       ...                   NaN
# Kapai                ...                   NaN
# Lagayan              ...                   NaN
# Lugus                ...                   NaN
# Lumbaca-Unayan       ...                   NaN
# Luuk                 ...                   NaN
# Maimbung             ...                   NaN
# Old Panamao          ...                   NaN
# Oras                 ...                   NaN
# Pandami              ...                   NaN
# Panglima Estino      ...                   NaN
# Pangutaran           ...                   NaN
# Parang (SU)          ...                   NaN
# Patikul              ...                   NaN
# San Isidro (AA)      ...                   NaN
# San Quintin (AA)     ...                   NaN
# Siasi                ...                   NaN
# Sibuco               ...                   NaN
# Tabuan-Lasa          ...                   NaN
# Tapul                ...                   NaN
# Tongkil              ...                   NaN
# Tuburan (BA)         ...                   NaN
# Ungkaya Pukan        ...                   NaN
#
#                      2021 - Disaster Risk Reduction Plan  \
# city_municipality
# Akbar                                                NaN
# Al-Barka                                             NaN
# Compostela (DDO)                                     NaN
# Hadji Mohammad Ajul                                  NaN
# Hadji Muhtamad                                       NaN
# Kapai                                                NaN
# Lagayan                                              NaN
# Lugus                                                NaN
# Lumbaca-Unayan                                       NaN
# Luuk                                                 NaN
# Maimbung                                             NaN
# Old Panamao                                          NaN
# Oras                                                 NaN
# Pandami                                              NaN
# Panglima Estino                                      NaN
# Pangutaran                                           NaN
# Parang (SU)                                          NaN
# Patikul                                              NaN
# San Isidro (AA)                                      NaN
# San Quintin (AA)                                     NaN
# Siasi                                                NaN
# Sibuco                                               NaN
# Tabuan-Lasa                                          NaN
# Tapul                                                NaN
# Tongkil                                              NaN
# Tuburan (BA)                                         NaN
# Ungkaya Pukan                                        NaN
#
#                      2021 - Annual Disaster Drill  \
# city_municipality
# Akbar                                         NaN
# Al-Barka                                      NaN
# Compostela (DDO)                              NaN
# Hadji Mohammad Ajul                           NaN
# Hadji Muhtamad                                NaN
# Kapai                                         NaN
# Lagayan                                       NaN
# Lugus                                         NaN
# Lumbaca-Unayan                                NaN
# Luuk                                          NaN
# Maimbung                                      NaN
# Old Panamao                                   NaN
# Oras                                          NaN
# Pandami                                       NaN
# Panglima Estino                               NaN
# Pangutaran                                    NaN
# Parang (SU)                                   NaN
# Patikul                                       NaN
# San Isidro (AA)                               NaN
# San Quintin (AA)                              NaN
# Siasi                                         NaN
# Sibuco                                        NaN
# Tabuan-Lasa                                   NaN
# Tapul                                         NaN
# Tongkil                                       NaN
# Tuburan (BA)                                  NaN
# Ungkaya Pukan                                 NaN
#
#                      2021 - Early Warning System  2021 - Budget for DRRMP  \
# city_municipality
# Akbar                                        NaN                      NaN
# Al-Barka                                     NaN                      NaN
# Compostela (DDO)                             NaN                      NaN
# Hadji Mohammad Ajul                          NaN                      NaN
# Hadji Muhtamad                               NaN                      NaN
# Kapai                                        NaN                      NaN
# Lagayan                                      NaN                      NaN
# Lugus                                        NaN                      NaN
# Lumbaca-Unayan                               NaN                      NaN
# Luuk                                         NaN                      NaN
# Maimbung                                     NaN                      NaN
# Old Panamao                                  NaN                      NaN
# Oras                                         NaN                      NaN
# Pandami                                      NaN                      NaN
# Panglima Estino                              NaN                      NaN
# Pangutaran                                   NaN                      NaN
# Parang (SU)                                  NaN                      NaN
# Patikul                                      NaN                      NaN
# San Isidro (AA)                              NaN                      NaN
# San Quintin (AA)                             NaN                      NaN
# Siasi                                        NaN                      NaN
# Sibuco                                       NaN                      NaN
# Tabuan-Lasa                                  NaN                      NaN
# Tapul                                        NaN                      NaN
# Tongkil                                      NaN                      NaN
# Tuburan (BA)                                 NaN                      NaN
# Ungkaya Pukan                                NaN                      NaN
#
#                      2021 - Local Risk Assessments  \
# city_municipality
# Akbar                                          NaN
# Al-Barka                                       NaN
# Compostela (DDO)                               NaN
# Hadji Mohammad Ajul                            NaN
# Hadji Muhtamad                                 NaN
# Kapai                                          NaN
# Lagayan                                        NaN
# Lugus                                          NaN
# Lumbaca-Unayan                                 NaN
# Luuk                                           NaN
# Maimbung                                       NaN
# Old Panamao                                    NaN
# Oras                                           NaN
# Pandami                                        NaN
# Panglima Estino                                NaN
# Pangutaran                                     NaN
# Parang (SU)                                    NaN
# Patikul                                        NaN
# San Isidro (AA)                                NaN
# San Quintin (AA)                               NaN
# Siasi                                          NaN
# Sibuco                                         NaN
# Tabuan-Lasa                                    NaN
# Tapul                                          NaN
# Tongkil                                        NaN
# Tuburan (BA)                                   NaN
# Ungkaya Pukan                                  NaN
#
#                      2021 - Emergency Infrastructure  2021 - Utilities  \
# city_municipality
# Akbar                                            NaN               NaN
# Al-Barka                                         NaN               NaN
# Compostela (DDO)                                 NaN               NaN
# Hadji Mohammad Ajul                              NaN               NaN
# Hadji Muhtamad                                   NaN               NaN
# Kapai                                            NaN               NaN
# Lagayan                                          NaN               NaN
# Lugus                                            NaN               NaN
# Lumbaca-Unayan                                   NaN               NaN
# Luuk                                             NaN               NaN
# Maimbung                                         NaN               NaN
# Old Panamao                                      NaN               NaN
# Oras                                             NaN               NaN
# Pandami                                          NaN               NaN
# Panglima Estino                                  NaN               NaN
# Pangutaran                                       NaN               NaN
# Parang (SU)                                      NaN               NaN
# Patikul                                          NaN               NaN
# San Isidro (AA)                                  NaN               NaN
# San Quintin (AA)                                 NaN               NaN
# Siasi                                            NaN               NaN
# Sibuco                                           NaN               NaN
# Tabuan-Lasa                                      NaN               NaN
# Tapul                                            NaN               NaN
# Tongkil                                          NaN               NaN
# Tuburan (BA)                                     NaN               NaN
# Ungkaya Pukan                                    NaN               NaN
#
#                      2021 - Employed Population  2021 - Sanitary System
# city_municipality
# Akbar                                       NaN                     NaN
# Al-Barka                                    NaN                     NaN
# Compostela (DDO)                            NaN                     NaN
# Hadji Mohammad Ajul                         NaN                     NaN
# Hadji Muhtamad                              NaN                     NaN
# Kapai                                       NaN                     NaN
# Lagayan                                     NaN                     NaN
# Lugus                                       NaN                     NaN
# Lumbaca-Unayan                              NaN                     NaN
# Luuk                                        NaN                     NaN
# Maimbung                                    NaN                     NaN
# Old Panamao                                 NaN                     NaN
# Oras                                        NaN                     NaN
# Pandami                                     NaN                     NaN
# Panglima Estino                             NaN                     NaN
# Pangutaran                                  NaN                     NaN
# Parang (SU)                                 NaN                     NaN
# Patikul                                     NaN                     NaN
# San Isidro (AA)                             NaN                     NaN
# San Quintin (AA)                            NaN                     NaN
# Siasi                                       NaN                     NaN
# Sibuco                                      NaN                     NaN
# Tabuan-Lasa                                 NaN                     NaN
# Tapul                                       NaN                     NaN
# Tongkil                                     NaN                     NaN
# Tuburan (BA)                                NaN                     NaN
# Ungkaya Pukan                               NaN                     NaN
#
# [27 rows x 40 columns]

# %%
# Remove '2021 - ' from all the column names
dti_2021.columns = dti_2021.columns.str.replace('2021 - ','')
dti_2021.head()
# Out:
#                    Local Economy Size  Local Economy Growth  \
# city_municipality
# Aborlan                        0.0067                0.0045
# Abra De Ilog                   0.0070                0.0066
# Abucay                         0.0876                0.0007
# Abulug                         0.0921                0.0012
# Abuyog                         0.0111                0.0027
#
#                    Active Establishments in the Locality  \
# city_municipality
# Aborlan                                           0.2606
# Abra De Ilog                                      0.0588
# Abucay                                            0.7344
# Abulug                                            0.3498
# Abuyog                                            0.1457
#
#                    Safety Compliant Business  Employment Generation  \
# city_municipality
# Aborlan                               0.1683                 0.1052
# Abra De Ilog                          0.0676                 0.0191
# Abucay                                0.4760                 0.5753
# Abulug                                0.3568                 0.3785
# Abuyog                                0.1349                 0.0811
#
#                    Cost of Living  Cost of Doing Business  \
# city_municipality
# Aborlan                    1.6250                  2.3654
# Abra De Ilog               0.5938                  2.3642
# Abucay                     1.0625                  2.0565
# Abulug                     0.7813                  2.1551
# Abuyog                     1.9688                  1.7724
#
#                    Financial Deepening  Productivity  \
# city_municipality
# Aborlan                         0.1231        0.0690
# Abra De Ilog                    0.0380        0.0150
# Abucay                          0.5657        0.5111
# Abulug                          1.2830        0.3946
# Abuyog                          0.5127        0.0606
#
#                    Presence of Business and Professional Organizations  ...  \
# city_municipality                                                       ...
# Aborlan                                                       0.1089    ...
# Abra De Ilog                                                  0.0106    ...
# Abucay                                                        0.0030    ...
# Abulug                                                        0.0030    ...
# Abuyog                                                        0.0439    ...
#
#                    Land Use Plan  Disaster Risk Reduction Plan  \
# city_municipality
# Aborlan                   2.4545                        2.4737
# Abra De Ilog              2.4773                        2.4737
# Abucay                    2.4857                        2.5000
# Abulug                    2.5000                        2.5000
# Abuyog                    2.4091                        2.4737
#
#                    Annual Disaster Drill  Early Warning System  \
# city_municipality
# Aborlan                           1.2542                1.2537
# Abra De Ilog                      1.2750                1.2683
# Abucay                            1.2829                1.2799
# Abulug                            1.2829                1.2525
# Abuyog                            0.0000                1.2518
#
#                    Budget for DRRMP  Local Risk Assessments  \
# city_municipality
# Aborlan                      0.0215                     2.5
# Abra De Ilog                 0.0215                     2.5
# Abucay                       0.0024                     2.5
# Abulug                       0.0025                     2.5
# Abuyog                       0.0236                     2.5
#
#                    Emergency Infrastructure  Utilities  Employed Population  \
# city_municipality
# Aborlan                              0.0531     1.2478               0.0060
# Abra De Ilog                         0.3294     1.2509               0.0443
# Abucay                               0.2674     1.3019               0.3219
# Abulug                               0.2912     1.2578               0.0157
# Abuyog                               0.2971     1.2604               0.0389
#
#                    Sanitary System
# city_municipality
# Aborlan                     1.2502
# Abra De Ilog                1.8752
# Abucay                      1.8751
# Abulug                      1.8750
# Abuyog                      1.8753
#
# [5 rows x 40 columns]

# %% [markdown]
# Only 27 rows have 100% null values. Let's impute those.

# %%
#Backfilling missing values in dti_2021 from dti_2022
dti_2021 = dti_2021.fillna(dti_2022)

# %%
# Finding the rows that has 100% null values
dti_2021[dti_2021.isna().all(axis=1)]
# Out:
#                    Local Economy Size  Local Economy Growth  \
# city_municipality
# Oras                              NaN                   NaN
#
#                    Active Establishments in the Locality  \
# city_municipality
# Oras                                                 NaN
#
#                    Safety Compliant Business  Employment Generation  \
# city_municipality
# Oras                                     NaN                    NaN
#
#                    Cost of Living  Cost of Doing Business  \
# city_municipality
# Oras                          NaN                     NaN
#
#                    Financial Deepening  Productivity  \
# city_municipality
# Oras                               NaN           NaN
#
#                    Presence of Business and Professional Organizations  ...  \
# city_municipality                                                       ...
# Oras                                                             NaN    ...
#
#                    Land Use Plan  Disaster Risk Reduction Plan  \
# city_municipality
# Oras                         NaN                           NaN
#
#                    Annual Disaster Drill  Early Warning System  \
# city_municipality
# Oras                                 NaN                   NaN
#
#                    Budget for DRRMP  Local Risk Assessments  \
# city_municipality
# Oras                            NaN                     NaN
#
#                    Emergency Infrastructure  Utilities  Employed Population  \
# city_municipality
# Oras                                    NaN        NaN                  NaN
#
#                    Sanitary System
# city_municipality
# Oras                           NaN
#
# [1 rows x 40 columns]

# %%
#Creating a dataframe with only 2020 data
cols_2020 = dti.columns[dti.columns.str.startswith('2020')].tolist()
dti_2020 = dti[cols_2020]
dti_2020.head()
# Out:
#                    2020 - Local Economy Size  2020 - Local Economy Growth  \
# city_municipality
# Aborlan                               0.0013                       0.1419
# Abra De Ilog                          0.0368                       0.3312
# Abucay                                0.1573                       1.0283
# Abulug                                0.1152                       1.0271
# Abuyog                                0.0056                       0.3335
#
#                    2020 - Active Establishments in the Locality  \
# city_municipality
# Aborlan                                                  0.1653
# Abra De Ilog                                             0.0368
# Abucay                                                   0.5199
# Abulug                                                   0.4901
# Abuyog                                                   0.1439
#
#                    2020 - Safety Compliant Business  \
# city_municipality
# Aborlan                                      0.1643
# Abra De Ilog                                 0.0255
# Abucay                                       0.4827
# Abulug                                       0.4286
# Abuyog                                       0.1115
#
#                    2020 - Employment Generation  2020 - Cost of Living  \
# city_municipality
# Aborlan                                  0.0651                 0.3017
# Abra De Ilog                             0.0166                 0.0000
# Abucay                                   0.4710                 1.3542
# Abulug                                   0.4318                 1.4583
# Abuyog                                   0.0697                 0.7759
#
#                    2020 - Cost of Doing Business  2020 - Financial Deepening  \
# city_municipality
# Aborlan                                   2.2798                      0.1390
# Abra De Ilog                              2.2618                      0.0593
# Abucay                                    2.0464                      0.4358
# Abulug                                    1.9800                      1.0757
# Abuyog                                    2.2232                      0.5327
#
#                    2020 - Productivity  \
# city_municipality
# Aborlan                         0.0413
# Abra De Ilog                    0.0088
# Abucay                          0.3949
# Abulug                          0.3447
# Abuyog                          0.0510
#
#                    2020 - Presence of Business and Professional Organizations  \
# city_municipality
# Aborlan                                                       0.0216
# Abra De Ilog                                                  0.0077
# Abucay                                                        0.0031
# Abulug                                                        0.0130
# Abuyog                                                        0.0452
#
#                    ...  2020 - Land Use Plan  \
# city_municipality  ...
# Aborlan            ...                2.5000
# Abra De Ilog       ...                2.3974
# Abucay             ...                2.3718
# Abulug             ...                1.3462
# Abuyog             ...                2.4872
#
#                    2020 - Disaster Risk Reduction Plan  \
# city_municipality
# Aborlan                                            2.5
# Abra De Ilog                                       2.5
# Abucay                                             2.5
# Abulug                                             2.5
# Abuyog                                             2.5
#
#                    2020 - Annual Disaster Drill  2020 - Early Warning System  \
# city_municipality
# Aborlan                                  2.5000                          2.5
# Abra De Ilog                             2.5000                          2.5
# Abucay                                   2.5000                          2.5
# Abulug                                   2.5000                          2.5
# Abuyog                                   2.0833                          2.5
#
#                    2020 - Budget for DRRMP  2020 - Local Risk Assessments  \
# city_municipality
# Aborlan                             0.0852                            2.5
# Abra De Ilog                        0.1105                            2.5
# Abucay                              0.0579                            2.5
# Abulug                              0.0473                            2.5
# Abuyog                              0.1630                            2.5
#
#                    2020 - Emergency Infrastructure  2020 - Utilities  \
# city_municipality
# Aborlan                                     0.5004            1.8706
# Abra De Ilog                                0.4665            1.8743
# Abucay                                      0.4839            1.8880
# Abulug                                      0.4934            1.8692
# Abuyog                                      0.5320            1.8616
#
#                    2020 - Employed Population  2020 - Sanitary System
# city_municipality
# Aborlan                                0.0385                  0.9946
# Abra De Ilog                           0.0798                  1.9811
# Abucay                                 0.3476                  1.9886
# Abulug                                 0.0367                  1.5003
# Abuyog                                 0.0061                  1.9774
#
# [5 rows x 40 columns]

# %%
# Finding the rows that has 100% null values
dti_2020[dti_2020.isna().all(axis=1)]
# Out:
#                    2020 - Local Economy Size  2020 - Local Economy Growth  \
# city_municipality
# Akbar                                    NaN                          NaN
# Al-Barka                                 NaN                          NaN
# Amai Manabilang                          NaN                          NaN
# Ampatuan                                 NaN                          NaN
# Bacolod-Kalawi                           NaN                          NaN
# ...                                      ...                          ...
# Tuburan (BA)                             NaN                          NaN
# Tugaya                                   NaN                          NaN
# Turtle Islands                           NaN                          NaN
# Ungkaya Pukan                            NaN                          NaN
# Wao                                      NaN                          NaN
#
#                    2020 - Active Establishments in the Locality  \
# city_municipality
# Akbar                                                       NaN
# Al-Barka                                                    NaN
# Amai Manabilang                                             NaN
# Ampatuan                                                    NaN
# Bacolod-Kalawi                                              NaN
# ...                                                         ...
# Tuburan (BA)                                                NaN
# Tugaya                                                      NaN
# Turtle Islands                                              NaN
# Ungkaya Pukan                                               NaN
# Wao                                                         NaN
#
#                    2020 - Safety Compliant Business  \
# city_municipality
# Akbar                                           NaN
# Al-Barka                                        NaN
# Amai Manabilang                                 NaN
# Ampatuan                                        NaN
# Bacolod-Kalawi                                  NaN
# ...                                             ...
# Tuburan (BA)                                    NaN
# Tugaya                                          NaN
# Turtle Islands                                  NaN
# Ungkaya Pukan                                   NaN
# Wao                                             NaN
#
#                    2020 - Employment Generation  2020 - Cost of Living  \
# city_municipality
# Akbar                                       NaN                    NaN
# Al-Barka                                    NaN                    NaN
# Amai Manabilang                             NaN                    NaN
# Ampatuan                                    NaN                    NaN
# Bacolod-Kalawi                              NaN                    NaN
# ...                                         ...                    ...
# Tuburan (BA)                                NaN                    NaN
# Tugaya                                      NaN                    NaN
# Turtle Islands                              NaN                    NaN
# Ungkaya Pukan                               NaN                    NaN
# Wao                                         NaN                    NaN
#
#                    2020 - Cost of Doing Business  2020 - Financial Deepening  \
# city_municipality
# Akbar                                        NaN                         NaN
# Al-Barka                                     NaN                         NaN
# Amai Manabilang                              NaN                         NaN
# Ampatuan                                     NaN                         NaN
# Bacolod-Kalawi                               NaN                         NaN
# ...                                          ...                         ...
# Tuburan (BA)                                 NaN                         NaN
# Tugaya                                       NaN                         NaN
# Turtle Islands                               NaN                         NaN
# Ungkaya Pukan                                NaN                         NaN
# Wao                                          NaN                         NaN
#
#                    2020 - Productivity  \
# city_municipality
# Akbar                              NaN
# Al-Barka                           NaN
# Amai Manabilang                    NaN
# Ampatuan                           NaN
# Bacolod-Kalawi                     NaN
# ...                                ...
# Tuburan (BA)                       NaN
# Tugaya                             NaN
# Turtle Islands                     NaN
# Ungkaya Pukan                      NaN
# Wao                                NaN
#
#                    2020 - Presence of Business and Professional Organizations  \
# city_municipality
# Akbar                                                            NaN
# Al-Barka                                                         NaN
# Amai Manabilang                                                  NaN
# Ampatuan                                                         NaN
# Bacolod-Kalawi                                                   NaN
# ...                                                              ...
# Tuburan (BA)                                                     NaN
# Tugaya                                                           NaN
# Turtle Islands                                                   NaN
# Ungkaya Pukan                                                    NaN
# Wao                                                              NaN
#
#                    ...  2020 - Land Use Plan  \
# city_municipality  ...
# Akbar              ...                   NaN
# Al-Barka           ...                   NaN
# Amai Manabilang    ...                   NaN
# Ampatuan           ...                   NaN
# Bacolod-Kalawi     ...                   NaN
# ...                ...                   ...
# Tuburan (BA)       ...                   NaN
# Tugaya             ...                   NaN
# Turtle Islands     ...                   NaN
# Ungkaya Pukan      ...                   NaN
# Wao                ...                   NaN
#
#                    2020 - Disaster Risk Reduction Plan  \
# city_municipality
# Akbar                                              NaN
# Al-Barka                                           NaN
# Amai Manabilang                                    NaN
# Ampatuan                                           NaN
# Bacolod-Kalawi                                     NaN
# ...                                                ...
# Tuburan (BA)                                       NaN
# Tugaya                                             NaN
# Turtle Islands                                     NaN
# Ungkaya Pukan                                      NaN
# Wao                                                NaN
#
#                    2020 - Annual Disaster Drill  2020 - Early Warning System  \
# city_municipality
# Akbar                                       NaN                          NaN
# Al-Barka                                    NaN                          NaN
# Amai Manabilang                             NaN                          NaN
# Ampatuan                                    NaN                          NaN
# Bacolod-Kalawi                              NaN                          NaN
# ...                                         ...                          ...
# Tuburan (BA)                                NaN                          NaN
# Tugaya                                      NaN                          NaN
# Turtle Islands                              NaN                          NaN
# Ungkaya Pukan                               NaN                          NaN
# Wao                                         NaN                          NaN
#
#                    2020 - Budget for DRRMP  2020 - Local Risk Assessments  \
# city_municipality
# Akbar                                  NaN                            NaN
# Al-Barka                               NaN                            NaN
# Amai Manabilang                        NaN                            NaN
# Ampatuan                               NaN                            NaN
# Bacolod-Kalawi                         NaN                            NaN
# ...                                    ...                            ...
# Tuburan (BA)                           NaN                            NaN
# Tugaya                                 NaN                            NaN
# Turtle Islands                         NaN                            NaN
# Ungkaya Pukan                          NaN                            NaN
# Wao                                    NaN                            NaN
#
#                    2020 - Emergency Infrastructure  2020 - Utilities  \
# city_municipality
# Akbar                                          NaN               NaN
# Al-Barka                                       NaN               NaN
# Amai Manabilang                                NaN               NaN
# Ampatuan                                       NaN               NaN
# Bacolod-Kalawi                                 NaN               NaN
# ...                                            ...               ...
# Tuburan (BA)                                   NaN               NaN
# Tugaya                                         NaN               NaN
# Turtle Islands                                 NaN               NaN
# Ungkaya Pukan                                  NaN               NaN
# Wao                                            NaN               NaN
#
#                    2020 - Employed Population  2020 - Sanitary System
# city_municipality
# Akbar                                     NaN                     NaN
# Al-Barka                                  NaN                     NaN
# Amai Manabilang                           NaN                     NaN
# Ampatuan                                  NaN                     NaN
# Bacolod-Kalawi                            NaN                     NaN
# ...                                       ...                     ...
# Tuburan (BA)                              NaN                     NaN
# Tugaya                                    NaN                     NaN
# Turtle Islands                            NaN                     NaN
# Ungkaya Pukan                             NaN                     NaN
# Wao                                       NaN                     NaN
#
# [119 rows x 40 columns]

# %%
# Remove '2020 - ' from all the column names
dti_2020.columns = dti_2020.columns.str.replace('2020 - ','')
dti_2020.head()
# Out:
#                    Local Economy Size  Local Economy Growth  \
# city_municipality
# Aborlan                        0.0013                0.1419
# Abra De Ilog                   0.0368                0.3312
# Abucay                         0.1573                1.0283
# Abulug                         0.1152                1.0271
# Abuyog                         0.0056                0.3335
#
#                    Active Establishments in the Locality  \
# city_municipality
# Aborlan                                           0.1653
# Abra De Ilog                                      0.0368
# Abucay                                            0.5199
# Abulug                                            0.4901
# Abuyog                                            0.1439
#
#                    Safety Compliant Business  Employment Generation  \
# city_municipality
# Aborlan                               0.1643                 0.0651
# Abra De Ilog                          0.0255                 0.0166
# Abucay                                0.4827                 0.4710
# Abulug                                0.4286                 0.4318
# Abuyog                                0.1115                 0.0697
#
#                    Cost of Living  Cost of Doing Business  \
# city_municipality
# Aborlan                    0.3017                  2.2798
# Abra De Ilog               0.0000                  2.2618
# Abucay                     1.3542                  2.0464
# Abulug                     1.4583                  1.9800
# Abuyog                     0.7759                  2.2232
#
#                    Financial Deepening  Productivity  \
# city_municipality
# Aborlan                         0.1390        0.0413
# Abra De Ilog                    0.0593        0.0088
# Abucay                          0.4358        0.3949
# Abulug                          1.0757        0.3447
# Abuyog                          0.5327        0.0510
#
#                    Presence of Business and Professional Organizations  ...  \
# city_municipality                                                       ...
# Aborlan                                                       0.0216    ...
# Abra De Ilog                                                  0.0077    ...
# Abucay                                                        0.0031    ...
# Abulug                                                        0.0130    ...
# Abuyog                                                        0.0452    ...
#
#                    Land Use Plan  Disaster Risk Reduction Plan  \
# city_municipality
# Aborlan                   2.5000                           2.5
# Abra De Ilog              2.3974                           2.5
# Abucay                    2.3718                           2.5
# Abulug                    1.3462                           2.5
# Abuyog                    2.4872                           2.5
#
#                    Annual Disaster Drill  Early Warning System  \
# city_municipality
# Aborlan                           2.5000                   2.5
# Abra De Ilog                      2.5000                   2.5
# Abucay                            2.5000                   2.5
# Abulug                            2.5000                   2.5
# Abuyog                            2.0833                   2.5
#
#                    Budget for DRRMP  Local Risk Assessments  \
# city_municipality
# Aborlan                      0.0852                     2.5
# Abra De Ilog                 0.1105                     2.5
# Abucay                       0.0579                     2.5
# Abulug                       0.0473                     2.5
# Abuyog                       0.1630                     2.5
#
#                    Emergency Infrastructure  Utilities  Employed Population  \
# city_municipality
# Aborlan                              0.5004     1.8706               0.0385
# Abra De Ilog                         0.4665     1.8743               0.0798
# Abucay                               0.4839     1.8880               0.3476
# Abulug                               0.4934     1.8692               0.0367
# Abuyog                               0.5320     1.8616               0.0061
#
#                    Sanitary System
# city_municipality
# Aborlan                     0.9946
# Abra De Ilog                1.9811
# Abucay                      1.9886
# Abulug                      1.5003
# Abuyog                      1.9774
#
# [5 rows x 40 columns]

# %%
#Backfilling missing values in dti_2020 from dti_2021
dti_2020 = dti_2020.fillna(dti_2021)

# %%
# Finding the rows that has 100% null values
dti_2020[dti_2020.isna().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Local Economy Size, Local Economy Growth, Active Establishments in the Locality, Safety Compliant Business, Employment Generation, Cost of Living, Cost of Doing Business, Financial Deepening, Productivity, Presence of Business and Professional Organizations, Compliance to National Directives, Presence of Investment Promotion Unit, Compliance to ARTA Citizens Charter, Capacity to Generate Local Resource, Capacity of Health Services, Capacity of School Services, Recognition of Performance, Getting Business Permits, Peace and Order, Social Protection, Road Network, Distance to Ports, Availability of Basic Utilities, Transportation Vehicles, Education, Health, LGU Investment, Accommodation Capacity, Information Technology Capacity, Financial Technology Capacity, Land Use Plan, Disaster Risk Reduction Plan, Annual Disaster Drill, Early Warning System, Budget for DRRMP, Local Risk Assessments, Emergency Infrastructure, Utilities, Employed Population, Sanitary System]
# Index: []
#
# [0 rows x 40 columns]

# %%
#Creating a dataframe with only 2019 data
cols_2019 = dti.columns[dti.columns.str.startswith('2019')].tolist()
dti_2019 = dti[cols_2019]
dti_2019.head()
# Out:
#                    2019 - Local Economy Size  2019 - Local Economy Growth  \
# city_municipality
# Aborlan                               0.0051                       0.0024
# Abra De Ilog                          0.0025                       0.0071
# Abucay                                0.0659                       0.0010
# Abulug                                0.0417                       0.0013
# Abuyog                                0.0018                       0.0008
#
#                    2019 - Active Establishments in the Locality  \
# city_municipality
# Aborlan                                                  0.0000
# Abra De Ilog                                             0.0267
# Abucay                                                   0.3854
# Abulug                                                   0.2087
# Abuyog                                                   0.1112
#
#                    2019 - Safety Compliant Business  \
# city_municipality
# Aborlan                                      0.2553
# Abra De Ilog                                 0.0398
# Abucay                                       0.4388
# Abulug                                       0.3854
# Abuyog                                       0.1251
#
#                    2019 - Employment Generation  2019 - Cost of Living  \
# city_municipality
# Aborlan                                  0.0000                 0.9127
# Abra De Ilog                             0.0181                 1.8254
# Abucay                                   0.4713                 2.5000
# Abulug                                   0.3250                 1.7500
# Abuyog                                   0.0639                 1.0714
#
#                    2019 - Cost of Doing Business  2019 - Financial Deepening  \
# city_municipality
# Aborlan                                   1.9655                      0.1339
# Abra De Ilog                              2.0960                      0.0588
# Abucay                                    1.9681                      0.3395
# Abulug                                    1.9673                      0.7000
# Abuyog                                    2.1017                      0.5411
#
#                    2019 - Productivity  \
# city_municipality
# Aborlan                         0.0004
# Abra De Ilog                    0.0002
# Abucay                          0.3674
# Abulug                          0.2565
# Abuyog                          0.0005
#
#                    2019 - Presence of Business and Professional Organizations  \
# city_municipality
# Aborlan                                                       0.0007
# Abra De Ilog                                                  0.0106
# Abucay                                                        0.0019
# Abulug                                                        0.0019
# Abuyog                                                        0.0177
#
#                    ...  2019 - Land Use Plan  \
# city_municipality  ...
# Aborlan            ...                2.4231
# Abra De Ilog       ...                2.3974
# Abucay             ...                2.3718
# Abulug             ...                0.3462
# Abuyog             ...                2.4872
#
#                    2019 - Disaster Risk Reduction Plan  \
# city_municipality
# Aborlan                                         2.4537
# Abra De Ilog                                    2.4537
# Abucay                                          2.4537
# Abulug                                          2.0833
# Abuyog                                          2.4537
#
#                    2019 - Annual Disaster Drill  2019 - Early Warning System  \
# city_municipality
# Aborlan                                  2.2500                          2.5
# Abra De Ilog                             2.2500                          2.5
# Abucay                                   2.4107                          2.5
# Abulug                                   1.2500                          2.5
# Abuyog                                   2.2500                          2.5
#
#                    2019 - Budget for DRRMP  2019 - Local Risk Assessments  \
# city_municipality
# Aborlan                             0.2189                            2.5
# Abra De Ilog                        0.1545                            2.5
# Abucay                              0.1544                            2.5
# Abulug                              0.1396                            2.5
# Abuyog                              0.2455                            2.5
#
#                    2019 - Emergency Infrastructure  2019 - Utilities  \
# city_municipality
# Aborlan                                     0.4984            1.8558
# Abra De Ilog                                0.4807            1.8746
# Abucay                                      0.4776            1.8850
# Abulug                                      0.5014            1.8742
# Abuyog                                      0.5121            1.8612
#
#                    2019 - Employed Population  2019 - Sanitary System
# city_municipality
# Aborlan                                0.0401                  1.4921
# Abra De Ilog                           0.0817                  1.9674
# Abucay                                 0.2901                  2.0447
# Abulug                                 0.0475                  2.0125
# Abuyog                                 0.0095                  1.9483
#
# [5 rows x 40 columns]

# %%
# Finding the rows that has 100% null values
dti_2019[dti_2019.isna().all(axis=1)]
# Out:
#                    2019 - Local Economy Size  2019 - Local Economy Growth  \
# city_municipality
# Akbar                                    NaN                          NaN
# Al-Barka                                 NaN                          NaN
# Amai Manabilang                          NaN                          NaN
# Ampatuan                                 NaN                          NaN
# Bacolod-Kalawi                           NaN                          NaN
# ...                                      ...                          ...
# Tuburan (BA)                             NaN                          NaN
# Tugaya                                   NaN                          NaN
# Turtle Islands                           NaN                          NaN
# Ungkaya Pukan                            NaN                          NaN
# Wao                                      NaN                          NaN
#
#                    2019 - Active Establishments in the Locality  \
# city_municipality
# Akbar                                                       NaN
# Al-Barka                                                    NaN
# Amai Manabilang                                             NaN
# Ampatuan                                                    NaN
# Bacolod-Kalawi                                              NaN
# ...                                                         ...
# Tuburan (BA)                                                NaN
# Tugaya                                                      NaN
# Turtle Islands                                              NaN
# Ungkaya Pukan                                               NaN
# Wao                                                         NaN
#
#                    2019 - Safety Compliant Business  \
# city_municipality
# Akbar                                           NaN
# Al-Barka                                        NaN
# Amai Manabilang                                 NaN
# Ampatuan                                        NaN
# Bacolod-Kalawi                                  NaN
# ...                                             ...
# Tuburan (BA)                                    NaN
# Tugaya                                          NaN
# Turtle Islands                                  NaN
# Ungkaya Pukan                                   NaN
# Wao                                             NaN
#
#                    2019 - Employment Generation  2019 - Cost of Living  \
# city_municipality
# Akbar                                       NaN                    NaN
# Al-Barka                                    NaN                    NaN
# Amai Manabilang                             NaN                    NaN
# Ampatuan                                    NaN                    NaN
# Bacolod-Kalawi                              NaN                    NaN
# ...                                         ...                    ...
# Tuburan (BA)                                NaN                    NaN
# Tugaya                                      NaN                    NaN
# Turtle Islands                              NaN                    NaN
# Ungkaya Pukan                               NaN                    NaN
# Wao                                         NaN                    NaN
#
#                    2019 - Cost of Doing Business  2019 - Financial Deepening  \
# city_municipality
# Akbar                                        NaN                         NaN
# Al-Barka                                     NaN                         NaN
# Amai Manabilang                              NaN                         NaN
# Ampatuan                                     NaN                         NaN
# Bacolod-Kalawi                               NaN                         NaN
# ...                                          ...                         ...
# Tuburan (BA)                                 NaN                         NaN
# Tugaya                                       NaN                         NaN
# Turtle Islands                               NaN                         NaN
# Ungkaya Pukan                                NaN                         NaN
# Wao                                          NaN                         NaN
#
#                    2019 - Productivity  \
# city_municipality
# Akbar                              NaN
# Al-Barka                           NaN
# Amai Manabilang                    NaN
# Ampatuan                           NaN
# Bacolod-Kalawi                     NaN
# ...                                ...
# Tuburan (BA)                       NaN
# Tugaya                             NaN
# Turtle Islands                     NaN
# Ungkaya Pukan                      NaN
# Wao                                NaN
#
#                    2019 - Presence of Business and Professional Organizations  \
# city_municipality
# Akbar                                                            NaN
# Al-Barka                                                         NaN
# Amai Manabilang                                                  NaN
# Ampatuan                                                         NaN
# Bacolod-Kalawi                                                   NaN
# ...                                                              ...
# Tuburan (BA)                                                     NaN
# Tugaya                                                           NaN
# Turtle Islands                                                   NaN
# Ungkaya Pukan                                                    NaN
# Wao                                                              NaN
#
#                    ...  2019 - Land Use Plan  \
# city_municipality  ...
# Akbar              ...                   NaN
# Al-Barka           ...                   NaN
# Amai Manabilang    ...                   NaN
# Ampatuan           ...                   NaN
# Bacolod-Kalawi     ...                   NaN
# ...                ...                   ...
# Tuburan (BA)       ...                   NaN
# Tugaya             ...                   NaN
# Turtle Islands     ...                   NaN
# Ungkaya Pukan      ...                   NaN
# Wao                ...                   NaN
#
#                    2019 - Disaster Risk Reduction Plan  \
# city_municipality
# Akbar                                              NaN
# Al-Barka                                           NaN
# Amai Manabilang                                    NaN
# Ampatuan                                           NaN
# Bacolod-Kalawi                                     NaN
# ...                                                ...
# Tuburan (BA)                                       NaN
# Tugaya                                             NaN
# Turtle Islands                                     NaN
# Ungkaya Pukan                                      NaN
# Wao                                                NaN
#
#                    2019 - Annual Disaster Drill  2019 - Early Warning System  \
# city_municipality
# Akbar                                       NaN                          NaN
# Al-Barka                                    NaN                          NaN
# Amai Manabilang                             NaN                          NaN
# Ampatuan                                    NaN                          NaN
# Bacolod-Kalawi                              NaN                          NaN
# ...                                         ...                          ...
# Tuburan (BA)                                NaN                          NaN
# Tugaya                                      NaN                          NaN
# Turtle Islands                              NaN                          NaN
# Ungkaya Pukan                               NaN                          NaN
# Wao                                         NaN                          NaN
#
#                    2019 - Budget for DRRMP  2019 - Local Risk Assessments  \
# city_municipality
# Akbar                                  NaN                            NaN
# Al-Barka                               NaN                            NaN
# Amai Manabilang                        NaN                            NaN
# Ampatuan                               NaN                            NaN
# Bacolod-Kalawi                         NaN                            NaN
# ...                                    ...                            ...
# Tuburan (BA)                           NaN                            NaN
# Tugaya                                 NaN                            NaN
# Turtle Islands                         NaN                            NaN
# Ungkaya Pukan                          NaN                            NaN
# Wao                                    NaN                            NaN
#
#                    2019 - Emergency Infrastructure  2019 - Utilities  \
# city_municipality
# Akbar                                          NaN               NaN
# Al-Barka                                       NaN               NaN
# Amai Manabilang                                NaN               NaN
# Ampatuan                                       NaN               NaN
# Bacolod-Kalawi                                 NaN               NaN
# ...                                            ...               ...
# Tuburan (BA)                                   NaN               NaN
# Tugaya                                         NaN               NaN
# Turtle Islands                                 NaN               NaN
# Ungkaya Pukan                                  NaN               NaN
# Wao                                            NaN               NaN
#
#                    2019 - Employed Population  2019 - Sanitary System
# city_municipality
# Akbar                                     NaN                     NaN
# Al-Barka                                  NaN                     NaN
# Amai Manabilang                           NaN                     NaN
# Ampatuan                                  NaN                     NaN
# Bacolod-Kalawi                            NaN                     NaN
# ...                                       ...                     ...
# Tuburan (BA)                              NaN                     NaN
# Tugaya                                    NaN                     NaN
# Turtle Islands                            NaN                     NaN
# Ungkaya Pukan                             NaN                     NaN
# Wao                                       NaN                     NaN
#
# [118 rows x 40 columns]

# %%
# Remove '2019 - ' from all the column names
dti_2019.columns = dti_2019.columns.str.replace('2019 - ','')
dti_2019.head()
# Out:
#                    Local Economy Size  Local Economy Growth  \
# city_municipality
# Aborlan                        0.0051                0.0024
# Abra De Ilog                   0.0025                0.0071
# Abucay                         0.0659                0.0010
# Abulug                         0.0417                0.0013
# Abuyog                         0.0018                0.0008
#
#                    Active Establishments in the Locality  \
# city_municipality
# Aborlan                                           0.0000
# Abra De Ilog                                      0.0267
# Abucay                                            0.3854
# Abulug                                            0.2087
# Abuyog                                            0.1112
#
#                    Safety Compliant Business  Employment Generation  \
# city_municipality
# Aborlan                               0.2553                 0.0000
# Abra De Ilog                          0.0398                 0.0181
# Abucay                                0.4388                 0.4713
# Abulug                                0.3854                 0.3250
# Abuyog                                0.1251                 0.0639
#
#                    Cost of Living  Cost of Doing Business  \
# city_municipality
# Aborlan                    0.9127                  1.9655
# Abra De Ilog               1.8254                  2.0960
# Abucay                     2.5000                  1.9681
# Abulug                     1.7500                  1.9673
# Abuyog                     1.0714                  2.1017
#
#                    Financial Deepening  Productivity  \
# city_municipality
# Aborlan                         0.1339        0.0004
# Abra De Ilog                    0.0588        0.0002
# Abucay                          0.3395        0.3674
# Abulug                          0.7000        0.2565
# Abuyog                          0.5411        0.0005
#
#                    Presence of Business and Professional Organizations  ...  \
# city_municipality                                                       ...
# Aborlan                                                       0.0007    ...
# Abra De Ilog                                                  0.0106    ...
# Abucay                                                        0.0019    ...
# Abulug                                                        0.0019    ...
# Abuyog                                                        0.0177    ...
#
#                    Land Use Plan  Disaster Risk Reduction Plan  \
# city_municipality
# Aborlan                   2.4231                        2.4537
# Abra De Ilog              2.3974                        2.4537
# Abucay                    2.3718                        2.4537
# Abulug                    0.3462                        2.0833
# Abuyog                    2.4872                        2.4537
#
#                    Annual Disaster Drill  Early Warning System  \
# city_municipality
# Aborlan                           2.2500                   2.5
# Abra De Ilog                      2.2500                   2.5
# Abucay                            2.4107                   2.5
# Abulug                            1.2500                   2.5
# Abuyog                            2.2500                   2.5
#
#                    Budget for DRRMP  Local Risk Assessments  \
# city_municipality
# Aborlan                      0.2189                     2.5
# Abra De Ilog                 0.1545                     2.5
# Abucay                       0.1544                     2.5
# Abulug                       0.1396                     2.5
# Abuyog                       0.2455                     2.5
#
#                    Emergency Infrastructure  Utilities  Employed Population  \
# city_municipality
# Aborlan                              0.4984     1.8558               0.0401
# Abra De Ilog                         0.4807     1.8746               0.0817
# Abucay                               0.4776     1.8850               0.2901
# Abulug                               0.5014     1.8742               0.0475
# Abuyog                               0.5121     1.8612               0.0095
#
#                    Sanitary System
# city_municipality
# Aborlan                     1.4921
# Abra De Ilog                1.9674
# Abucay                      2.0447
# Abulug                      2.0125
# Abuyog                      1.9483
#
# [5 rows x 40 columns]

# %%
#Backfilling missing values in dti_2019 from dti_2020
dti_2019 = dti_2019.fillna(dti_2020)

# %%
# Finding the rows that has 100% null values
dti_2019[dti_2019.isna().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Local Economy Size, Local Economy Growth, Active Establishments in the Locality, Safety Compliant Business, Employment Generation, Cost of Living, Cost of Doing Business, Financial Deepening, Productivity, Presence of Business and Professional Organizations, Compliance to National Directives, Presence of Investment Promotion Unit, Compliance to ARTA Citizens Charter, Capacity to Generate Local Resource, Capacity of Health Services, Capacity of School Services, Recognition of Performance, Getting Business Permits, Peace and Order, Social Protection, Road Network, Distance to Ports, Availability of Basic Utilities, Transportation Vehicles, Education, Health, LGU Investment, Accommodation Capacity, Information Technology Capacity, Financial Technology Capacity, Land Use Plan, Disaster Risk Reduction Plan, Annual Disaster Drill, Early Warning System, Budget for DRRMP, Local Risk Assessments, Emergency Infrastructure, Utilities, Employed Population, Sanitary System]
# Index: []
#
# [0 rows x 40 columns]

# %%
#Creating a dataframe with only 2018 data
cols_2018 = dti.columns[dti.columns.str.startswith('2018')].tolist()
dti_2018 = dti[cols_2018]
dti_2018.head()
# Out:
#                    2018 - Local Economy Size  2018 - Local Economy Growth  \
# city_municipality
# Aborlan                               0.0072                       0.0224
# Abra De Ilog                          0.0027                       0.0102
# Abucay                                0.0488                       0.0020
# Abulug                                0.0651                       0.0052
# Abuyog                                0.0115                       0.0208
#
#                    2018 - Active Establishments in the Locality  \
# city_municipality
# Aborlan                                                  0.2337
# Abra De Ilog                                             0.0477
# Abucay                                                   0.0053
# Abulug                                                   0.0053
# Abuyog                                                   0.1813
#
#                    2018 - Safety Compliant Business  \
# city_municipality
# Aborlan                                      0.1253
# Abra De Ilog                                 0.0282
# Abucay                                       0.2363
# Abulug                                       0.2440
# Abuyog                                       0.3592
#
#                    2018 - Employment Generation  2018 - Cost of Living  \
# city_municipality
# Aborlan                                  0.0197                 1.9907
# Abra De Ilog                             0.0008                 2.3611
# Abucay                                   0.2299                 1.1111
# Abulug                                   0.1548                 1.2963
# Abuyog                                   0.0499                 1.0185
#
#                    2018 - Cost of Doing Business  2018 - Financial Deepening  \
# city_municipality
# Aborlan                                   2.1771                      0.0423
# Abra De Ilog                              2.2200                      0.0184
# Abucay                                    1.8373                      0.0965
# Abulug                                    2.0402                      0.1762
# Abuyog                                    1.1430                      0.1049
#
#                    2018 - Productivity  \
# city_municipality
# Aborlan                         0.0047
# Abra De Ilog                    0.0579
# Abucay                          0.0198
# Abulug                          0.0103
# Abuyog                          0.0028
#
#                    2018 - Presence of Business and Professional Organizations  \
# city_municipality
# Aborlan                                                       0.0218
# Abra De Ilog                                                  0.0235
# Abucay                                                        0.0317
# Abulug                                                        0.0011
# Abuyog                                                        0.0000
#
#                    ...  2018 - Land Use Plan  \
# city_municipality  ...
# Aborlan            ...                   0.0
# Abra De Ilog       ...                   0.0
# Abucay             ...                   0.0
# Abulug             ...                   0.0
# Abuyog             ...                   0.0
#
#                    2018 - Disaster Risk Reduction Plan  \
# city_municipality
# Aborlan                                            0.0
# Abra De Ilog                                       0.0
# Abucay                                             0.0
# Abulug                                             0.0
# Abuyog                                             0.0
#
#                    2018 - Annual Disaster Drill  2018 - Early Warning System  \
# city_municipality
# Aborlan                                     0.0                          0.0
# Abra De Ilog                                0.0                          0.0
# Abucay                                      0.0                          0.0
# Abulug                                      0.0                          0.0
# Abuyog                                      0.0                          0.0
#
#                    2018 - Budget for DRRMP  2018 - Local Risk Assessments  \
# city_municipality
# Aborlan                                0.0                            0.0
# Abra De Ilog                           0.0                            0.0
# Abucay                                 0.0                            0.0
# Abulug                                 0.0                            0.0
# Abuyog                                 0.0                            0.0
#
#                    2018 - Emergency Infrastructure  2018 - Utilities  \
# city_municipality
# Aborlan                                        0.0               0.0
# Abra De Ilog                                   0.0               0.0
# Abucay                                         0.0               0.0
# Abulug                                         0.0               0.0
# Abuyog                                         0.0               0.0
#
#                    2018 - Employed Population  2018 - Sanitary System
# city_municipality
# Aborlan                                   0.0                     0.0
# Abra De Ilog                              0.0                     0.0
# Abucay                                    0.0                     0.0
# Abulug                                    0.0                     0.0
# Abuyog                                    0.0                     0.0
#
# [5 rows x 40 columns]

# %%
# Finding the rows that has 100% null values
dti_2018[dti_2018.isna().all(axis=1)]
# Out:
#                    2018 - Local Economy Size  2018 - Local Economy Growth  \
# city_municipality
# Akbar                                    NaN                          NaN
# Al-Barka                                 NaN                          NaN
# Amai Manabilang                          NaN                          NaN
# Ampatuan                                 NaN                          NaN
# Bacolod-Kalawi                           NaN                          NaN
# ...                                      ...                          ...
# Tuburan (BA)                             NaN                          NaN
# Tugaya                                   NaN                          NaN
# Turtle Islands                           NaN                          NaN
# Ungkaya Pukan                            NaN                          NaN
# Wao                                      NaN                          NaN
#
#                    2018 - Active Establishments in the Locality  \
# city_municipality
# Akbar                                                       NaN
# Al-Barka                                                    NaN
# Amai Manabilang                                             NaN
# Ampatuan                                                    NaN
# Bacolod-Kalawi                                              NaN
# ...                                                         ...
# Tuburan (BA)                                                NaN
# Tugaya                                                      NaN
# Turtle Islands                                              NaN
# Ungkaya Pukan                                               NaN
# Wao                                                         NaN
#
#                    2018 - Safety Compliant Business  \
# city_municipality
# Akbar                                           NaN
# Al-Barka                                        NaN
# Amai Manabilang                                 NaN
# Ampatuan                                        NaN
# Bacolod-Kalawi                                  NaN
# ...                                             ...
# Tuburan (BA)                                    NaN
# Tugaya                                          NaN
# Turtle Islands                                  NaN
# Ungkaya Pukan                                   NaN
# Wao                                             NaN
#
#                    2018 - Employment Generation  2018 - Cost of Living  \
# city_municipality
# Akbar                                       NaN                    NaN
# Al-Barka                                    NaN                    NaN
# Amai Manabilang                             NaN                    NaN
# Ampatuan                                    NaN                    NaN
# Bacolod-Kalawi                              NaN                    NaN
# ...                                         ...                    ...
# Tuburan (BA)                                NaN                    NaN
# Tugaya                                      NaN                    NaN
# Turtle Islands                              NaN                    NaN
# Ungkaya Pukan                               NaN                    NaN
# Wao                                         NaN                    NaN
#
#                    2018 - Cost of Doing Business  2018 - Financial Deepening  \
# city_municipality
# Akbar                                        NaN                         NaN
# Al-Barka                                     NaN                         NaN
# Amai Manabilang                              NaN                         NaN
# Ampatuan                                     NaN                         NaN
# Bacolod-Kalawi                               NaN                         NaN
# ...                                          ...                         ...
# Tuburan (BA)                                 NaN                         NaN
# Tugaya                                       NaN                         NaN
# Turtle Islands                               NaN                         NaN
# Ungkaya Pukan                                NaN                         NaN
# Wao                                          NaN                         NaN
#
#                    2018 - Productivity  \
# city_municipality
# Akbar                              NaN
# Al-Barka                           NaN
# Amai Manabilang                    NaN
# Ampatuan                           NaN
# Bacolod-Kalawi                     NaN
# ...                                ...
# Tuburan (BA)                       NaN
# Tugaya                             NaN
# Turtle Islands                     NaN
# Ungkaya Pukan                      NaN
# Wao                                NaN
#
#                    2018 - Presence of Business and Professional Organizations  \
# city_municipality
# Akbar                                                            NaN
# Al-Barka                                                         NaN
# Amai Manabilang                                                  NaN
# Ampatuan                                                         NaN
# Bacolod-Kalawi                                                   NaN
# ...                                                              ...
# Tuburan (BA)                                                     NaN
# Tugaya                                                           NaN
# Turtle Islands                                                   NaN
# Ungkaya Pukan                                                    NaN
# Wao                                                              NaN
#
#                    ...  2018 - Land Use Plan  \
# city_municipality  ...
# Akbar              ...                   NaN
# Al-Barka           ...                   NaN
# Amai Manabilang    ...                   NaN
# Ampatuan           ...                   NaN
# Bacolod-Kalawi     ...                   NaN
# ...                ...                   ...
# Tuburan (BA)       ...                   NaN
# Tugaya             ...                   NaN
# Turtle Islands     ...                   NaN
# Ungkaya Pukan      ...                   NaN
# Wao                ...                   NaN
#
#                    2018 - Disaster Risk Reduction Plan  \
# city_municipality
# Akbar                                              NaN
# Al-Barka                                           NaN
# Amai Manabilang                                    NaN
# Ampatuan                                           NaN
# Bacolod-Kalawi                                     NaN
# ...                                                ...
# Tuburan (BA)                                       NaN
# Tugaya                                             NaN
# Turtle Islands                                     NaN
# Ungkaya Pukan                                      NaN
# Wao                                                NaN
#
#                    2018 - Annual Disaster Drill  2018 - Early Warning System  \
# city_municipality
# Akbar                                       NaN                          NaN
# Al-Barka                                    NaN                          NaN
# Amai Manabilang                             NaN                          NaN
# Ampatuan                                    NaN                          NaN
# Bacolod-Kalawi                              NaN                          NaN
# ...                                         ...                          ...
# Tuburan (BA)                                NaN                          NaN
# Tugaya                                      NaN                          NaN
# Turtle Islands                              NaN                          NaN
# Ungkaya Pukan                               NaN                          NaN
# Wao                                         NaN                          NaN
#
#                    2018 - Budget for DRRMP  2018 - Local Risk Assessments  \
# city_municipality
# Akbar                                  NaN                            NaN
# Al-Barka                               NaN                            NaN
# Amai Manabilang                        NaN                            NaN
# Ampatuan                               NaN                            NaN
# Bacolod-Kalawi                         NaN                            NaN
# ...                                    ...                            ...
# Tuburan (BA)                           NaN                            NaN
# Tugaya                                 NaN                            NaN
# Turtle Islands                         NaN                            NaN
# Ungkaya Pukan                          NaN                            NaN
# Wao                                    NaN                            NaN
#
#                    2018 - Emergency Infrastructure  2018 - Utilities  \
# city_municipality
# Akbar                                          NaN               NaN
# Al-Barka                                       NaN               NaN
# Amai Manabilang                                NaN               NaN
# Ampatuan                                       NaN               NaN
# Bacolod-Kalawi                                 NaN               NaN
# ...                                            ...               ...
# Tuburan (BA)                                   NaN               NaN
# Tugaya                                         NaN               NaN
# Turtle Islands                                 NaN               NaN
# Ungkaya Pukan                                  NaN               NaN
# Wao                                            NaN               NaN
#
#                    2018 - Employed Population  2018 - Sanitary System
# city_municipality
# Akbar                                     NaN                     NaN
# Al-Barka                                  NaN                     NaN
# Amai Manabilang                           NaN                     NaN
# Ampatuan                                  NaN                     NaN
# Bacolod-Kalawi                            NaN                     NaN
# ...                                       ...                     ...
# Tuburan (BA)                              NaN                     NaN
# Tugaya                                    NaN                     NaN
# Turtle Islands                            NaN                     NaN
# Ungkaya Pukan                             NaN                     NaN
# Wao                                       NaN                     NaN
#
# [126 rows x 40 columns]

# %%
# Remove '2018 - ' from all the column names
dti_2018.columns = dti_2018.columns.str.replace('2018 - ','')
dti_2018.head()
# Out:
#                    Local Economy Size  Local Economy Growth  \
# city_municipality
# Aborlan                        0.0072                0.0224
# Abra De Ilog                   0.0027                0.0102
# Abucay                         0.0488                0.0020
# Abulug                         0.0651                0.0052
# Abuyog                         0.0115                0.0208
#
#                    Active Establishments in the Locality  \
# city_municipality
# Aborlan                                           0.2337
# Abra De Ilog                                      0.0477
# Abucay                                            0.0053
# Abulug                                            0.0053
# Abuyog                                            0.1813
#
#                    Safety Compliant Business  Employment Generation  \
# city_municipality
# Aborlan                               0.1253                 0.0197
# Abra De Ilog                          0.0282                 0.0008
# Abucay                                0.2363                 0.2299
# Abulug                                0.2440                 0.1548
# Abuyog                                0.3592                 0.0499
#
#                    Cost of Living  Cost of Doing Business  \
# city_municipality
# Aborlan                    1.9907                  2.1771
# Abra De Ilog               2.3611                  2.2200
# Abucay                     1.1111                  1.8373
# Abulug                     1.2963                  2.0402
# Abuyog                     1.0185                  1.1430
#
#                    Financial Deepening  Productivity  \
# city_municipality
# Aborlan                         0.0423        0.0047
# Abra De Ilog                    0.0184        0.0579
# Abucay                          0.0965        0.0198
# Abulug                          0.1762        0.0103
# Abuyog                          0.1049        0.0028
#
#                    Presence of Business and Professional Organizations  ...  \
# city_municipality                                                       ...
# Aborlan                                                       0.0218    ...
# Abra De Ilog                                                  0.0235    ...
# Abucay                                                        0.0317    ...
# Abulug                                                        0.0011    ...
# Abuyog                                                        0.0000    ...
#
#                    Land Use Plan  Disaster Risk Reduction Plan  \
# city_municipality
# Aborlan                      0.0                           0.0
# Abra De Ilog                 0.0                           0.0
# Abucay                       0.0                           0.0
# Abulug                       0.0                           0.0
# Abuyog                       0.0                           0.0
#
#                    Annual Disaster Drill  Early Warning System  \
# city_municipality
# Aborlan                              0.0                   0.0
# Abra De Ilog                         0.0                   0.0
# Abucay                               0.0                   0.0
# Abulug                               0.0                   0.0
# Abuyog                               0.0                   0.0
#
#                    Budget for DRRMP  Local Risk Assessments  \
# city_municipality
# Aborlan                         0.0                     0.0
# Abra De Ilog                    0.0                     0.0
# Abucay                          0.0                     0.0
# Abulug                          0.0                     0.0
# Abuyog                          0.0                     0.0
#
#                    Emergency Infrastructure  Utilities  Employed Population  \
# city_municipality
# Aborlan                                 0.0        0.0                  0.0
# Abra De Ilog                            0.0        0.0                  0.0
# Abucay                                  0.0        0.0                  0.0
# Abulug                                  0.0        0.0                  0.0
# Abuyog                                  0.0        0.0                  0.0
#
#                    Sanitary System
# city_municipality
# Aborlan                        0.0
# Abra De Ilog                   0.0
# Abucay                         0.0
# Abulug                         0.0
# Abuyog                         0.0
#
# [5 rows x 40 columns]

# %%
#Backfilling missing values in dti_2018 from dti_2019
dti_2018 = dti_2018.fillna(dti_2019)

# %%
# Finding the rows that has 100% null values
dti_2018[dti_2018.isna().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Local Economy Size, Local Economy Growth, Active Establishments in the Locality, Safety Compliant Business, Employment Generation, Cost of Living, Cost of Doing Business, Financial Deepening, Productivity, Presence of Business and Professional Organizations, Compliance to National Directives, Presence of Investment Promotion Unit, Compliance to ARTA Citizens Charter, Capacity to Generate Local Resource, Capacity of Health Services, Capacity of School Services, Recognition of Performance, Getting Business Permits, Peace and Order, Social Protection, Road Network, Distance to Ports, Availability of Basic Utilities, Transportation Vehicles, Education, Health, LGU Investment, Accommodation Capacity, Information Technology Capacity, Financial Technology Capacity, Land Use Plan, Disaster Risk Reduction Plan, Annual Disaster Drill, Early Warning System, Budget for DRRMP, Local Risk Assessments, Emergency Infrastructure, Utilities, Employed Population, Sanitary System]
# Index: []
#
# [0 rows x 40 columns]

# %%
# Check number of missing values in each column of dti_2018
dti_2018.isnull().sum()
# Out:
# Local Economy Size                                     0
# Local Economy Growth                                   0
# Active Establishments in the Locality                  0
# Safety Compliant Business                              0
# Employment Generation                                  0
# Cost of Living                                         0
# Cost of Doing Business                                 0
# Financial Deepening                                    0
# Productivity                                           0
# Presence of Business and Professional Organizations    0
# Compliance to National Directives                      0
# Presence of Investment Promotion Unit                  0
# Compliance to ARTA Citizens Charter                    0
# Capacity to Generate Local Resource                    0
# Capacity of Health Services                            0
# Capacity of School Services                            0
# Recognition of Performance                             0
# Getting Business Permits                               0
# Peace and Order                                        0
# Social Protection                                      0
# Road Network                                           0
# Distance to Ports                                      0
# Availability of Basic Utilities                        0
# Transportation Vehicles                                0
# Education                                              0
# Health                                                 0
# LGU Investment                                         0
# Accommodation Capacity                                 0
# Information Technology Capacity                        0
# Financial Technology Capacity                          0
# Land Use Plan                                          0
# Disaster Risk Reduction Plan                           0
# Annual Disaster Drill                                  0
# Early Warning System                                   0
# Budget for DRRMP                                       0
# Local Risk Assessments                                 0
# Emergency Infrastructure                               0
# Utilities                                              0
# Employed Population                                    0
# Sanitary System                                        0
# dtype: int64

# %%
# Check number of missing values in each column of dti_2019
dti_2019.isnull().sum()
# Out:
# Local Economy Size                                     0
# Local Economy Growth                                   0
# Active Establishments in the Locality                  0
# Safety Compliant Business                              0
# Employment Generation                                  0
# Cost of Living                                         0
# Cost of Doing Business                                 0
# Financial Deepening                                    0
# Productivity                                           0
# Presence of Business and Professional Organizations    0
# Compliance to National Directives                      0
# Presence of Investment Promotion Unit                  0
# Compliance to ARTA Citizens Charter                    0
# Capacity to Generate Local Resource                    0
# Capacity of Health Services                            0
# Capacity of School Services                            0
# Recognition of Performance                             0
# Getting Business Permits                               0
# Peace and Order                                        0
# Social Protection                                      0
# Road Network                                           0
# Distance to Ports                                      0
# Availability of Basic Utilities                        0
# Transportation Vehicles                                0
# Education                                              0
# Health                                                 0
# LGU Investment                                         0
# Accommodation Capacity                                 0
# Information Technology Capacity                        0
# Financial Technology Capacity                          0
# Land Use Plan                                          0
# Disaster Risk Reduction Plan                           0
# Annual Disaster Drill                                  0
# Early Warning System                                   0
# Budget for DRRMP                                       0
# Local Risk Assessments                                 0
# Emergency Infrastructure                               0
# Utilities                                              0
# Employed Population                                    0
# Sanitary System                                        0
# dtype: int64

# %%
# Check number of missing values in each column of dti_2020
dti_2020.isnull().sum()
# Out:
# Local Economy Size                                     0
# Local Economy Growth                                   0
# Active Establishments in the Locality                  0
# Safety Compliant Business                              0
# Employment Generation                                  0
# Cost of Living                                         0
# Cost of Doing Business                                 0
# Financial Deepening                                    0
# Productivity                                           0
# Presence of Business and Professional Organizations    0
# Compliance to National Directives                      0
# Presence of Investment Promotion Unit                  0
# Compliance to ARTA Citizens Charter                    0
# Capacity to Generate Local Resource                    0
# Capacity of Health Services                            0
# Capacity of School Services                            0
# Recognition of Performance                             0
# Getting Business Permits                               0
# Peace and Order                                        0
# Social Protection                                      0
# Road Network                                           0
# Distance to Ports                                      0
# Availability of Basic Utilities                        0
# Transportation Vehicles                                0
# Education                                              0
# Health                                                 0
# LGU Investment                                         0
# Accommodation Capacity                                 0
# Information Technology Capacity                        0
# Financial Technology Capacity                          0
# Land Use Plan                                          0
# Disaster Risk Reduction Plan                           0
# Annual Disaster Drill                                  0
# Early Warning System                                   0
# Budget for DRRMP                                       0
# Local Risk Assessments                                 0
# Emergency Infrastructure                               0
# Utilities                                              0
# Employed Population                                    0
# Sanitary System                                        0
# dtype: int64

# %%
# Check number of missing values in each column of dti_2021
dti_2021.isnull().sum()
# Out:
# Local Economy Size                                     1
# Local Economy Growth                                   1
# Active Establishments in the Locality                  1
# Safety Compliant Business                              1
# Employment Generation                                  1
# Cost of Living                                         1
# Cost of Doing Business                                 1
# Financial Deepening                                    1
# Productivity                                           1
# Presence of Business and Professional Organizations    1
# Compliance to National Directives                      1
# Presence of Investment Promotion Unit                  1
# Compliance to ARTA Citizens Charter                    1
# Capacity to Generate Local Resource                    1
# Capacity of Health Services                            1
# Capacity of School Services                            1
# Recognition of Performance                             1
# Getting Business Permits                               1
# Peace and Order                                        1
# Social Protection                                      1
# Road Network                                           1
# Distance to Ports                                      1
# Availability of Basic Utilities                        1
# Transportation Vehicles                                1
# Education                                              1
# Health                                                 1
# LGU Investment                                         1
# Accommodation Capacity                                 1
# Information Technology Capacity                        1
# Financial Technology Capacity                          1
# Land Use Plan                                          1
# Disaster Risk Reduction Plan                           1
# Annual Disaster Drill                                  1
# Early Warning System                                   1
# Budget for DRRMP                                       1
# Local Risk Assessments                                 1
# Emergency Infrastructure                               1
# Utilities                                              1
# Employed Population                                    1
# Sanitary System                                        1
# dtype: int64

# %%
#Impute the missing values of dti_2021 from dt_2020
dti_2021 = dti_2021.fillna(dti_2020)

# %%
dti_2021.isnull().sum()
# Out:
# Local Economy Size                                     0
# Local Economy Growth                                   0
# Active Establishments in the Locality                  0
# Safety Compliant Business                              0
# Employment Generation                                  0
# Cost of Living                                         0
# Cost of Doing Business                                 0
# Financial Deepening                                    0
# Productivity                                           0
# Presence of Business and Professional Organizations    0
# Compliance to National Directives                      0
# Presence of Investment Promotion Unit                  0
# Compliance to ARTA Citizens Charter                    0
# Capacity to Generate Local Resource                    0
# Capacity of Health Services                            0
# Capacity of School Services                            0
# Recognition of Performance                             0
# Getting Business Permits                               0
# Peace and Order                                        0
# Social Protection                                      0
# Road Network                                           0
# Distance to Ports                                      0
# Availability of Basic Utilities                        0
# Transportation Vehicles                                0
# Education                                              0
# Health                                                 0
# LGU Investment                                         0
# Accommodation Capacity                                 0
# Information Technology Capacity                        0
# Financial Technology Capacity                          0
# Land Use Plan                                          0
# Disaster Risk Reduction Plan                           0
# Annual Disaster Drill                                  0
# Early Warning System                                   0
# Budget for DRRMP                                       0
# Local Risk Assessments                                 0
# Emergency Infrastructure                               0
# Utilities                                              0
# Employed Population                                    0
# Sanitary System                                        0
# dtype: int64

# %%
# Check number of missing values in each column of dti_2022
dti_2022.isnull().sum()
# Out:
# Local Economy Size                                      3
# Local Economy Growth                                    3
# Active Establishments in the Locality                  14
# Safety Compliant Business                               3
# Employment Generation                                   3
# Cost of Living                                          3
# Cost of Doing Business                                  3
# Financial Deepening                                     3
# Productivity                                            3
# Presence of Business and Professional Organizations     3
# Compliance to National Directives                       3
# Presence of Investment Promotion Unit                   3
# Compliance to ARTA Citizens Charter                     3
# Capacity to Generate Local Resource                     3
# Capacity of Health Services                             3
# Capacity of School Services                             3
# Recognition of Performance                              3
# Getting Business Permits                                3
# Peace and Order                                         3
# Social Protection                                       3
# Road Network                                            3
# Distance to Ports                                       3
# Availability of Basic Utilities                         3
# Transportation Vehicles                                 3
# Education                                               3
# Health                                                  3
# LGU Investment                                          3
# Accommodation Capacity                                  3
# Information Technology Capacity                         3
# Financial Technology Capacity                           3
# Land Use Plan                                           3
# Disaster Risk Reduction Plan                            3
# Annual Disaster Drill                                   3
# Early Warning System                                    3
# Budget for DRRMP                                        3
# Local Risk Assessments                                  3
# Emergency Infrastructure                                3
# Utilities                                               3
# Employed Population                                     3
# Sanitary System                                         3
# dtype: int64

# %%
#Impute the missing values of dti_2022 from dt_2021
dti_2022 = dti_2022.fillna(dti_2021)

# %%
# Check number of missing values in each column of dti_2022
dti_2022.isnull().sum()
# Out:
# Local Economy Size                                     0
# Local Economy Growth                                   0
# Active Establishments in the Locality                  0
# Safety Compliant Business                              0
# Employment Generation                                  0
# Cost of Living                                         0
# Cost of Doing Business                                 0
# Financial Deepening                                    0
# Productivity                                           0
# Presence of Business and Professional Organizations    0
# Compliance to National Directives                      0
# Presence of Investment Promotion Unit                  0
# Compliance to ARTA Citizens Charter                    0
# Capacity to Generate Local Resource                    0
# Capacity of Health Services                            0
# Capacity of School Services                            0
# Recognition of Performance                             0
# Getting Business Permits                               0
# Peace and Order                                        0
# Social Protection                                      0
# Road Network                                           0
# Distance to Ports                                      0
# Availability of Basic Utilities                        0
# Transportation Vehicles                                0
# Education                                              0
# Health                                                 0
# LGU Investment                                         0
# Accommodation Capacity                                 0
# Information Technology Capacity                        0
# Financial Technology Capacity                          0
# Land Use Plan                                          0
# Disaster Risk Reduction Plan                           0
# Annual Disaster Drill                                  0
# Early Warning System                                   0
# Budget for DRRMP                                       0
# Local Risk Assessments                                 0
# Emergency Infrastructure                               0
# Utilities                                              0
# Employed Population                                    0
# Sanitary System                                        0
# dtype: int64

# %%
#Create a new dataframe by taking the average of dti_2018,dti_2019,dti_2020,dti_2021,dti_2022 values
dti_consolidated = pd.concat([dti_2018,dti_2019,dti_2020,dti_2021,dti_2022]).groupby(level=0).mean()
dti_consolidated.head()
# Out:
#                    Local Economy Size  Local Economy Growth  \
# city_municipality
# Aborlan                       0.00616               0.03426
# Abra De Ilog                  0.01010               0.07102
# Abucay                        0.07480               0.20654
# Abulug                        0.06570               0.20716
# Abuyog                        0.00716               0.07156
#
#                    Active Establishments in the Locality  \
# city_municipality
# Aborlan                                          0.14516
# Abra De Ilog                                     0.04396
# Abucay                                           0.48740
# Abulug                                           0.27102
# Abuyog                                           0.14468
#
#                    Safety Compliant Business  Employment Generation  \
# city_municipality
# Aborlan                              0.14264                0.05048
# Abra De Ilog                         0.03222                0.01434
# Abucay                               0.41882                0.51426
# Abulug                               0.33298                0.34670
# Abuyog                               0.14614                0.06394
#
#                    Cost of Living  Cost of Doing Business  \
# city_municipality
# Aborlan                   1.35160                 2.13764
# Abra De Ilog              1.29356                 2.16820
# Abucay                    1.60536                 1.96090
# Abulug                    1.45696                 2.00796
# Abuyog                    1.31884                 1.81616
#
#                    Financial Deepening  Productivity  \
# city_municipality
# Aborlan                        0.10352       0.02990
# Abra De Ilog                   0.04376       0.01722
# Abucay                         0.33254       0.33276
# Abulug                         0.74002       0.25454
# Abuyog                         0.38690       0.03070
#
#                    Presence of Business and Professional Organizations  ...  \
# city_municipality                                                       ...
# Aborlan                                                      0.03294    ...
# Abra De Ilog                                                 0.01148    ...
# Abucay                                                       0.00984    ...
# Abulug                                                       0.00380    ...
# Abuyog                                                       0.02258    ...
#
#                    Land Use Plan  Disaster Risk Reduction Plan  \
# city_municipality
# Aborlan                  1.87248                       1.88544
# Abra De Ilog             1.85138                       1.88544
# Abucay                   1.83776                       1.89070
# Abulug                   1.23578                       1.51652
# Abuyog                   1.86154                       1.88544
#
#                    Annual Disaster Drill  Early Warning System  \
# city_municipality
# Aborlan                          1.40124               1.45248
# Abra De Ilog                     1.40660               1.45614
# Abucay                           1.43912               1.46348
# Abulug                           1.20698               1.45130
# Abuyog                           0.86666               1.45086
#
#                    Budget for DRRMP  Local Risk Assessments  \
# city_municipality
# Aborlan                     0.06512                     1.9
# Abra De Ilog                0.05730                     1.7
# Abucay                      0.04294                     1.9
# Abulug                      0.03788                     1.9
# Abuyog                      0.08642                     1.9
#
#                    Emergency Infrastructure  Utilities  Employed Population  \
# city_municipality
# Aborlan                             0.21622    1.29498              0.01814
# Abra De Ilog                        0.33904    1.30018              0.05380
# Abucay                              0.32866    1.31684              0.20318
# Abulug                              0.36148    1.30024              0.02080
# Abuyog                              0.35030    1.29742              0.01710
#
#                    Sanitary System
# city_municipality
# Aborlan                    0.94742
# Abra De Ilog               1.46478
# Abucay                     1.48168
# Abulug                     1.37756
# Abuyog                     1.46024
#
# [5 rows x 40 columns]
